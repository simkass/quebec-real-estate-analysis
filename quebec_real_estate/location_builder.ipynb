# %%
import pandas as pd
import numpy as np
import pickle

from geopy.geocoders import Nominatim
from geopy.distance import geodesic

# %% [markdown]
# Scraped Locations

# %%
raw_df = pd.read_csv('../data/raw/raw_listings.csv')
locations = list(raw_df['location'].value_counts().to_dict().keys())

# %% [markdown]
# Population centres

# %%
population_centres = pd.read_csv('../data/wikipedia/population_centres.csv')
population_centres.head()
# Out:
#    Rank       Population centre[2] Size group[2] Population (2016)[2]  \
# 0     1                   Montreal   Large urban            3,519,595
# 1     2  Ottawa - Gatineau (QC/ON)   Large urban              989,567
# 2     3                Quebec City   Large urban              705,103
# 3     4                 Sherbrooke   Large urban              139,565
# 4     5             Trois-Rivières   Large urban              114,203
#
#   Population (2011)[2] % Change[2]
# 0            3,387,653       +3.9%
# 1              945,592       +4.7%
# 2              681,804       +3.4%
# 3              133,673       +4.4%
# 4              112,626       +1.4%

# %%
population_centres = population_centres.drop(population_centres.columns[[0, 2, 3, 4, 5]], axis=1)
population_centres = population_centres.rename(columns={'Population centre[2]': 'Name'})
population_centres.head()
# Out:
#                         Name
# 0                   Montreal
# 1  Ottawa - Gatineau (QC/ON)
# 2                Quebec City
# 3                 Sherbrooke
# 4             Trois-Rivières

# %% [markdown]
# Dropping Quebec, Montreal & Laval

# %%
population_centres = population_centres[population_centres['Name'] != 'Montreal']
population_centres = population_centres[population_centres['Name'] != 'Quebec City']

# %% [markdown]
# Fixing town names

# %%
d = {'Ottawa - Gatineau (QC/ON)': 'Gatineau', 'Chicoutimi - Jonquière': 'Chicoutimi', 'Hawkesbury (QC/ON)': 'Grenville',
     'Campbellton (QC/NB)': 'Pointe-à-la-Croix', 'Port-Alfred-Bagotville': 'Bagotville', 'Sainte-Agathe-des-Monts -Val-David': 'Sainte-Agathe-des-Monts', 'Terrasse-des-Pins': 'Prévost', 'Domaine-C.-L.-C.': 'Saint-Lin–Laurentides'}
population_centres['Name'] = population_centres['Name'].replace(d)

# %% [markdown]
# Adding Quebec, Montreal & Laval Boroughs

# %%
mtl = pd.read_csv('../data/wikipedia/mtl-boroughs.csv')
laval = pd.read_csv('../data/wikipedia/laval-boroughs.csv')
quebec = pd.read_csv('../data/wikipedia/qc-boroughs.csv')

# %%
centres = list(population_centres['Name']) + list(mtl['Borough']) + list(laval['name']) + list(quebec['name'])

# %% [markdown]
# Finding geographical position

# %%
geolocator = Nominatim(user_agent='housing-qc')

# %%
# centre_dicts = []

# for centre in centres:
#     print(centre)
#     geocode = geolocator.geocode(centre + ', QC')
#     centre_dicts.append({'Name': centre, 'Latitude': geocode.latitude, 'Longitude': geocode.longitude})

# population_centres = pd.DataFrame(centre_dicts)
# population_centres.head()

# %%
# population_centres.to_csv('../data/processed/population_centres.csv', index=False)

# %%
population_centres = pd.read_csv('../data/processed/population_centres.csv')

# %% [markdown]
# Associating locations to populations centres

# %%
def find_closest_population_centre(locations, population_centres):
    location_mapper = {}
    unknown_locations = []
    for location in locations:
        print('LOCATION: ' + location)

        distances = []
        geocode = geolocator.geocode(str(location) + ', QC', timeout=None)

        if geocode is None:
            unknown_locations.append(location)
            print('UNKNOWN LOCATION: ' + location)
        else:
            for _, centre in population_centres.iterrows():
                distances.append(geodesic((geocode.latitude, geocode.longitude), (centre['Latitude'], centre['Longitude'])))

            closest_centre = population_centres.iloc[np.argmin(distances)]['Name']
            location_mapper[location] = closest_centre
            print('CLOSEST POPULATION CENTRE: ' + closest_centre)
    return location_mapper, unknown_locations

# %%
location_mapper, unknown_locations = find_closest_population_centre(locations, population_centres)
# Out:
# LOCATION: Gatineau
# CLOSEST POPULATION CENTRE: Gatineau
# LOCATION: Trois-Rivières
# CLOSEST POPULATION CENTRE: Trois-Rivières
# LOCATION: Beauport
# CLOSEST POPULATION CENTRE: Beauport
# LOCATION: Mercier
# CLOSEST POPULATION CENTRE: Châteauguay
# LOCATION: Alma
# CLOSEST POPULATION CENTRE: Alma
# LOCATION: Fabreville
# CLOSEST POPULATION CENTRE: Fabreville
# LOCATION: Ste-Marthe-Sur-Le-Lac
# CLOSEST POPULATION CENTRE: Laval-sur-le-Lac
# LOCATION: Stoneham
# CLOSEST POPULATION CENTRE: Stoneham
# LOCATION: St-Ferréol-les-Neiges
# CLOSEST POPULATION CENTRE: Beaupré
# LOCATION: Deschambault
# CLOSEST POPULATION CENTRE: Portneuf
# LOCATION: Sherbrooke
# CLOSEST POPULATION CENTRE: Sherbrooke
# LOCATION: St-Raymond
# CLOSEST POPULATION CENTRE: Saint-Raymond
# LOCATION: Longueuil
# CLOSEST POPULATION CENTRE: Mercier–Hochelaga-Maisonneuve
# LOCATION: Drummondville
# CLOSEST POPULATION CENTRE: Drummondville
# LOCATION: Charlesbourg
# CLOSEST POPULATION CENTRE: Charlesbourg
# LOCATION: Terrebonne
# CLOSEST POPULATION CENTRE: Filion
# LOCATION: Berthier-Sur-Mer
# CLOSEST POPULATION CENTRE: Saint-Raphaël
# LOCATION: St-Jean-sur-Richelieu
# CLOSEST POPULATION CENTRE: Saint-Jean-sur-Richelieu
# LOCATION: Lévis
# CLOSEST POPULATION CENTRE: La Cité-Limoilou
# LOCATION: Repentigny
# CLOSEST POPULATION CENTRE: Varennes
# LOCATION: Ste-Foy
# CLOSEST POPULATION CENTRE: Sainte-Foy-Sillery-Cap-Rouge
# LOCATION: Chicoutimi
# CLOSEST POPULATION CENTRE: Chicoutimi
# LOCATION: Jonquière
# CLOSEST POPULATION CENTRE: Chicoutimi
# LOCATION: Granby
# CLOSEST POPULATION CENTRE: Granby
# LOCATION: St-Nicolas
# CLOSEST POPULATION CENTRE: Sainte-Foy-Sillery-Cap-Rouge
# LOCATION: St-Jérôme
# CLOSEST POPULATION CENTRE: Saint-Jérôme
# LOCATION: Chambly
# CLOSEST POPULATION CENTRE: Marieville
# LOCATION: Blainville
# CLOSEST POPULATION CENTRE: Alençon
# LOCATION: Boucherville
# CLOSEST POPULATION CENTRE: Mercier–Hochelaga-Maisonneuve
# LOCATION: Mirabel
# CLOSEST POPULATION CENTRE: Saint-Canut
# LOCATION: Val-Bélair
# CLOSEST POPULATION CENTRE: La Haute-Saint-Charles
# LOCATION: Rimouski
# CLOSEST POPULATION CENTRE: Rimouski
# LOCATION: Ste-Julie
# CLOSEST POPULATION CENTRE: Saint-Amable
# LOCATION: Neufchatel
# CLOSEST POPULATION CENTRE: Les Rivières
# LOCATION: Mascouche
# CLOSEST POPULATION CENTRE: Saint-François
# LOCATION: Victoriaville
# CLOSEST POPULATION CENTRE: Victoriaville
# LOCATION: Brossard
# CLOSEST POPULATION CENTRE: Verdun
# LOCATION: St-Jean-Chrysostome
# CLOSEST POPULATION CENTRE: Saint-Henri-de-Lévis
# LOCATION: Magog
# CLOSEST POPULATION CENTRE: Magog
# LOCATION: St-Eustache
# CLOSEST POPULATION CENTRE: Laval-Ouest
# LOCATION: St-Émile
# CLOSEST POPULATION CENTRE: Les Rivières
# LOCATION: Ste-Rose
# CLOSEST POPULATION CENTRE: Sainte-Rose
# LOCATION: St-Augustin-De-Desmaures
# CLOSEST POPULATION CENTRE: Sainte-Foy-Sillery-Cap-Rouge
# LOCATION: Shawinigan
# CLOSEST POPULATION CENTRE: Shawinigan
# LOCATION: St-Bruno-De-Montarville
# CLOSEST POPULATION CENTRE: Beloeil
# LOCATION: Varennes
# CLOSEST POPULATION CENTRE: Varennes
# LOCATION: St-Hyacinthe
# CLOSEST POPULATION CENTRE: Saint-Hyacinthe
# LOCATION: St-Georges
# CLOSEST POPULATION CENTRE: Saint-Georges
# LOCATION: Beloeil
# CLOSEST POPULATION CENTRE: Beloeil
# LOCATION: La Prairie
# CLOSEST POPULATION CENTRE: Verdun
# LOCATION: Cap-Rouge
# CLOSEST POPULATION CENTRE: Sainte-Foy-Sillery-Cap-Rouge
# LOCATION: Mont-St-Hilaire
# CLOSEST POPULATION CENTRE: Beloeil
# LOCATION: Lebourgneuf
# CLOSEST POPULATION CENTRE: Les Rivières
# LOCATION: L'Ancienne-Lorette
# CLOSEST POPULATION CENTRE: Sainte-Foy-Sillery-Cap-Rouge
# LOCATION: L'Assomption
# CLOSEST POPULATION CENTRE: L'Assomption
# LOCATION: Candiac
# CLOSEST POPULATION CENTRE: Verdun
# LOCATION: St-Constant
# CLOSEST POPULATION CENTRE: LaSalle
# LOCATION: Chateauguay
# CLOSEST POPULATION CENTRE: Châteauguay
# LOCATION: Vaudreuil-Dorion
# CLOSEST POPULATION CENTRE: Oka
# LOCATION: St-Étienne-De-Lauzon
# CLOSEST POPULATION CENTRE: Ville Lambert
# LOCATION: Bromont
# CLOSEST POPULATION CENTRE: Bromont
# LOCATION: Pointe-Aux-Trembles
# CLOSEST POPULATION CENTRE: Rivière-des-Prairies–Pointe-aux-Trembles
# LOCATION: Sorel-Tracy
# CLOSEST POPULATION CENTRE: Sorel
# LOCATION: Boisbriand
# CLOSEST POPULATION CENTRE: Fabreville
# LOCATION: Ste-Marie
# CLOSEST POPULATION CENTRE: Sainte-Marie
# LOCATION: Val-Des-Monts
# CLOSEST POPULATION CENTRE: Gatineau
# LOCATION: St-Colomban
# CLOSEST POPULATION CENTRE: Saint-Canut
# LOCATION: St-Rédempteur
# CLOSEST POPULATION CENTRE: Sainte-Foy-Sillery-Cap-Rouge
# LOCATION: St-Basile-Le-Grand
# CLOSEST POPULATION CENTRE: Beloeil
# LOCATION: St-Romuald
# CLOSEST POPULATION CENTRE: La Cité-Limoilou
# LOCATION: Ste-Dorothée
# CLOSEST POPULATION CENTRE: Sainte-Dorothée
# LOCATION: Breakeyville
# CLOSEST POPULATION CENTRE: Saint-Henri-de-Lévis
# LOCATION: Ste-Catherine
# CLOSEST POPULATION CENTRE: LaSalle
# LOCATION: Chomedey
# CLOSEST POPULATION CENTRE: Chomedey
# LOCATION: Marieville
# CLOSEST POPULATION CENTRE: Marieville
# LOCATION: Deux-Montagnes
# CLOSEST POPULATION CENTRE: Laval-sur-le-Lac
# LOCATION: Cantley
# CLOSEST POPULATION CENTRE: Gatineau
# LOCATION: Ahuntsic
# CLOSEST POPULATION CENTRE: Pont-Viau
# LOCATION: Duberger
# CLOSEST POPULATION CENTRE: Les Rivières
# LOCATION: Auteuil
# CLOSEST POPULATION CENTRE: Auteuil
# LOCATION: Pont-Rouge
# CLOSEST POPULATION CENTRE: Pont-Rouge
# LOCATION: Rosemont
# CLOSEST POPULATION CENTRE: Outremont
# LOCATION: Bécancour
# CLOSEST POPULATION CENTRE: Godefroy
# LOCATION: Orford
# CLOSEST POPULATION CENTRE: Magog
# LOCATION: Salaberry-De-Valleyfield
# CLOSEST POPULATION CENTRE: Salaberry-de-Valleyfield
# LOCATION: Ste-Adèle
# CLOSEST POPULATION CENTRE: Sainte-Adèle
# LOCATION: Prévost
# CLOSEST POPULATION CENTRE: Prévost
# LOCATION: Vimont
# CLOSEST POPULATION CENTRE: Vimont
# LOCATION: Ste-Sophie
# CLOSEST POPULATION CENTRE: Sainte-Anne-des-Plaines
# LOCATION: Lac-St-Charles
# CLOSEST POPULATION CENTRE: La Haute-Saint-Charles
# LOCATION: St-Lambert
# CLOSEST POPULATION CENTRE: La Sarre
# LOCATION: Loretteville
# CLOSEST POPULATION CENTRE: Les Rivières
# LOCATION: Charny
# CLOSEST POPULATION CENTRE: Sainte-Foy-Sillery-Cap-Rouge
# LOCATION: Ste-Catherine-de-la-JC
# UNKNOWN LOCATION: Ste-Catherine-de-la-JC
# LOCATION: Carignan
# CLOSEST POPULATION CENTRE: Saint-Vincent-de-Paul
# LOCATION: Saint-Laurent
# CLOSEST POPULATION CENTRE: Saint-Laurent
# LOCATION: Duvernay
# CLOSEST POPULATION CENTRE: Duvernay
# LOCATION: Pierrefonds
# CLOSEST POPULATION CENTRE: Pierrefonds-Roxboro
# LOCATION: Rivière des Prairies
# CLOSEST POPULATION CENTRE: Laval-des-Rapides
# LOCATION: Sillery
# CLOSEST POPULATION CENTRE: La Cité-Limoilou
# LOCATION: Lac-Beauport
# CLOSEST POPULATION CENTRE: Charlesbourg
# LOCATION: La Baie
# CLOSEST POPULATION CENTRE: Chicoutimi
# LOCATION: Pintendre
# CLOSEST POPULATION CENTRE: La Cité-Limoilou
# LOCATION: St-Hippolyte
# CLOSEST POPULATION CENTRE: Lac-Connelly
# LOCATION: Shefford
# CLOSEST POPULATION CENTRE: Waterloo
# LOCATION: St-Lin-Laurentides
# CLOSEST POPULATION CENTRE: Saint-Lin–Laurentides
# LOCATION: Rosemère
# CLOSEST POPULATION CENTRE: Sainte-Rose
# LOCATION: St-Sauveur
# CLOSEST POPULATION CENTRE: Saint-Sauveur-des-Monts
# LOCATION: Ste-Therese
# CLOSEST POPULATION CENTRE: Sainte-Rose
# LOCATION: Lachine
# CLOSEST POPULATION CENTRE: Lachine
# LOCATION: Donnacona
# CLOSEST POPULATION CENTRE: Donnacona
# LOCATION: Otterburn Park
# CLOSEST POPULATION CENTRE: Beloeil
# LOCATION: Contrecoeur
# CLOSEST POPULATION CENTRE: Contrecoeur
# LOCATION: St-Amable
# CLOSEST POPULATION CENTRE: Saint-Amable
# LOCATION: Lavaltrie
# CLOSEST POPULATION CENTRE: Lavaltrie
# LOCATION: Joliette
# CLOSEST POPULATION CENTRE: Joliette
# LOCATION: Lorraine
# CLOSEST POPULATION CENTRE: Filion
# LOCATION: Laval-des-Rapides
# CLOSEST POPULATION CENTRE: Laval-des-Rapides
# LOCATION: St-Lambert-De-Lauzon
# CLOSEST POPULATION CENTRE: Ville Lambert
# LOCATION: Les Saules
# CLOSEST POPULATION CENTRE: Sainte-Foy-Sillery-Cap-Rouge
# LOCATION: St-Charles-Borromée
# CLOSEST POPULATION CENTRE: Joliette
# LOCATION: St-François
# CLOSEST POPULATION CENTRE: Saint-François
# LOCATION: St-Henri-de-Lévis
# CLOSEST POPULATION CENTRE: Saint-Henri-de-Lévis
# LOCATION: St-Lazare
# CLOSEST POPULATION CENTRE: Hudson
# LOCATION: Boischatel
# CLOSEST POPULATION CENTRE: L'Ange-Gardien
# LOCATION: Cowansville
# CLOSEST POPULATION CENTRE: Cowansville
# LOCATION: Rivière-Du-Loup
# CLOSEST POPULATION CENTRE: Rivière-du-Loup
# LOCATION: ND-Des-Prairies
# UNKNOWN LOCATION: ND-Des-Prairies
# LOCATION: Chelsea
# CLOSEST POPULATION CENTRE: Gatineau
# LOCATION: Rawdon
# CLOSEST POPULATION CENTRE: Rawdon
# LOCATION: Delson
# CLOSEST POPULATION CENTRE: LaSalle
# LOCATION: L'île-Bizard
# CLOSEST POPULATION CENTRE: Pierrefonds-Roxboro
# LOCATION: St-Apollinaire
# CLOSEST POPULATION CENTRE: Saint-Apollinaire
# LOCATION: Nicolet
# CLOSEST POPULATION CENTRE: Nicolet
# LOCATION: Limoilou
# CLOSEST POPULATION CENTRE: La Cité-Limoilou
# LOCATION: Pincourt
# CLOSEST POPULATION CENTRE: Melocheville
# LOCATION: Pointe-Claire
# CLOSEST POPULATION CENTRE: Pierrefonds-Roxboro
# LOCATION: Anjou
# CLOSEST POPULATION CENTRE: Anjou
# LOCATION: Ste-Julienne
# CLOSEST POPULATION CENTRE: Sainte-Julienne
# LOCATION: Ste-Brigitte-De-Laval
# CLOSEST POPULATION CENTRE: Sainte-Brigitte-de-Laval
# LOCATION: Bois-Des-Filion
# CLOSEST POPULATION CENTRE: Filion
# LOCATION: Ste-Anne-Des-Plaines
# CLOSEST POPULATION CENTRE: Sainte-Anne-des-Plaines
# LOCATION: Montchatel
# CLOSEST POPULATION CENTRE: La Haute-Saint-Charles
# LOCATION: Laval-Ouest
# CLOSEST POPULATION CENTRE: Laval-Ouest
# LOCATION: Montréal-Nord
# CLOSEST POPULATION CENTRE: Montréal-Nord
# LOCATION: Neuville
# CLOSEST POPULATION CENTRE: Neuville
# LOCATION: L'Ange-Gardien-Outaouais
# CLOSEST POPULATION CENTRE: Angers
# LOCATION: Ste-Agathe-Des-Monts
# CLOSEST POPULATION CENTRE: Sainte-Agathe-des-Monts
# LOCATION: Dollard-Des-Ormeaux
# CLOSEST POPULATION CENTRE: Pierrefonds-Roxboro
# LOCATION: St-Félicien
# CLOSEST POPULATION CENTRE: Saint-Félicien
# LOCATION: Côte-des-Neiges
# CLOSEST POPULATION CENTRE: Outremont
# LOCATION: Baie-Comeau
# CLOSEST POPULATION CENTRE: Baie-Comeau
# LOCATION: St-Honore-De-Chicoutimi
# CLOSEST POPULATION CENTRE: Saint-Honoré
# LOCATION: Thetford Mines
# CLOSEST POPULATION CENTRE: Thetford Mines
# LOCATION: Val-David
# CLOSEST POPULATION CENTRE: Sainte-Agathe-des-Monts
# LOCATION: Roberval
# CLOSEST POPULATION CENTRE: Roberval
# LOCATION: Montmagny
# CLOSEST POPULATION CENTRE: Montmagny
# LOCATION: La Malbaie
# CLOSEST POPULATION CENTRE: La Malbaie
# LOCATION: Villeray
# CLOSEST POPULATION CENTRE: Villeray–Saint-Michel–Parc-Extension
# LOCATION: Le Sud-Ouest
# CLOSEST POPULATION CENTRE: Le Sud-Ouest
# LOCATION: St-Rémi
# CLOSEST POPULATION CENTRE: Saint-Rémi
# LOCATION: McMasterville
# CLOSEST POPULATION CENTRE: Beloeil
# LOCATION: Richelieu
# CLOSEST POPULATION CENTRE: Marieville
# LOCATION: Dolbeau-Mistassini
# CLOSEST POPULATION CENTRE: Dolbeau
# LOCATION: Shannon
# CLOSEST POPULATION CENTRE: Shannon
# LOCATION: La Pêche
# CLOSEST POPULATION CENTRE: Shawville
# LOCATION: St-Paul
# CLOSEST POPULATION CENTRE: Crabtree
# LOCATION: St-Cyrille-De-Wendover
# CLOSEST POPULATION CENTRE: Saint-Cyrille-de-Wendover
# LOCATION: St-Zotique
# CLOSEST POPULATION CENTRE: Les Coteaux
# LOCATION: Ile d'Orléans
# CLOSEST POPULATION CENTRE: Château-Richer
# LOCATION: St-Adolphe-D'Howard
# CLOSEST POPULATION CENTRE: Sainte-Agathe-des-Monts
# LOCATION: St-Vincent-de-Paul
# CLOSEST POPULATION CENTRE: Montréal-Nord
# LOCATION: Beauharnois
# CLOSEST POPULATION CENTRE: Melocheville
# LOCATION: Le Plateau-Mont-Royal
# CLOSEST POPULATION CENTRE: Le Plateau-Mont-Royal
# LOCATION: Verchères
# CLOSEST POPULATION CENTRE: Verchères
# LOCATION: St-Anselme
# CLOSEST POPULATION CENTRE: Saint-Anselme
# LOCATION: ND-De-L'Ile-Perrot
# UNKNOWN LOCATION: ND-De-L'Ile-Perrot
# LOCATION: Farnham
# CLOSEST POPULATION CENTRE: Farnham
# LOCATION: Mont-Tremblant
# CLOSEST POPULATION CENTRE: Saint-Jovite
# LOCATION: St-Cesaire
# CLOSEST POPULATION CENTRE: Saint-Césaire
# LOCATION: Matane
# CLOSEST POPULATION CENTRE: Matane
# LOCATION: Château-Richer
# CLOSEST POPULATION CENTRE: Château-Richer
# LOCATION: L'Épiphanie
# CLOSEST POPULATION CENTRE: L'Épiphanie
# LOCATION: Lachute
# CLOSEST POPULATION CENTRE: Lachute
# LOCATION: St-Joseph-Du-Lac
# CLOSEST POPULATION CENTRE: L'Île-Bizard–Sainte-Geneviève
# LOCATION: Baie-St-Paul
# CLOSEST POPULATION CENTRE: Baie-Saint-Paul
# LOCATION: Beaupré
# CLOSEST POPULATION CENTRE: Beaupré
# LOCATION: St-Agapit
# CLOSEST POPULATION CENTRE: Saint-Agapit
# LOCATION: St-Denis-De-Brompton
# CLOSEST POPULATION CENTRE: Bromptonville
# LOCATION: St-Philippe
# CLOSEST POPULATION CENTRE: Verdun
# LOCATION: Eastman
# CLOSEST POPULATION CENTRE: Magog
# LOCATION: St-Faustin-Lac-Carré
# CLOSEST POPULATION CENTRE: Saint-Jovite
# LOCATION: Sutton
# CLOSEST POPULATION CENTRE: Cowansville
# LOCATION: L'Ile-Perrot
# CLOSEST POPULATION CENTRE: Melocheville
# LOCATION: ND-Du-Mont-Carmel
# UNKNOWN LOCATION: ND-Du-Mont-Carmel
# LOCATION: Les Côteaux
# CLOSEST POPULATION CENTRE: Les Coteaux
# LOCATION: L'Ile Des Soeurs
# UNKNOWN LOCATION: L'Ile Des Soeurs
# LOCATION: St-Mathias-sur-Richelieu
# CLOSEST POPULATION CENTRE: Marieville
# LOCATION: Chertsey
# CLOSEST POPULATION CENTRE: Rawdon
# LOCATION: Pointe-Calumet
# CLOSEST POPULATION CENTRE: L'Île-Bizard–Sainte-Geneviève
# LOCATION: Val-des-Sources
# CLOSEST POPULATION CENTRE: Val-des-Sources
# LOCATION: Sept-Iles
# CLOSEST POPULATION CENTRE: Sept-Îles
# LOCATION: LaSalle
# CLOSEST POPULATION CENTRE: LaSalle
# LOCATION: Gaspé
# CLOSEST POPULATION CENTRE: Gaspé
# LOCATION: Morin-Heights
# CLOSEST POPULATION CENTRE: Saint-Sauveur-des-Monts
# LOCATION: Pont-Viau
# CLOSEST POPULATION CENTRE: Pont-Viau
# LOCATION: Mont-Laurier
# CLOSEST POPULATION CENTRE: Mont-Laurier
# LOCATION: Fossambault-Sur-Le-Lac
# CLOSEST POPULATION CENTRE: Fossambault-sur-le-Lac
# LOCATION: Vanier
# CLOSEST POPULATION CENTRE: La Cité-Limoilou
# LOCATION: Piedmont
# CLOSEST POPULATION CENTRE: Saint-Sauveur-des-Monts
# LOCATION: St-Germain-De-Grantham
# CLOSEST POPULATION CENTRE: Saint-Germain-de-Grantham
# LOCATION: Waterloo
# CLOSEST POPULATION CENTRE: Waterloo
# LOCATION: Napierville
# CLOSEST POPULATION CENTRE: Napierville
# LOCATION: L'Ange-Gardien
# CLOSEST POPULATION CENTRE: L'Ange-Gardien
# LOCATION: Les Cèdres
# CLOSEST POPULATION CENTRE: Les Cèdres
# LOCATION: Roxton Pond
# CLOSEST POPULATION CENTRE: Roxton Pond
# LOCATION: Ascot Corner
# CLOSEST POPULATION CENTRE: East Angus
# LOCATION: St-David-de-Falardeau
# CLOSEST POPULATION CENTRE: Saint-Honoré
# LOCATION: Cap-Santé
# CLOSEST POPULATION CENTRE: Donnacona
# LOCATION: Beauceville
# CLOSEST POPULATION CENTRE: Beauceville
# LOCATION: Saint-Sacrement
# CLOSEST POPULATION CENTRE: La Cité-Limoilou
# LOCATION: Lac-Mégantic
# CLOSEST POPULATION CENTRE: Lac-Mégantic
# LOCATION: Mont-Joli
# CLOSEST POPULATION CENTRE: Mont-Joli
# LOCATION: Louiseville
# CLOSEST POPULATION CENTRE: Louiseville
# LOCATION: St-Charles-De-Bellechasse
# CLOSEST POPULATION CENTRE: Beaumont
# LOCATION: Plessisville
# CLOSEST POPULATION CENTRE: Plessisville
# LOCATION: Scott
# CLOSEST POPULATION CENTRE: Saint-Bernard
# LOCATION: Windsor
# CLOSEST POPULATION CENTRE: Windsor
# LOCATION: St-Ambroise
# CLOSEST POPULATION CENTRE: Saint-Ambroise
# LOCATION: Portneuf
# CLOSEST POPULATION CENTRE: Portneuf
# LOCATION: Saint-Sauveur
# CLOSEST POPULATION CENTRE: Saint-Sauveur-des-Monts
# LOCATION: Rivière-Rouge
# CLOSEST POPULATION CENTRE: Labelle
# LOCATION: Lac-Etchemin
# CLOSEST POPULATION CENTRE: Lac-Etchemin
# LOCATION: Coteau-Du-Lac
# CLOSEST POPULATION CENTRE: Les Coteaux
# LOCATION: St-Donat
# CLOSEST POPULATION CENTRE: Saint-Donat-de-Montcalm
# LOCATION: Acton Vale
# CLOSEST POPULATION CENTRE: Acton Vale
# LOCATION: Ste-Anne-Des-Lacs
# CLOSEST POPULATION CENTRE: Prévost
# LOCATION: St-Bruno
# CLOSEST POPULATION CENTRE: Saint-Bruno
# LOCATION: St-Jean-De-Matha
# CLOSEST POPULATION CENTRE: Saint-Félix-de-Valois
# LOCATION: St-Côme
# CLOSEST POPULATION CENTRE: Rawdon
# LOCATION: St-Boniface
# CLOSEST POPULATION CENTRE: Saint-Boniface
# LOCATION: Beaumont
# CLOSEST POPULATION CENTRE: Beaumont
# LOCATION: Verdun
# CLOSEST POPULATION CENTRE: Verdun
# LOCATION: Ste-Claire
# CLOSEST POPULATION CENTRE: Sainte-Claire
# LOCATION: Beaconsfield
# CLOSEST POPULATION CENTRE: Pierrefonds-Roxboro
# LOCATION: Dunham
# CLOSEST POPULATION CENTRE: Cowansville
# LOCATION: Kirkland
# CLOSEST POPULATION CENTRE: Pierrefonds-Roxboro
# LOCATION: St-Isidore
# CLOSEST POPULATION CENTRE: Saint-Henri-de-Lévis
# LOCATION: St-Elzéar-de-Beauce
# CLOSEST POPULATION CENTRE: Saint-Bernard
# LOCATION: St-Étienne-Des-Gres
# CLOSEST POPULATION CENTRE: Saint-Boniface
# LOCATION: Val-Morin
# CLOSEST POPULATION CENTRE: Sainte-Adèle
# LOCATION: Coaticook
# CLOSEST POPULATION CENTRE: Coaticook
# LOCATION: St-Félix-De-Valois
# CLOSEST POPULATION CENTRE: Saint-Félix-de-Valois
# LOCATION: St-Pie
# CLOSEST POPULATION CENTRE: Saint-Pie
# LOCATION: Ste-Catherine-De-Hatley
# CLOSEST POPULATION CENTRE: Magog
# LOCATION: Princeville
# CLOSEST POPULATION CENTRE: Princeville
# LOCATION: St-Mathieu-De-Beloeil
# CLOSEST POPULATION CENTRE: Beloeil
# LOCATION: Berthierville
# CLOSEST POPULATION CENTRE: Berthierville
# LOCATION: Rouyn-Noranda
# CLOSEST POPULATION CENTRE: Rouyn-Noranda
# LOCATION: Oka
# CLOSEST POPULATION CENTRE: Oka
# LOCATION: Ste-Marguerite-Du-Lac-Masson
# CLOSEST POPULATION CENTRE: Sainte-Adèle
# LOCATION: St-Calixte
# CLOSEST POPULATION CENTRE: Lac-Lapierre
# LOCATION: St-Gilles
# CLOSEST POPULATION CENTRE: Saint-Agapit
# LOCATION: Montcalm
# CLOSEST POPULATION CENTRE: Sainte-Agathe-des-Monts
# LOCATION: Rigaud
# CLOSEST POPULATION CENTRE: Rigaud
# LOCATION: Lac-Brome
# CLOSEST POPULATION CENTRE: Bromont
# LOCATION: Dorval
# CLOSEST POPULATION CENTRE: Saint-Charles
# LOCATION: Ville-Marie
# CLOSEST POPULATION CENTRE: Ville-Marie
# LOCATION: St-Maurice
# CLOSEST POPULATION CENTRE: Notre-Dame-du-Mont-Carmel
# LOCATION: Mont-Royal
# CLOSEST POPULATION CENTRE: Le Plateau-Mont-Royal
# LOCATION: St-Michel
# CLOSEST POPULATION CENTRE: Saint-Michel
# LOCATION: Austin
# CLOSEST POPULATION CENTRE: Magog
# LOCATION: Hébertville
# CLOSEST POPULATION CENTRE: Hébertville
# LOCATION: Venise-En-Quebec
# CLOSEST POPULATION CENTRE: Bedford
# LOCATION: Ste-Croix
# CLOSEST POPULATION CENTRE: Sainte-Croix
# LOCATION: Métabetchouan-Lac-à-la-Croix
# CLOSEST POPULATION CENTRE: Métabetchouan
# LOCATION: Champlain
# CLOSEST POPULATION CENTRE: Gentilly
# LOCATION: St-Sulpice
# CLOSEST POPULATION CENTRE: Saint-Sulpice
# LOCATION: Ste-Luce
# CLOSEST POPULATION CENTRE: Luceville
# LOCATION: St-André-Avellin
# CLOSEST POPULATION CENTRE: Saint-André-Avellin
# LOCATION: St-Ambroise-De-Kildare
# CLOSEST POPULATION CENTRE: Saint-Ambroise-de-Kildare
# LOCATION: St-Jacques
# CLOSEST POPULATION CENTRE: Saint-Jacques
# LOCATION: St-Joseph-De-Beauce
# CLOSEST POPULATION CENTRE: Saint-Joseph-de-Beauce
# LOCATION: Duvernay-Est
# CLOSEST POPULATION CENTRE: Duvernay
# LOCATION: St-Damien
# CLOSEST POPULATION CENTRE: Saint-Gabriel
# LOCATION: Luskville
# CLOSEST POPULATION CENTRE: Gatineau
# LOCATION: St-Anaclet-De-Lessard
# CLOSEST POPULATION CENTRE: Luceville
# LOCATION: St-Antoine-De-Tilly
# CLOSEST POPULATION CENTRE: Saint-Apollinaire
# LOCATION: St-Gabriel-De-Brandon
# CLOSEST POPULATION CENTRE: Saint-Gabriel
# LOCATION: Lanoraie
# CLOSEST POPULATION CENTRE: Saint-Joseph-de-Lanoraie
# LOCATION: St-Basile-De-Portneuf
# CLOSEST POPULATION CENTRE: Saint-Basile-Sud
# LOCATION: St-Bernard
# CLOSEST POPULATION CENTRE: Saint-Bernard
# LOCATION: Notre-Dame-des-Pins
# CLOSEST POPULATION CENTRE: Beauceville
# LOCATION: East Angus
# CLOSEST POPULATION CENTRE: East Angus
# LOCATION: St-Alphonse-Rodriguez
# CLOSEST POPULATION CENTRE: Rawdon
# LOCATION: Ste-Martine
# CLOSEST POPULATION CENTRE: Sainte-Martine
# LOCATION: L'Islet
# CLOSEST POPULATION CENTRE: Cap-Saint-Ignace
# LOCATION: St-Mathieu-De-Laprairie
# UNKNOWN LOCATION: St-Mathieu-De-Laprairie
# LOCATION: St-Roch-De-Richelieu
# CLOSEST POPULATION CENTRE: Contrecoeur
# LOCATION: St-Marc-sur-Richelieu
# CLOSEST POPULATION CENTRE: Saint-Amable
# LOCATION: Carleton-sur-Mer
# CLOSEST POPULATION CENTRE: Carleton
# LOCATION: St-Roch-De-L'Achigan
# CLOSEST POPULATION CENTRE: Saint-Roch-de-l'Achigan
# LOCATION: St-Malachie
# CLOSEST POPULATION CENTRE: Sainte-Claire
# LOCATION: ND-Du-Bon-Conseil
# UNKNOWN LOCATION: ND-Du-Bon-Conseil
# LOCATION: St-Gabriel-De-Valcartier
# CLOSEST POPULATION CENTRE: Shannon
# LOCATION: St-Jean-Port-Joli
# CLOSEST POPULATION CENTRE: Saint-Jean-Port-Joli
# LOCATION: St-Jean-Baptiste
# CLOSEST POPULATION CENTRE: Saint-Jean-Baptiste
# LOCATION: St-Mathieu-Du-Parc
# CLOSEST POPULATION CENTRE: Domaine-Ouellet
# LOCATION: Thurso
# CLOSEST POPULATION CENTRE: Thurso
# LOCATION: Valcourt
# CLOSEST POPULATION CENTRE: Valcourt
# LOCATION: St-Alexandre-D'Iberville
# CLOSEST POPULATION CENTRE: Saint-Alexandre
# LOCATION: Port-Cartier
# CLOSEST POPULATION CENTRE: Port-Cartier
# LOCATION: Ste-Thecle
# CLOSEST POPULATION CENTRE: Sainte-Thècle
# LOCATION: Mont-St-Gregoire
# CLOSEST POPULATION CENTRE: Saint-Jean-sur-Richelieu
# LOCATION: Brownsburg-Chatham
# CLOSEST POPULATION CENTRE: Brownsburg
# LOCATION: St-Alphonse-de-Granby
# CLOSEST POPULATION CENTRE: Granby
# LOCATION: Nominingue
# CLOSEST POPULATION CENTRE: Laurentides
# LOCATION: Cookshire-Eaton
# CLOSEST POPULATION CENTRE: Cookshire
# LOCATION: Ste-Madeleine
# CLOSEST POPULATION CENTRE: Sainte-Madeleine
# LOCATION: St-Prime
# CLOSEST POPULATION CENTRE: Saint-Prime
# LOCATION: St-Tite
# CLOSEST POPULATION CENTRE: Saint-Tite
# LOCATION: Ste-Mélanie
# CLOSEST POPULATION CENTRE: Saint-Ambroise-de-Kildare
# LOCATION: Stoke
# CLOSEST POPULATION CENTRE: Bromptonville
# LOCATION: St-Léonard-D'Aston
# CLOSEST POPULATION CENTRE: Saint-Léonard-d'Aston
# LOCATION: La Pocatiere
# CLOSEST POPULATION CENTRE: La Pocatière
# LOCATION: St-Alexis-Des-Monts
# CLOSEST POPULATION CENTRE: Saint-Alexis-des-Monts
# LOCATION: ND-Du-Laus
# UNKNOWN LOCATION: ND-Du-Laus
# LOCATION: Dudswell
# CLOSEST POPULATION CENTRE: East Angus
# LOCATION: Compton
# CLOSEST POPULATION CENTRE: Coaticook
# LOCATION: Laurier-Station
# CLOSEST POPULATION CENTRE: Laurier-Station
# LOCATION: Weedon
# CLOSEST POPULATION CENTRE: Disraeli
# LOCATION: Saint-Léonard
# CLOSEST POPULATION CENTRE: Saint-Léonard
# LOCATION: Maniwaki
# CLOSEST POPULATION CENTRE: Maniwaki
# LOCATION: St-Antoine-sur-Richelieu
# CLOSEST POPULATION CENTRE: Contrecoeur
# LOCATION: Waterville
# CLOSEST POPULATION CENTRE: Sherbrooke
# LOCATION: St-Liboire
# CLOSEST POPULATION CENTRE: Saint-Liboire
# LOCATION: Wickham
# CLOSEST POPULATION CENTRE: Saint-Germain-de-Grantham
# LOCATION: Ange-Gardien-de-Rouville
# CLOSEST POPULATION CENTRE: Saint-Césaire
# LOCATION: Chambord
# CLOSEST POPULATION CENTRE: Métabetchouan
# LOCATION: Mandeville
# CLOSEST POPULATION CENTRE: Saint-Gabriel
# LOCATION: Yamachiche
# CLOSEST POPULATION CENTRE: Yamachiche
# LOCATION: St-Damien-De-Buckland
# CLOSEST POPULATION CENTRE: Saint-Damien-de-Buckland
# LOCATION: Ste-Cécile-De-Milton
# CLOSEST POPULATION CENTRE: Roxton Pond
# LOCATION: Saint-Gédéon
# CLOSEST POPULATION CENTRE: Saint-Gédéon
# LOCATION: Lac-Superieur
# CLOSEST POPULATION CENTRE: Labelle
# LOCATION: Warwick
# CLOSEST POPULATION CENTRE: Warwick
# LOCATION: Témiscouata-sur-le-Lac
# CLOSEST POPULATION CENTRE: Cabano
# LOCATION: Danville
# CLOSEST POPULATION CENTRE: Danville
# LOCATION: Richmond
# CLOSEST POPULATION CENTRE: Richmond
# LOCATION: Amqui
# CLOSEST POPULATION CENTRE: Amqui
# LOCATION: Lac-Delage
# CLOSEST POPULATION CENTRE: Stoneham
# LOCATION: St-Prosper-De-Dorchester
# CLOSEST POPULATION CENTRE: Saint-Prosper
# LOCATION: Degelis
# CLOSEST POPULATION CENTRE: Dégelis
# LOCATION: St-Christophe-D'Arthabaska
# CLOSEST POPULATION CENTRE: Victoriaville
# LOCATION: St-Gervais
# CLOSEST POPULATION CENTRE: Saint-Anselme
# LOCATION: Lacolle
# CLOSEST POPULATION CENTRE: Lacolle
# LOCATION: Charlemagne
# CLOSEST POPULATION CENTRE: Varennes
# LOCATION: Ste-Anne-De-Sorel
# CLOSEST POPULATION CENTRE: Sorel
# LOCATION: Brigham
# CLOSEST POPULATION CENTRE: Cowansville
# LOCATION: St-Isidore-De-Laprairie
# UNKNOWN LOCATION: St-Isidore-De-Laprairie
# LOCATION: St-Pierre-Les-Becquets
# CLOSEST POPULATION CENTRE: Gentilly
# LOCATION: Stukely-Sud
# CLOSEST POPULATION CENTRE: Waterloo
# LOCATION: Crabtree
# CLOSEST POPULATION CENTRE: Crabtree
# LOCATION: St-Fulgence
# CLOSEST POPULATION CENTRE: Bagotville
# LOCATION: Rougemont
# CLOSEST POPULATION CENTRE: Rougemont
# LOCATION: Potton
# CLOSEST POPULATION CENTRE: Stanstead
# LOCATION: St-François-Xavier-De-Brompton
# CLOSEST POPULATION CENTRE: Windsor
# LOCATION: La Presentation
# CLOSEST POPULATION CENTRE: Sainte-Madeleine
# LOCATION: Ste-Beatrix
# CLOSEST POPULATION CENTRE: Saint-Ambroise-de-Kildare
# LOCATION: Papineauville
# CLOSEST POPULATION CENTRE: Papineauville
# LOCATION: St-Lucien
# CLOSEST POPULATION CENTRE: Saint-Cyrille-de-Wendover
# LOCATION: Côte-St-Luc
# CLOSEST POPULATION CENTRE: Côte-des-Neiges–Notre-Dame-de-Grâce
# LOCATION: St-Elie-de-Caxton
# CLOSEST POPULATION CENTRE: Domaine-Ouellet
# LOCATION: St-Michel-de-Bellechasse
# CLOSEST POPULATION CENTRE: Saint-Michel-de-Bellechasse
# LOCATION: St-Jacques-Le-Mineur
# CLOSEST POPULATION CENTRE: Napierville
# LOCATION: Wentworth-Nord
# CLOSEST POPULATION CENTRE: Brownsburg
# LOCATION: L'Anse-St-Jean
# CLOSEST POPULATION CENTRE: Bagotville
# LOCATION: St-Denis-sur-Richelieu
# CLOSEST POPULATION CENTRE: Contrecoeur
# LOCATION: Stratford
# CLOSEST POPULATION CENTRE: Disraeli
# LOCATION: Bolton-Est
# CLOSEST POPULATION CENTRE: Magog
# LOCATION: Outremont
# CLOSEST POPULATION CENTRE: Outremont
# LOCATION: St-Paul-De-L'Ile-Aux-Noix
# CLOSEST POPULATION CENTRE: Lacolle
# LOCATION: Gore
# CLOSEST POPULATION CENTRE: Lachute
# LOCATION: Ste-Angèle-De-Monnoir
# CLOSEST POPULATION CENTRE: Marieville
# LOCATION: St-Côme-Linière
# CLOSEST POPULATION CENTRE: Linière
# LOCATION: St-Victor
# CLOSEST POPULATION CENTRE: Saint-Éphrem-de-Tring
# LOCATION: Entrelacs
# CLOSEST POPULATION CENTRE: Sainte-Adèle
# LOCATION: St-Anicet
# CLOSEST POPULATION CENTRE: Huntingdon
# LOCATION: St-Liguori
# CLOSEST POPULATION CENTRE: Saint-Jacques
# LOCATION: ND-De-Lourdes
# UNKNOWN LOCATION: ND-De-Lourdes
# LOCATION: Val-d'Or
# CLOSEST POPULATION CENTRE: Val-d'Or
# LOCATION: Vallée-Jonction
# CLOSEST POPULATION CENTRE: Vallée-Jonction
# LOCATION: St-Dominique
# CLOSEST POPULATION CENTRE: Saint-Pie
# LOCATION: St-Marc-Des-Carrières
# CLOSEST POPULATION CENTRE: Saint-Marc-des-Carrières
# LOCATION: Trois-Pistoles
# CLOSEST POPULATION CENTRE: Trois-Pistoles
# LOCATION: Cap-St-Ignace
# CLOSEST POPULATION CENTRE: Cap-Saint-Ignace
# LOCATION: Ste-Émélie-De-L'Énergie
# CLOSEST POPULATION CENTRE: Saint-Gabriel
# LOCATION: Disraeli
# CLOSEST POPULATION CENTRE: Disraeli
# LOCATION: St-Charles-sur-Richelieu
# CLOSEST POPULATION CENTRE: Saint-Amable
# LOCATION: St-André-D'Argenteuil
# CLOSEST POPULATION CENTRE: Rigaud
# LOCATION: Rivière-Beaudette
# CLOSEST POPULATION CENTRE: Saint-Polycarpe
# LOCATION: St-Antonin
# CLOSEST POPULATION CENTRE: Rivière-du-Loup
# LOCATION: Larouche
# CLOSEST POPULATION CENTRE: Saint-Bruno
# LOCATION: St-Joachim-De-Shefford
# CLOSEST POPULATION CENTRE: Roxton Pond
# LOCATION: Labelle
# CLOSEST POPULATION CENTRE: Labelle
# LOCATION: St-Michel-Des-Saints
# CLOSEST POPULATION CENTRE: Saint-Michel-des-Saints
# LOCATION: St-Wenceslas
# CLOSEST POPULATION CENTRE: Saint-Léonard-d'Aston
# LOCATION: Ste-Anne-Des-Monts
# CLOSEST POPULATION CENTRE: Sainte-Anne-des-Monts
# LOCATION: St-Ours
# CLOSEST POPULATION CENTRE: Contrecoeur
# LOCATION: Lac-Sergent
# CLOSEST POPULATION CENTRE: Saint-Raymond
# LOCATION: Ste-Marcelline-De-Kildare
# CLOSEST POPULATION CENTRE: Saint-Ambroise-de-Kildare
# LOCATION: St-Paul-D'Abbotsford
# CLOSEST POPULATION CENTRE: Saint-Pie
# LOCATION: Amherst
# CLOSEST POPULATION CENTRE: Saint-Jovite
# LOCATION: Pontiac
# CLOSEST POPULATION CENTRE: Fort-Coulonge
# LOCATION: Batiscan
# CLOSEST POPULATION CENTRE: Gentilly
# LOCATION: L'Ascension-De-Notre-Seigneur
# CLOSEST POPULATION CENTRE: Alma
# LOCATION: St-Ignace-De-Loyola
# CLOSEST POPULATION CENTRE: Sorel
# LOCATION: St-Ferdinand
# CLOSEST POPULATION CENTRE: Black Lake
# LOCATION: Lac-Bouchette
# CLOSEST POPULATION CENTRE: Roberval
# LOCATION: Val-Des-Bois
# CLOSEST POPULATION CENTRE: Lac-Simon
# LOCATION: Hudson
# CLOSEST POPULATION CENTRE: Hudson
# LOCATION: Petite-Rivière-St-François
# CLOSEST POPULATION CENTRE: Baie-Saint-Paul
# LOCATION: Lac-Simon
# CLOSEST POPULATION CENTRE: Lac-Simon
# LOCATION: St-Nérée
# CLOSEST POPULATION CENTRE: Sainte-Foy-Sillery-Cap-Rouge
# LOCATION: Ste-Anne-de-Beaupré
# CLOSEST POPULATION CENTRE: Beaupré
# LOCATION: Kingsey Falls
# CLOSEST POPULATION CENTRE: Kingsey Falls
# LOCATION: Les Éboulements
# CLOSEST POPULATION CENTRE: Baie-Saint-Paul
# LOCATION: Ste-Anne-De-La-Perade
# CLOSEST POPULATION CENTRE: Saint-Marc-des-Carrières
# LOCATION: St-Vallier
# CLOSEST POPULATION CENTRE: Saint-Michel-de-Bellechasse
# LOCATION: Lambton
# CLOSEST POPULATION CENTRE: Disraeli
# LOCATION: La Tuque
# CLOSEST POPULATION CENTRE: La Tuque
# LOCATION: St-Ubalde
# CLOSEST POPULATION CENTRE: Saint-Marc-des-Carrières
# LOCATION: St-Barthelemy
# CLOSEST POPULATION CENTRE: Maskinongé
# LOCATION: St-Thomas
# CLOSEST POPULATION CENTRE: Saint-Thomas
# LOCATION: Ayer's Cliff
# CLOSEST POPULATION CENTRE: Magog
# LOCATION: St-Irenee
# CLOSEST POPULATION CENTRE: La Malbaie
# LOCATION: Québec
# CLOSEST POPULATION CENTRE: La Cité-Limoilou
# LOCATION: St-Léonard-De-Portneuf
# CLOSEST POPULATION CENTRE: Saint-Raymond
# LOCATION: Lery
# CLOSEST POPULATION CENTRE: Châteauguay
# LOCATION: St-Félix-D'Otis
# CLOSEST POPULATION CENTRE: Bagotville
# LOCATION: St-Pascal-De-Kamouraska
# CLOSEST POPULATION CENTRE: Saint-Pascal
# LOCATION: Ste-Hénédine
# CLOSEST POPULATION CENTRE: Saint-Anselme
# LOCATION: La Conception
# CLOSEST POPULATION CENTRE: Saint-Jovite
# LOCATION: St-Polycarpe
# CLOSEST POPULATION CENTRE: Saint-Polycarpe
# LOCATION: Lac-Aux-Sables
# CLOSEST POPULATION CENTRE: Sainte-Thècle
# LOCATION: St-Joseph-De-Coleraine
# CLOSEST POPULATION CENTRE: Disraeli
# LOCATION: St-Damase
# CLOSEST POPULATION CENTRE: Saint-Damase
# LOCATION: St-Alexandre-De-Kamouraska
# CLOSEST POPULATION CENTRE: Rivière-du-Loup
# LOCATION: La Durantaye
# CLOSEST POPULATION CENTRE: Saint-Michel-de-Bellechasse
# LOCATION: Pierreville
# CLOSEST POPULATION CENTRE: Pierreville
# LOCATION: Ripon
# CLOSEST POPULATION CENTRE: Saint-André-Avellin
# LOCATION: Roxton Falls
# CLOSEST POPULATION CENTRE: Roxton Falls
# LOCATION: Percé
# CLOSEST POPULATION CENTRE: Grande-Rivière
# LOCATION: Maskinonge
# CLOSEST POPULATION CENTRE: Maskinongé
# LOCATION: St-Nazaire
# CLOSEST POPULATION CENTRE: Alma
# LOCATION: Clermont
# CLOSEST POPULATION CENTRE: Clermont
# LOCATION: Bury
# CLOSEST POPULATION CENTRE: Cookshire
# LOCATION: Saint-Roch
# CLOSEST POPULATION CENTRE: La Cité-Limoilou
# LOCATION: St-Alban
# CLOSEST POPULATION CENTRE: Saint-Marc-des-Carrières
# LOCATION: Val-Des-Lacs
# CLOSEST POPULATION CENTRE: Sainte-Agathe-des-Monts
# LOCATION: Daveluyville
# CLOSEST POPULATION CENTRE: Daveluyville
# LOCATION: Val-Joli
# CLOSEST POPULATION CENTRE: Windsor
# LOCATION: Ste-Justine
# CLOSEST POPULATION CENTRE: Sainte-Justine
# LOCATION: St-Henri-De-Taillon
# CLOSEST POPULATION CENTRE: Alma
# LOCATION: Ste-Flavie
# CLOSEST POPULATION CENTRE: Mont-Joli
# LOCATION: Ste-Monique
# CLOSEST POPULATION CENTRE: Alma
# LOCATION: Tewkesbury
# CLOSEST POPULATION CENTRE: Stoneham
# LOCATION: Ste-Lucie-Des-Laurentides
# CLOSEST POPULATION CENTRE: Sainte-Agathe-des-Monts
# LOCATION: St-Lazare-De-Bellechasse
# CLOSEST POPULATION CENTRE: Sainte-Claire
# LOCATION: Ste-Marie-Madeleine
# CLOSEST POPULATION CENTRE: Sainte-Madeleine
# LOCATION: Grenville-sur-la-Rouge
# CLOSEST POPULATION CENTRE: Grenville
# LOCATION: Upton
# CLOSEST POPULATION CENTRE: Saint-Liboire
# LOCATION: Canton-de-Hatley
# CLOSEST POPULATION CENTRE: Magog
# LOCATION: Mille-Isles
# CLOSEST POPULATION CENTRE: Saint-Sauveur-des-Monts
# LOCATION: Maria
# CLOSEST POPULATION CENTRE: Maria
# LOCATION: Frampton
# CLOSEST POPULATION CENTRE: Vallée-Jonction
# LOCATION: La Minerve
# CLOSEST POPULATION CENTRE: Labelle
# LOCATION: L'Avenir
# CLOSEST POPULATION CENTRE: Richmond
# LOCATION: St-Paul-De-Montminy
# CLOSEST POPULATION CENTRE: Saint-Damien-de-Buckland
# LOCATION: St-Tite-Des-Caps
# CLOSEST POPULATION CENTRE: Beaupré
# LOCATION: St-Magloire-De-Bellechasse
# UNKNOWN LOCATION: St-Magloire-De-Bellechasse
# LOCATION: Melbourne
# CLOSEST POPULATION CENTRE: Richmond
# LOCATION: Normandin
# CLOSEST POPULATION CENTRE: Normandin
# LOCATION: Armagh
# CLOSEST POPULATION CENTRE: Saint-Raphaël
# LOCATION: Hemmingford
# CLOSEST POPULATION CENTRE: Saint-Chrysostome
# LOCATION: Beaulac Garthby
# CLOSEST POPULATION CENTRE: Disraeli
# LOCATION: Ste-Anne-De-Bellevue
# CLOSEST POPULATION CENTRE: Melocheville
# LOCATION: Canton de Stanstead
# CLOSEST POPULATION CENTRE: Stanstead
# LOCATION: Chibougamau
# CLOSEST POPULATION CENTRE: Chibougamau
# LOCATION: St-Simon-De-Bagot
# CLOSEST POPULATION CENTRE: Saint-Liboire
# LOCATION: St-Pamphile
# CLOSEST POPULATION CENTRE: Saint-Jean-Port-Joli
# LOCATION: Lac-Des-Ecorces
# CLOSEST POPULATION CENTRE: Mont-Laurier
# LOCATION: St-Edouard-De-Napierville
# CLOSEST POPULATION CENTRE: Saint-Michel
# LOCATION: St-Zénon
# CLOSEST POPULATION CENTRE: Saint-Michel-des-Saints
# LOCATION: Chute-St-Philippe
# CLOSEST POPULATION CENTRE: Laurentides
# LOCATION: Ste-Genevieve-De-Batiscan
# CLOSEST POPULATION CENTRE: Gentilly
# LOCATION: Ste-Christine-D'Auvergne
# CLOSEST POPULATION CENTRE: Saint-Basile-Sud
# LOCATION: Hébertville-Station
# CLOSEST POPULATION CENTRE: Saint-Bruno
# LOCATION: St-Chrysostome
# CLOSEST POPULATION CENTRE: Saint-Chrysostome
# LOCATION: St-Léon-Le-Grand
# CLOSEST POPULATION CENTRE: Louiseville
# LOCATION: St-Odilon
# CLOSEST POPULATION CENTRE: Lac-Etchemin
# LOCATION: Sts-Anges
# UNKNOWN LOCATION: Sts-Anges
# LOCATION: St-Roch-Des-Aulnaies
# CLOSEST POPULATION CENTRE: La Pocatière
# LOCATION: Notre-Dame-de-Pontmain
# CLOSEST POPULATION CENTRE: Maniwaki
# LOCATION: Ste-Hélène-De-Bagot
# CLOSEST POPULATION CENTRE: Saint-Liboire
# LOCATION: La Patrie
# CLOSEST POPULATION CENTRE: Cookshire
# LOCATION: Ste-Brigide-D'Iberville
# CLOSEST POPULATION CENTRE: Farnham
# LOCATION: Lotbinière
# CLOSEST POPULATION CENTRE: Portneuf
# LOCATION: Ste-Clotilde-De-Chateauguay
# CLOSEST POPULATION CENTRE: Saint-Chrysostome
# LOCATION: Sabrevois
# CLOSEST POPULATION CENTRE: Saint-Alexandre
# LOCATION: St-Raphael-de-Bellechasse
# CLOSEST POPULATION CENTRE: Saint-Raphaël
# LOCATION: St-Albert
# CLOSEST POPULATION CENTRE: Warwick
# LOCATION: Cleveland
# CLOSEST POPULATION CENTRE: Richmond
# LOCATION: Lac-Ste-Marie
# CLOSEST POPULATION CENTRE: Maniwaki
# LOCATION: St-Robert
# CLOSEST POPULATION CENTRE: Sorel
# LOCATION: Grondines
# CLOSEST POPULATION CENTRE: Saint-Marc-des-Carrières
# LOCATION: Frontenac
# CLOSEST POPULATION CENTRE: Lac-Mégantic
# LOCATION: Notre-Dame-Des-Bois
# CLOSEST POPULATION CENTRE: Lac-Mégantic
# LOCATION: St-Cyrille-De-Lessard
# CLOSEST POPULATION CENTRE: Cap-Saint-Ignace
# LOCATION: St-Esprit
# CLOSEST POPULATION CENTRE: Saint-Roch-de-l'Achigan
# LOCATION: Tingwick
# CLOSEST POPULATION CENTRE: Warwick
# LOCATION: Racine
# CLOSEST POPULATION CENTRE: Valcourt
# LOCATION: ND-De-La-Merci
# UNKNOWN LOCATION: ND-De-La-Merci
# LOCATION: Pointe-Lebel
# CLOSEST POPULATION CENTRE: Hauterive
# LOCATION: St-Mathieu-De-Rioux
# CLOSEST POPULATION CENTRE: Saint-Fabien
# LOCATION: St-Étienne-De-Bolton
# CLOSEST POPULATION CENTRE: Waterloo
# LOCATION: La Macaza
# CLOSEST POPULATION CENTRE: Labelle
# LOCATION: St-François-Du-Lac
# CLOSEST POPULATION CENTRE: Pierreville
# LOCATION: ND-Du-Portage
# CLOSEST POPULATION CENTRE: Saint-Alexis-des-Monts
# LOCATION: Lyster
# CLOSEST POPULATION CENTRE: Laurier-Station
# LOCATION: St-Flavien
# CLOSEST POPULATION CENTRE: Laurier-Station
# LOCATION: St-Didace
# CLOSEST POPULATION CENTRE: Saint-Gabriel
# LOCATION: Pointe-des-Cascades
# CLOSEST POPULATION CENTRE: Melocheville
# LOCATION: St-Gabriel-De-Rimouski
# CLOSEST POPULATION CENTRE: Luceville
# LOCATION: Messines
# CLOSEST POPULATION CENTRE: Maniwaki
# LOCATION: St-Patrice-De-Beaurivage
# CLOSEST POPULATION CENTRE: Saint-Bernard
# LOCATION: Riviere-Ouelle
# CLOSEST POPULATION CENTRE: La Pocatière
# LOCATION: St-Casimir
# CLOSEST POPULATION CENTRE: Saint-Marc-des-Carrières
# LOCATION: East Broughton
# CLOSEST POPULATION CENTRE: East Broughton
# LOCATION: Buckland
# CLOSEST POPULATION CENTRE: Saint-Damien-de-Buckland
# LOCATION: Herouxville
# CLOSEST POPULATION CENTRE: Saint-Tite
# LOCATION: St-Aubert
# CLOSEST POPULATION CENTRE: Saint-Jean-Port-Joli
# LOCATION: Chandler
# CLOSEST POPULATION CENTRE: Chandler
# LOCATION: St-Pacôme
# CLOSEST POPULATION CENTRE: La Pocatière
# LOCATION: Ste-Marguerite-De-Beauce
# CLOSEST POPULATION CENTRE: Sainte-Marie
# LOCATION: St-Fabien
# CLOSEST POPULATION CENTRE: Saint-Fabien
# LOCATION: Cap-Chat
# CLOSEST POPULATION CENTRE: Cap-Chat
# LOCATION: Westbury
# CLOSEST POPULATION CENTRE: East Angus
# LOCATION: Les Méchins
# CLOSEST POPULATION CENTRE: Cap-Chat
# LOCATION: St-Ephrem-De-Beauce
# CLOSEST POPULATION CENTRE: Saint-Éphrem-de-Tring
# LOCATION: Ste-Ursule
# CLOSEST POPULATION CENTRE: Louiseville
# LOCATION: St-Blaise-sur-Richelieu
# CLOSEST POPULATION CENTRE: Napierville
# LOCATION: Bonaventure
# CLOSEST POPULATION CENTRE: Bonaventure
# LOCATION: St-Celestin
# CLOSEST POPULATION CENTRE: Saint Grégoire
# LOCATION: Huberdeau
# CLOSEST POPULATION CENTRE: Saint-Jovite
# LOCATION: Grande-Vallee
# CLOSEST POPULATION CENTRE: Rivière-au-Renard
# LOCATION: St-Edouard-De-Lotbiniere
# CLOSEST POPULATION CENTRE: Sainte-Croix
# LOCATION: St-Janvier-De-Joly
# CLOSEST POPULATION CENTRE: Laurier-Station
# LOCATION: St-Ulric
# CLOSEST POPULATION CENTRE: Matane
# LOCATION: North-Hatley
# CLOSEST POPULATION CENTRE: Magog
# LOCATION: Vaudreuil-Sur-Le-Lac
# CLOSEST POPULATION CENTRE: Oka
# LOCATION: L'Isle-Verte
# CLOSEST POPULATION CENTRE: Trois-Pistoles
# LOCATION: Cacouna
# CLOSEST POPULATION CENTRE: Rivière-du-Loup
# LOCATION: L'Isle-aux-Coudres
# CLOSEST POPULATION CENTRE: Baie-Saint-Paul
# LOCATION: St-Stanislas-De-Kostka
# CLOSEST POPULATION CENTRE: Salaberry-de-Valleyfield
# LOCATION: Ste-Victoire-De-Sorel
# CLOSEST POPULATION CENTRE: Sorel
# LOCATION: St-Bonaventure
# CLOSEST POPULATION CENTRE: Pierreville
# LOCATION: St-Paulin
# CLOSEST POPULATION CENTRE: Saint-Alexis-des-Monts
# LOCATION: St-Narcisse
# CLOSEST POPULATION CENTRE: Notre-Dame-du-Mont-Carmel
# LOCATION: Pohénégamook
# CLOSEST POPULATION CENTRE: Cabano
# LOCATION: St-Clet
# CLOSEST POPULATION CENTRE: Saint-Polycarpe
# LOCATION: Ste-Rose-De-Watford
# CLOSEST POPULATION CENTRE: Lac-Etchemin
# LOCATION: St-Aime-Des-Lacs
# CLOSEST POPULATION CENTRE: Clermont
# LOCATION: Ste-Clotilde-De-Horton
# CLOSEST POPULATION CENTRE: Notre-Dame-du-Bon-Conseil
# LOCATION: St-Jude
# CLOSEST POPULATION CENTRE: Saint-Hyacinthe
# LOCATION: St-Raphael
# CLOSEST POPULATION CENTRE: Saint-Raphaël
# LOCATION: St-Léon-De-Standon
# CLOSEST POPULATION CENTRE: Lac-Etchemin
# LOCATION: St-Georges-De-Windsor
# CLOSEST POPULATION CENTRE: Val-des-Sources
# LOCATION: Nantes
# CLOSEST POPULATION CENTRE: Lac-Mégantic
# LOCATION: Lochaber-Partie-Ouest
# CLOSEST POPULATION CENTRE: Thurso
# LOCATION: St-Narcisse-De-Rimouski
# CLOSEST POPULATION CENTRE: Rimouski
# LOCATION: St-Samuel
# CLOSEST POPULATION CENTRE: Saint-Léonard-d'Aston
# LOCATION: Mayo
# CLOSEST POPULATION CENTRE: Buckingham
# LOCATION: St-Majorique-De-Grantham
# CLOSEST POPULATION CENTRE: Drummondville
# LOCATION: St-Placide
# CLOSEST POPULATION CENTRE: Hudson
# LOCATION: St-Patrice-De-Sherrington
# CLOSEST POPULATION CENTRE: Saint-Michel
# LOCATION: St-Jacques-De-Leeds
# CLOSEST POPULATION CENTRE: East Broughton
# LOCATION: St-Sylvere
# CLOSEST POPULATION CENTRE: Daveluyville
# LOCATION: Mulgrave-Et-Derry
# CLOSEST POPULATION CENTRE: Buckingham
# LOCATION: St-Edmond-De-Grantham
# CLOSEST POPULATION CENTRE: Saint-Germain-de-Grantham
# LOCATION: Ulverton
# CLOSEST POPULATION CENTRE: Richmond
# LOCATION: Val-Brillant
# CLOSEST POPULATION CENTRE: Amqui
# LOCATION: Ste-Eulalie
# CLOSEST POPULATION CENTRE: Saint-Léonard-d'Aston
# LOCATION: Chesterville
# CLOSEST POPULATION CENTRE: Warwick
# LOCATION: St-François-De-La-Rivière-Du-Sud
# CLOSEST POPULATION CENTRE: Saint-Raphaël
# LOCATION: St-Guillaume
# CLOSEST POPULATION CENTRE: Saint-Germain-de-Grantham
# LOCATION: Montpellier
# CLOSEST POPULATION CENTRE: Lac-Simon
# LOCATION: Wotton
# CLOSEST POPULATION CENTRE: Val-des-Sources
# LOCATION: St-Armand
# CLOSEST POPULATION CENTRE: Bedford
# LOCATION: Harrington
# CLOSEST POPULATION CENTRE: Grenville
# LOCATION: Montebello
# CLOSEST POPULATION CENTRE: Papineauville
# LOCATION: St-Justin
# CLOSEST POPULATION CENTRE: Maskinongé
# LOCATION: St-Louis-De-Gonzague
# CLOSEST POPULATION CENTRE: Saint-Prosper
# LOCATION: St-Donat-De-Rimouski
# UNKNOWN LOCATION: St-Donat-De-Rimouski
# LOCATION: Honfleur
# CLOSEST POPULATION CENTRE: Sainte-Claire
# LOCATION: Westmount
# CLOSEST POPULATION CENTRE: Le Sud-Ouest
# LOCATION: Adstock
# CLOSEST POPULATION CENTRE: Saint-Éphrem-de-Tring
# LOCATION: Bouchette
# CLOSEST POPULATION CENTRE: Maniwaki
# LOCATION: St-Charles-De-Bourget
# CLOSEST POPULATION CENTRE: Saint-Ambroise
# LOCATION: Ste-Cecile-De-Levrard
# CLOSEST POPULATION CENTRE: Gentilly
# LOCATION: St-Félix-De-Kingsey
# CLOSEST POPULATION CENTRE: Kingsey Falls
# LOCATION: Bedford
# CLOSEST POPULATION CENTRE: Bedford
# LOCATION: Ste-Sophie-De-Levrard
# CLOSEST POPULATION CENTRE: Gentilly
# LOCATION: Métis-Sur-Mer
# CLOSEST POPULATION CENTRE: Price
# LOCATION: Ste-Geneviève-De-Berthier
# CLOSEST POPULATION CENTRE: Berthierville
# LOCATION: Mont-Carmel
# CLOSEST POPULATION CENTRE: Saint-Pascal
# LOCATION: St-Alexis
# CLOSEST POPULATION CENTRE: Saint-Jacques
# LOCATION: Ste-Aurélie
# CLOSEST POPULATION CENTRE: Saint-Prosper
# LOCATION: St-Luc-De-Vincennes
# CLOSEST POPULATION CENTRE: Gentilly
# LOCATION: Noyan
# CLOSEST POPULATION CENTRE: Lacolle
# LOCATION: St-Cyprien-De-Napierville
# CLOSEST POPULATION CENTRE: Napierville
# LOCATION: Stanstead
# CLOSEST POPULATION CENTRE: Stanstead
# LOCATION: St-Martin
# CLOSEST POPULATION CENTRE: Saint-Martin
# LOCATION: La Guadeloupe
# CLOSEST POPULATION CENTRE: Saint-Éphrem-de-Tring
# LOCATION: Labrecque
# CLOSEST POPULATION CENTRE: Alma
# LOCATION: Manseau
# CLOSEST POPULATION CENTRE: Daveluyville
# LOCATION: St-Frédéric
# CLOSEST POPULATION CENTRE: Saint-Joseph-de-Beauce
# LOCATION: St-Hilarion
# CLOSEST POPULATION CENTRE: Baie-Saint-Paul
# LOCATION: Deschaillons
# CLOSEST POPULATION CENTRE: Plessisville
# LOCATION: St-Gedeon-De-Beauce
# CLOSEST POPULATION CENTRE: Saint-Martin
# LOCATION: Ste-Euphemie-Sur-Riviere-Du-Sud
# CLOSEST POPULATION CENTRE: Montmagny
# LOCATION: Sawyerville
# CLOSEST POPULATION CENTRE: Cookshire
# LOCATION: St-Sylvestre
# CLOSEST POPULATION CENTRE: Saint-Elzéar
# LOCATION: Plaisance
# CLOSEST POPULATION CENTRE: Papineauville
# LOCATION: Sherrington
# CLOSEST POPULATION CENTRE: Napierville
# LOCATION: St-Joachim
# CLOSEST POPULATION CENTRE: Beaupré
# LOCATION: St-Benoit-Labre
# CLOSEST POPULATION CENTRE: Saint-Georges
# LOCATION: Causapscal
# CLOSEST POPULATION CENTRE: Causapscal
# LOCATION: Iles-de-la-Madeleine
# CLOSEST POPULATION CENTRE: Grande-Rivière
# LOCATION: Ste-Praxède
# CLOSEST POPULATION CENTRE: Disraeli
# LOCATION: St-Nazaire-D'Acton
# CLOSEST POPULATION CENTRE: Acton Vale
# LOCATION: Ste-Sabine-De-Bellechasse
# CLOSEST POPULATION CENTRE: Sainte-Justine
# LOCATION: Hatley
# CLOSEST POPULATION CENTRE: Coaticook
# LOCATION: St-Rene
# CLOSEST POPULATION CENTRE: Saint-Martin
# LOCATION: Cloridorme
# CLOSEST POPULATION CENTRE: Rivière-au-Renard
# LOCATION: Duhamel
# CLOSEST POPULATION CENTRE: Lac-Simon
# LOCATION: Lac-Drolet
# CLOSEST POPULATION CENTRE: Lac-Mégantic
# LOCATION: Desbiens
# CLOSEST POPULATION CENTRE: Métabetchouan
# LOCATION: Ham-Nord
# CLOSEST POPULATION CENTRE: Disraeli
# LOCATION: St-Norbert-D'Arthabaska
# CLOSEST POPULATION CENTRE: Princeville
# LOCATION: Scotstown
# CLOSEST POPULATION CENTRE: Cookshire
# LOCATION: Cayamant
# CLOSEST POPULATION CENTRE: Maniwaki
# LOCATION: Bonsecours
# CLOSEST POPULATION CENTRE: Valcourt
# LOCATION: Bowman
# CLOSEST POPULATION CENTRE: Buckingham
# LOCATION: Ferme-Neuve
# CLOSEST POPULATION CENTRE: Ferme-Neuve
# LOCATION: La Doré
# CLOSEST POPULATION CENTRE: Saint-Félicien
# LOCATION: Lac-des-Plages
# CLOSEST POPULATION CENTRE: Lac-Simon
# LOCATION: Laurierville
# CLOSEST POPULATION CENTRE: Plessisville
# LOCATION: Ste-Barbe
# CLOSEST POPULATION CENTRE: Huntingdon
# LOCATION: Ste-Perpétue
# CLOSEST POPULATION CENTRE: Saint-Jean-Port-Joli
# LOCATION: Albanel
# CLOSEST POPULATION CENTRE: Normandin
# LOCATION: Piopolis
# CLOSEST POPULATION CENTRE: Lac-Mégantic
# LOCATION: St-Hugues
# CLOSEST POPULATION CENTRE: Saint-Liboire
# LOCATION: St-Philémon
# CLOSEST POPULATION CENTRE: Saint-Damien-de-Buckland
# LOCATION: Dosquet
# CLOSEST POPULATION CENTRE: Laurier-Station
# LOCATION: St-Cuthbert
# CLOSEST POPULATION CENTRE: Berthierville
# LOCATION: Nouvelle
# CLOSEST POPULATION CENTRE: Carleton
# LOCATION: Tadoussac
# CLOSEST POPULATION CENTRE: Les Escoumins
# LOCATION: ND-De-La-Salette
# UNKNOWN LOCATION: ND-De-La-Salette
# LOCATION: Frelighsburg
# CLOSEST POPULATION CENTRE: Bedford
# LOCATION: Yamaska
# CLOSEST POPULATION CENTRE: Pierreville
# LOCATION: Issoudun
# CLOSEST POPULATION CENTRE: Laurier-Station
# LOCATION: St-Pierre-De-La-Riviere-Du-Sud
# CLOSEST POPULATION CENTRE: Montmagny
# LOCATION: Newport
# CLOSEST POPULATION CENTRE: Cookshire
# LOCATION: St-Stanislas-De-Champlain
# UNKNOWN LOCATION: St-Stanislas-De-Champlain
# LOCATION: St-Claude
# CLOSEST POPULATION CENTRE: Windsor
# LOCATION: St-Bernard-De-Lacolle
# CLOSEST POPULATION CENTRE: Lacolle
# LOCATION: La Visitation-de-l'Ile-Dupas
# CLOSEST POPULATION CENTRE: Berthierville
# LOCATION: St-Urbain-Premier
# CLOSEST POPULATION CENTRE: Sainte-Martine
# LOCATION: Durham-Sud
# CLOSEST POPULATION CENTRE: Richmond
# LOCATION: Ormstown
# CLOSEST POPULATION CENTRE: Ormstown
# LOCATION: Mansfield-Et-Pontefract
# CLOSEST POPULATION CENTRE: Fort-Coulonge
# LOCATION: St-Louis-de-Blandford
# CLOSEST POPULATION CENTRE: Daveluyville
# LOCATION: Ste-Hedwidge
# CLOSEST POPULATION CENTRE: Roberval
# LOCATION: Lamarche
# CLOSEST POPULATION CENTRE: Saint-Ambroise
# LOCATION: Caplan
# CLOSEST POPULATION CENTRE: New Richmond
# LOCATION: St-Adrien
# CLOSEST POPULATION CENTRE: Val-des-Sources
# LOCATION: Ste-Cecile-De-Whitton
# CLOSEST POPULATION CENTRE: Lac-Mégantic
# LOCATION: St-Valérien-De-Milton
# CLOSEST POPULATION CENTRE: Saint-Liboire
# LOCATION: Paspebiac
# CLOSEST POPULATION CENTRE: Bonaventure
# LOCATION: St-Sixte
# CLOSEST POPULATION CENTRE: Thurso
# LOCATION: St-Remi-De-Tingwick
# CLOSEST POPULATION CENTRE: Val-des-Sources
# LOCATION: St-Narcisse-De-Beaurivage
# CLOSEST POPULATION CENTRE: Saint-Bernard
# LOCATION: Cabano
# CLOSEST POPULATION CENTRE: Cabano
# LOCATION: Amos
# CLOSEST POPULATION CENTRE: Amos
# LOCATION: Déléage
# CLOSEST POPULATION CENTRE: Maniwaki
# LOCATION: Notre-Dame-Des-Monts
# CLOSEST POPULATION CENTRE: Clermont
# LOCATION: St-Louis-Du-Ha-Ha
# CLOSEST POPULATION CENTRE: Cabano
# LOCATION: St-Fabien-De-Panet
# CLOSEST POPULATION CENTRE: Sainte-Justine
# LOCATION: St-André-De-Kamouraska
# CLOSEST POPULATION CENTRE: Saint-Pascal
# LOCATION: St-Émile-De-Suffolk
# CLOSEST POPULATION CENTRE: Lac-Simon
# LOCATION: St-Zephirin-De-Courval
# CLOSEST POPULATION CENTRE: Pierreville
# LOCATION: Havre-St-Pierre
# CLOSEST POPULATION CENTRE: Havre-Saint-Pierre
# LOCATION: St-Sebastien-De-Frontenac
# UNKNOWN LOCATION: St-Sebastien-De-Frontenac
# LOCATION: ND-De-Montauban
# UNKNOWN LOCATION: ND-De-Montauban
# LOCATION: St-Norbert
# CLOSEST POPULATION CENTRE: Saint-Félix-de-Valois
# LOCATION: Bolton-Ouest
# CLOSEST POPULATION CENTRE: Waterloo
# LOCATION: St-Rene-De-Matane
# CLOSEST POPULATION CENTRE: Matane
# LOCATION: Terrasse-Vaudreuil
# CLOSEST POPULATION CENTRE: Melocheville
# LOCATION: St-Hubert-De-Rivière-Du-Loup
# CLOSEST POPULATION CENTRE: Cabano
# LOCATION: St-Ludger
# CLOSEST POPULATION CENTRE: Lac-Mégantic
# LOCATION: Ste-Anne-De-La-Pocatiere
# CLOSEST POPULATION CENTRE: La Pocatière
# LOCATION: Kiamika
# CLOSEST POPULATION CENTRE: Mont-Laurier
# LOCATION: St-Ludger-De-Milot
# CLOSEST POPULATION CENTRE: Dolbeau
# LOCATION: Ste-Anne-De-Sabrevois
# CLOSEST POPULATION CENTRE: Saint-Alexandre
# LOCATION: Lingwick
# CLOSEST POPULATION CENTRE: East Angus
# LOCATION: Gracefield
# CLOSEST POPULATION CENTRE: Maniwaki
# LOCATION: St-Valere
# CLOSEST POPULATION CENTRE: Victoriaville
# LOCATION: Ste-Madeleine-De-La-Riviere-Madeleine
# CLOSEST POPULATION CENTRE: Gaspé
# LOCATION: Courcelles
# CLOSEST POPULATION CENTRE: Saint-Éphrem-de-Tring
# LOCATION: Ste-Clotilde-De-Beauce
# CLOSEST POPULATION CENTRE: Saint-Éphrem-de-Tring
# LOCATION: Lefebvre
# CLOSEST POPULATION CENTRE: Acton Vale
# LOCATION: Audet
# CLOSEST POPULATION CENTRE: Lac-Mégantic
# LOCATION: Val-Alain
# CLOSEST POPULATION CENTRE: Laurier-Station
# LOCATION: Ste-Jeanne-D'Arc
# CLOSEST POPULATION CENTRE: Price
# LOCATION: St-Marcel-De-Richelieu
# CLOSEST POPULATION CENTRE: Pierreville
# LOCATION: Lac-St-Paul
# CLOSEST POPULATION CENTRE: Ferme-Neuve
# LOCATION: Fort-Coulonge
# CLOSEST POPULATION CENTRE: Fort-Coulonge
# LOCATION: Lac-Saguay
# CLOSEST POPULATION CENTRE: Laurentides
# LOCATION: Chute-aux-Outardes
# CLOSEST POPULATION CENTRE: Chute-aux-Outardes
# LOCATION: Mont-St-Michel
# CLOSEST POPULATION CENTRE: Ferme-Neuve
# LOCATION: Howick
# CLOSEST POPULATION CENTRE: Sainte-Martine
# LOCATION: St-Marcellin
# CLOSEST POPULATION CENTRE: Rimouski
# LOCATION: Gallix
# CLOSEST POPULATION CENTRE: Sept-Îles
# LOCATION: St-Marcel-De-L'Islet
# UNKNOWN LOCATION: St-Marcel-De-L'Islet
# LOCATION: Brébeuf
# CLOSEST POPULATION CENTRE: Saint-Jovite
# LOCATION: Black Lake
# CLOSEST POPULATION CENTRE: Black Lake
# LOCATION: Wentworth
# CLOSEST POPULATION CENTRE: Brownsburg
# LOCATION: St-Romain
# CLOSEST POPULATION CENTRE: Disraeli
# LOCATION: Grand-St-Esprit
# CLOSEST POPULATION CENTRE: Saint Grégoire
# LOCATION: St-Urbain
# CLOSEST POPULATION CENTRE: Baie-Saint-Paul
# LOCATION: St-Siméon-De-Bonaventure
# CLOSEST POPULATION CENTRE: LeBlanc
# LOCATION: Calixa-Lavallee
# CLOSEST POPULATION CENTRE: Verchères
# LOCATION: St-Isidore-de-Clifton
# CLOSEST POPULATION CENTRE: Cookshire
# LOCATION: Chartierville
# CLOSEST POPULATION CENTRE: Cookshire
# LOCATION: New Richmond
# CLOSEST POPULATION CENTRE: New Richmond
# LOCATION: Biencourt
# CLOSEST POPULATION CENTRE: Cabano
# ...
# LOCATION: Isle-Aux-Grues
# CLOSEST POPULATION CENTRE: Cap-Saint-Ignace
# LOCATION: Montcerf
# CLOSEST POPULATION CENTRE: Maniwaki
# LOCATION: St-Nazaire-de-Dorchester
# CLOSEST POPULATION CENTRE: Saint-Damien-de-Buckland
# LOCATION: Rivière-Éternité
# CLOSEST POPULATION CENTRE: Bagotville
# LOCATION: Petit-Saguenay
# CLOSEST POPULATION CENTRE: Les Escoumins
# LOCATION: Fassett
# CLOSEST POPULATION CENTRE: Papineauville
# LOCATION: Lacorne
# CLOSEST POPULATION CENTRE: Lac-Connelly
# LOCATION: Ste-Irène
# CLOSEST POPULATION CENTRE: Amqui
# LOCATION: St-Pierre-Baptiste
# CLOSEST POPULATION CENTRE: Plessisville
# LOCATION: Très-St-Sacrement
# CLOSEST POPULATION CENTRE: Sainte-Martine
# LOCATION: La Trinité-Des-Monts
# CLOSEST POPULATION CENTRE: Le Bic
# LOCATION: La Sarre
# CLOSEST POPULATION CENTRE: La Sarre
# LOCATION: Ste-Therese-De-Gaspe
# CLOSEST POPULATION CENTRE: Grande-Rivière
# LOCATION: Senneterre
# CLOSEST POPULATION CENTRE: Senneterre
# LOCATION: St-Adrien-D'Irlande
# CLOSEST POPULATION CENTRE: Black Lake
# LOCATION: St-Mathieu-d'Harricana
# CLOSEST POPULATION CENTRE: Amos
# LOCATION: Baie-des-Sables
# CLOSEST POPULATION CENTRE: Price
# LOCATION: Lac-Au-Saumon
# CLOSEST POPULATION CENTRE: Amqui
# LOCATION: Brome
# CLOSEST POPULATION CENTRE: Cowansville
# LOCATION: St-François-De-Sales
# CLOSEST POPULATION CENTRE: Roberval
# LOCATION: St-Eloi
# CLOSEST POPULATION CENTRE: Trois-Pistoles
# LOCATION: Franklin
# CLOSEST POPULATION CENTRE: Ormstown
# LOCATION: Stanstead-Est
# CLOSEST POPULATION CENTRE: Stanstead
# LOCATION: Ste-Paule
# CLOSEST POPULATION CENTRE: Matane
# LOCATION: St-Antoine-Abbe
# CLOSEST POPULATION CENTRE: Saint-Chrysostome
# LOCATION: Villeroy
# CLOSEST POPULATION CENTRE: Plessisville
# LOCATION: Johnville
# CLOSEST POPULATION CENTRE: Cookshire
# LOCATION: Ste-Sophie-D'Halifax
# CLOSEST POPULATION CENTRE: Plessisville
# LOCATION: Colombier
# CLOSEST POPULATION CENTRE: Betsiamites
# LOCATION: Grosses-Roches
# CLOSEST POPULATION CENTRE: Matane
# LOCATION: Lanoraie-D'Autray
# CLOSEST POPULATION CENTRE: Saint-Joseph-de-Lanoraie
# LOCATION: St-Moise
# CLOSEST POPULATION CENTRE: Price
# LOCATION: Franquelin
# CLOSEST POPULATION CENTRE: Baie-Comeau
# LOCATION: St-Honoré-de-Shenley
# CLOSEST POPULATION CENTRE: Saint-Martin
# LOCATION: Esprit-Saint
# CLOSEST POPULATION CENTRE: Saint-Fabien
# LOCATION: St-Arsene
# CLOSEST POPULATION CENTRE: Rivière-du-Loup
# LOCATION: St-Jean-De-Brebeuf
# CLOSEST POPULATION CENTRE: Thetford Mines
# LOCATION: St-Philibert
# CLOSEST POPULATION CENTRE: Linière
# LOCATION: Kingsbury
# CLOSEST POPULATION CENTRE: Richmond
# LOCATION: St-Evariste-De-Forsyth
# CLOSEST POPULATION CENTRE: Saint-Éphrem-de-Tring
# LOCATION: St-Joseph-de-Mékinac
# CLOSEST POPULATION CENTRE: Sainte-Thècle
# LOCATION: St-André-Du-Lac-St-Jean
# CLOSEST POPULATION CENTRE: Métabetchouan
# LOCATION: Proulxville
# CLOSEST POPULATION CENTRE: Saint-Tite
# LOCATION: St-Michel-Du-Squatec
# CLOSEST POPULATION CENTRE: Cabano
# LOCATION: Ste-Justine-De-Newton
# CLOSEST POPULATION CENTRE: Saint-Polycarpe
# LOCATION: St-Jules-De-Beauce
# CLOSEST POPULATION CENTRE: East Broughton
# LOCATION: Ste-Agathe-Nord
# CLOSEST POPULATION CENTRE: Sainte-Agathe-des-Monts
# LOCATION: Inverness
# CLOSEST POPULATION CENTRE: Plessisville
# LOCATION: Egan-Sud
# CLOSEST POPULATION CENTRE: Maniwaki
# LOCATION: Lejeune
# CLOSEST POPULATION CENTRE: Notre-Dame-du-Lac
# LOCATION: Boileau
# CLOSEST POPULATION CENTRE: Lac-Simon
# LOCATION: Ste-Helene-de-Chester
# CLOSEST POPULATION CENTRE: Victoriaville
# LOCATION: Stanbridge Station
# CLOSEST POPULATION CENTRE: Bedford
# LOCATION: St-Clement
# CLOSEST POPULATION CENTRE: Trois-Pistoles
# LOCATION: St-Damase-De-L'Islet
# CLOSEST POPULATION CENTRE: Saint-Jean-Port-Joli
# LOCATION: Baie-Ste-Catherine
# CLOSEST POPULATION CENTRE: Rivière-du-Loup
# LOCATION: Havre Aubert
# CLOSEST POPULATION CENTRE: Cap-aux-Meules
# LOCATION: Bergeronnes
# CLOSEST POPULATION CENTRE: Les Escoumins
# LOCATION: St-Maxime-Du-Mont-Louis
# CLOSEST POPULATION CENTRE: Sainte-Anne-des-Monts
# LOCATION: Clarke City
# CLOSEST POPULATION CENTRE: Sept-Îles
# LOCATION: St-Guillaume-D'Upton
# UNKNOWN LOCATION: St-Guillaume-D'Upton
# LOCATION: St-Severe
# CLOSEST POPULATION CENTRE: Yamachiche
# LOCATION: Ste-Rita
# CLOSEST POPULATION CENTRE: Trois-Pistoles
# LOCATION: St-Aime-Du-Lac-Des-Iles
# CLOSEST POPULATION CENTRE: Mont-Laurier
# LOCATION: Abercorn
# CLOSEST POPULATION CENTRE: Cowansville
# LOCATION: Ste-Francoise
# CLOSEST POPULATION CENTRE: Gentilly
# LOCATION: St-Albert-De-Warwick
# CLOSEST POPULATION CENTRE: Warwick
# LOCATION: Campbells Bay
# CLOSEST POPULATION CENTRE: Fort-Coulonge
# LOCATION: Ste-Seraphine
# CLOSEST POPULATION CENTRE: Kingsey Falls
# LOCATION: Bryson
# CLOSEST POPULATION CENTRE: Shawville
# LOCATION: St-Adelphe
# CLOSEST POPULATION CENTRE: Saint-Tite
# LOCATION: Anse-Pleureuse
# CLOSEST POPULATION CENTRE: Sainte-Anne-des-Monts
# LOCATION: Vendée
# CLOSEST POPULATION CENTRE: Saint-Jovite
# LOCATION: St-Telesphore
# CLOSEST POPULATION CENTRE: Saint-Polycarpe
# LOCATION: Ladysmith
# CLOSEST POPULATION CENTRE: Shawville
# LOCATION: Godmanchester
# CLOSEST POPULATION CENTRE: Huntingdon
# LOCATION: St-Alphonse-De-Caplan
# CLOSEST POPULATION CENTRE: New Richmond
# LOCATION: Kazabazua
# CLOSEST POPULATION CENTRE: Maniwaki
# LOCATION: Malartic
# CLOSEST POPULATION CENTRE: Malartic
# LOCATION: Preissac
# CLOSEST POPULATION CENTRE: Amos
# LOCATION: Landrienne
# CLOSEST POPULATION CENTRE: Amos
# LOCATION: Rivière-Heva
# CLOSEST POPULATION CENTRE: Malartic
# LOCATION: St-Zenon-Du-Lac-Humqui
# CLOSEST POPULATION CENTRE: Amqui
# LOCATION: Eaton
# CLOSEST POPULATION CENTRE: Cookshire
# LOCATION: Ste-Elisabeth-de-Proulx
# CLOSEST POPULATION CENTRE: Dolbeau
# LOCATION: Havelock
# CLOSEST POPULATION CENTRE: Saint-Chrysostome
# LOCATION: St-Denis-De-La-Bouteillerie
# CLOSEST POPULATION CENTRE: Saint-Pascal
# LOCATION: l'Ile-du-Grand-Calumet
# CLOSEST POPULATION CENTRE: Fort-Coulonge
# LOCATION: Lac-Frontiere
# CLOSEST POPULATION CENTRE: Sainte-Justine
# LOCATION: St-Eugène-De-Ladriere
# CLOSEST POPULATION CENTRE: Saint-Fabien
# LOCATION: La Corne
# CLOSEST POPULATION CENTRE: Amos
# LOCATION: St-Jacques-Le-Majeur-De-Wolfestown
# CLOSEST POPULATION CENTRE: Disraeli
# LOCATION: St-Adelphe-De-Champlain
# UNKNOWN LOCATION: St-Adelphe-De-Champlain
# LOCATION: New Carlisle
# CLOSEST POPULATION CENTRE: Bonaventure
# LOCATION: Sayabec
# CLOSEST POPULATION CENTRE: Amqui
# LOCATION: St-Guy
# CLOSEST POPULATION CENTRE: Saint-Fabien
# LOCATION: Mashteuiatsh
# CLOSEST POPULATION CENTRE: Roberval
# LOCATION: Pike River
# CLOSEST POPULATION CENTRE: Bedford
# LOCATION: Palmarolle
# CLOSEST POPULATION CENTRE: La Sarre
# LOCATION: St-Camille
# CLOSEST POPULATION CENTRE: Val-des-Sources
# LOCATION: St-Bruno-De-Kamouraska
# CLOSEST POPULATION CENTRE: Saint-Pascal
# LOCATION: Mont-St-Pierre
# CLOSEST POPULATION CENTRE: Sainte-Anne-des-Monts
# LOCATION: St-Jean-De-La-Lande
# CLOSEST POPULATION CENTRE: Dégelis
# LOCATION: Port-Au-Persil
# CLOSEST POPULATION CENTRE: La Malbaie
# LOCATION: Pointe-Aux-Outardes
# CLOSEST POPULATION CENTRE: Chute-aux-Outardes
# LOCATION: St-Thuribe
# CLOSEST POPULATION CENTRE: Saint-Marc-des-Carrières
# LOCATION: Barkmere
# CLOSEST POPULATION CENTRE: Saint-Jovite
# LOCATION: Pointe-A-La-Croix
# CLOSEST POPULATION CENTRE: Pointe-à-la-Croix
# LOCATION: Barraute
# CLOSEST POPULATION CENTRE: Barraute
# LOCATION: Lemieux
# CLOSEST POPULATION CENTRE: Daveluyville
# LOCATION: St-David
# CLOSEST POPULATION CENTRE: Pierreville
# LOCATION: Poularies
# CLOSEST POPULATION CENTRE: Macamic
# LOCATION: ND-Des-Neiges-Trois-Pistoles
# UNKNOWN LOCATION: ND-Des-Neiges-Trois-Pistoles
# LOCATION: St-Remi-D'Amherst
# CLOSEST POPULATION CENTRE: Saint-Jovite
# LOCATION: St-Edmond-les-Plaines
# CLOSEST POPULATION CENTRE: Normandin
# LOCATION: Ste-Félicité
# CLOSEST POPULATION CENTRE: Matane
# LOCATION: St-Octave-De-Metis
# CLOSEST POPULATION CENTRE: Price
# LOCATION: Natashquan
# CLOSEST POPULATION CENTRE: Havre-Saint-Pierre
# LOCATION: ND-De-Stanbridge
# UNKNOWN LOCATION: ND-De-Stanbridge
# LOCATION: Petite-Vallee
# CLOSEST POPULATION CENTRE: Rivière-au-Renard
# LOCATION: Waltham
# CLOSEST POPULATION CENTRE: Fort-Coulonge
# LOCATION: St-Valentin
# CLOSEST POPULATION CENTRE: Lacolle
# LOCATION: St-Severin
# CLOSEST POPULATION CENTRE: Saint-Tite
# LOCATION: St-Jogues
# CLOSEST POPULATION CENTRE: Bonaventure
# LOCATION: Moisie
# CLOSEST POPULATION CENTRE: Maliotenam
# LOCATION: Gallichan
# CLOSEST POPULATION CENTRE: La Sarre
# LOCATION: Lots-Renversés
# CLOSEST POPULATION CENTRE: Notre-Dame-du-Lac
# LOCATION: Baie-Trinite
# CLOSEST POPULATION CENTRE: Cap-Chat
# LOCATION: St-Pie-De-Guire
# CLOSEST POPULATION CENTRE: Pierreville
# LOCATION: Rivière-Trois-Pistoles
# CLOSEST POPULATION CENTRE: Trois-Pistoles
# LOCATION: Ivry-Sur-Le-Lac
# CLOSEST POPULATION CENTRE: Sainte-Agathe-des-Monts
# LOCATION: Belleterre
# CLOSEST POPULATION CENTRE: Ville-Marie
# LOCATION: St-Joseph-De-Kamouraska
# CLOSEST POPULATION CENTRE: Saint-Pascal
# LOCATION: St-Charles-Garnier
# CLOSEST POPULATION CENTRE: Mont-Joli
# LOCATION: Alleyn-Et-Cawood
# CLOSEST POPULATION CENTRE: Shawville
# LOCATION: St-Jules
# CLOSEST POPULATION CENTRE: East Broughton
# LOCATION: Compton Station
# CLOSEST POPULATION CENTRE: Coaticook
# LOCATION: St-Edouard
# CLOSEST POPULATION CENTRE: Saint-Michel
# LOCATION: Barnston
# CLOSEST POPULATION CENTRE: Coaticook
# LOCATION: St-Adalbert
# CLOSEST POPULATION CENTRE: Cap-Saint-Ignace
# LOCATION: Chester-Est
# CLOSEST POPULATION CENTRE: Lacolle
# LOCATION: Ste-Elisabeth-De-Warwick
# CLOSEST POPULATION CENTRE: Warwick
# LOCATION: Albertville
# CLOSEST POPULATION CENTRE: Causapscal
# LOCATION: Lac-Douaire
# CLOSEST POPULATION CENTRE: Ferme-Neuve
# LOCATION: Hampden
# CLOSEST POPULATION CENTRE: Lac-Mégantic
# LOCATION: Des Ruisseaux
# CLOSEST POPULATION CENTRE: Havre-Saint-Pierre
# LOCATION: Ste-Hélène
# CLOSEST POPULATION CENTRE: Saint-Pascal
# LOCATION: Sheenboro
# CLOSEST POPULATION CENTRE: Fort-Coulonge
# LOCATION: Authier-Nord
# CLOSEST POPULATION CENTRE: Macamic
# LOCATION: Grand-Métis
# CLOSEST POPULATION CENTRE: Price
# LOCATION: Marsoui
# CLOSEST POPULATION CENTRE: Sainte-Anne-des-Monts
# LOCATION: St-Denis de Kamouraska
# CLOSEST POPULATION CENTRE: Saint-Pascal
# LOCATION: Port-Menier
# CLOSEST POPULATION CENTRE: Rivière-au-Renard
# LOCATION: Baskatong
# CLOSEST POPULATION CENTRE: Ferme-Neuve
# LOCATION: Hope
# CLOSEST POPULATION CENTRE: Bonaventure
# LOCATION: St-Césaire
# CLOSEST POPULATION CENTRE: Saint-Césaire
# LOCATION: Valcartier
# CLOSEST POPULATION CENTRE: Shannon
# LOCATION: St-Severin-De-Beauce
# UNKNOWN LOCATION: St-Severin-De-Beauce
# LOCATION: Ste-Félicité-de-L'Islet
# CLOSEST POPULATION CENTRE: Saint-Jean-Port-Joli
# LOCATION: St-Omer
# CLOSEST POPULATION CENTRE: La Pocatière
# LOCATION: Labrieville
# CLOSEST POPULATION CENTRE: Forestville
# LOCATION: Weir
# CLOSEST POPULATION CENTRE: Saint-Jovite
# LOCATION: St-Edouard-De-Frampton
# CLOSEST POPULATION CENTRE: Vallée-Jonction
# LOCATION: Ste-Marguerite-De-Lingwick
# CLOSEST POPULATION CENTRE: East Angus
# LOCATION: L'Anse-aux-Griffons
# CLOSEST POPULATION CENTRE: Îles Laval
# LOCATION: St-Elphege
# CLOSEST POPULATION CENTRE: Pierreville
# LOCATION: Grande-Ile
# CLOSEST POPULATION CENTRE: Salaberry-de-Valleyfield
# LOCATION: Lakefield
# CLOSEST POPULATION CENTRE: Lachute
# LOCATION: Lac-Deschenes
# CLOSEST POPULATION CENTRE: Saint-Pascal
# LOCATION: Villemontel
# CLOSEST POPULATION CENTRE: Amos
# LOCATION: Godbout
# CLOSEST POPULATION CENTRE: Baie-Comeau
# LOCATION: Les Buissons
# CLOSEST POPULATION CENTRE: Chute-aux-Outardes
# LOCATION: St-Stanislas
# CLOSEST POPULATION CENTRE: Saint-Tite
# LOCATION: St-Simon-sur-Mer
# CLOSEST POPULATION CENTRE: Trois-Pistoles
# LOCATION: Hervey-Jonction
# CLOSEST POPULATION CENTRE: Sainte-Thècle
# LOCATION: Hope Town
# CLOSEST POPULATION CENTRE: Bonaventure
# LOCATION: St-Hilaire-De-Dorset
# CLOSEST POPULATION CENTRE: Saint-Martin
# LOCATION: St-Elzéar-De-Bonaventure
# CLOSEST POPULATION CENTRE: LeBlanc
# LOCATION: St-Omer-L'Islet
# CLOSEST POPULATION CENTRE: La Pocatière
# LOCATION: St-Gabriel
# CLOSEST POPULATION CENTRE: Saint-Gabriel
# LOCATION: Grandes-Bergeronnes
# CLOSEST POPULATION CENTRE: Les Escoumins
# LOCATION: St-Blaise
# CLOSEST POPULATION CENTRE: Napierville
# LOCATION: St-Antoine-De-L'Isle-Aux-Grues
# CLOSEST POPULATION CENTRE: Cap-Saint-Ignace
# LOCATION: Arthabaska
# CLOSEST POPULATION CENTRE: Victoriaville
# LOCATION: Dupuy
# CLOSEST POPULATION CENTRE: La Sarre
# LOCATION: Ste-Florence
# CLOSEST POPULATION CENTRE: Causapscal
# LOCATION: St-Godefroi
# CLOSEST POPULATION CENTRE: Bonaventure
# LOCATION: Clarendon
# CLOSEST POPULATION CENTRE: Shawville
# LOCATION: Ste-Irene-De-Matapedia
# CLOSEST POPULATION CENTRE: Amqui
# LOCATION: St-Augustin
# CLOSEST POPULATION CENTRE: Saint-Augustin
# LOCATION: St-François-de-Montmagny
# UNKNOWN LOCATION: St-François-de-Montmagny
# LOCATION: Val-Barrette
# CLOSEST POPULATION CENTRE: Mont-Laurier
# LOCATION: St-Noel
# CLOSEST POPULATION CENTRE: Price
# LOCATION: Longue-Pointe-De-Mingan
# CLOSEST POPULATION CENTRE: Havre-Saint-Pierre
# LOCATION: ND-De-Bonsecours
# UNKNOWN LOCATION: ND-De-Bonsecours
# LOCATION: Laverlochère-Angliers
# CLOSEST POPULATION CENTRE: Ville-Marie
# LOCATION: Remigny
# CLOSEST POPULATION CENTRE: Ville-Marie
# LOCATION: Rivière-Au-Tonnerre
# CLOSEST POPULATION CENTRE: Havre-Saint-Pierre
# LOCATION: St-Joseph-De-Lepage
# CLOSEST POPULATION CENTRE: Mont-Joli
# LOCATION: L'Ile-Cadieux
# CLOSEST POPULATION CENTRE: Oka
# LOCATION: Grand-Lac-St-François
# CLOSEST POPULATION CENTRE: Disraeli
# LOCATION: Esterel
# CLOSEST POPULATION CENTRE: Sainte-Adèle
# LOCATION: Lac Frontière
# CLOSEST POPULATION CENTRE: Sainte-Justine
# LOCATION: Macamic
# CLOSEST POPULATION CENTRE: Macamic
# LOCATION: Ste-Hélène-de-Mancebourg
# CLOSEST POPULATION CENTRE: La Sarre
# LOCATION: Pointe-Fortune
# CLOSEST POPULATION CENTRE: Rigaud
# LOCATION: Coteau-Station
# CLOSEST POPULATION CENTRE: Les Coteaux
# LOCATION: Portage-Du-Fort
# CLOSEST POPULATION CENTRE: Shawville
# LOCATION: Sacré-Coeur
# CLOSEST POPULATION CENTRE: Les Escoumins
# LOCATION: Ste-Agnes-De-Dundee
# CLOSEST POPULATION CENTRE: Huntingdon
# LOCATION: Aston Jonction
# CLOSEST POPULATION CENTRE: Daveluyville
# LOCATION: Chapeau
# CLOSEST POPULATION CENTRE: Fort-Coulonge
# LOCATION: St-Juste-Du-Lac
# CLOSEST POPULATION CENTRE: Notre-Dame-du-Lac
# LOCATION: Ste-Marguerite-Marie
# CLOSEST POPULATION CENTRE: Causapscal
# LOCATION: St-Eugène-d'Argentenay
# CLOSEST POPULATION CENTRE: Dolbeau
# LOCATION: St-Gilbert
# CLOSEST POPULATION CENTRE: Saint-Marc-des-Carrières
# LOCATION: Stukely
# CLOSEST POPULATION CENTRE: Waterloo
# LOCATION: St-Theophile
# CLOSEST POPULATION CENTRE: Saint-Martin
# LOCATION: St-Léandre
# CLOSEST POPULATION CENTRE: Matane
# LOCATION: Ste-Lucie-De-Beauregard
# CLOSEST POPULATION CENTRE: Montmagny
# LOCATION: Ste-Germaine-Boule
# CLOSEST POPULATION CENTRE: Macamic
# LOCATION: St-Elzéar-De-Temiscouata
# CLOSEST POPULATION CENTRE: Cabano
# LOCATION: St-André-De-Restigouche
# CLOSEST POPULATION CENTRE: Pointe-à-la-Croix
# LOCATION: Aguanish
# CLOSEST POPULATION CENTRE: Havre-Saint-Pierre
# LOCATION: Lochaber
# CLOSEST POPULATION CENTRE: Thurso
# LOCATION: La Redemption
# CLOSEST POPULATION CENTRE: Price
# LOCATION: Griffintown
# CLOSEST POPULATION CENTRE: Le Plateau-Mont-Royal
# LOCATION: Rivière-A-Claude
# CLOSEST POPULATION CENTRE: Sainte-Anne-des-Monts
# LOCATION: L'Anse-À-Valleau
# CLOSEST POPULATION CENTRE: Rivière-au-Renard
# LOCATION: St-Cléophas-De-Brandon
# CLOSEST POPULATION CENTRE: Saint-Félix-de-Valois
# LOCATION: Rivière-Madeleine
# CLOSEST POPULATION CENTRE: Gaspé
# LOCATION: Cascapedia-St-Jules
# CLOSEST POPULATION CENTRE: Maria
# LOCATION: Les Hauteurs
# CLOSEST POPULATION CENTRE: Mont-Joli
# LOCATION: Bristol
# CLOSEST POPULATION CENTRE: Shawville
# LOCATION: St-Denis-sur-Mer
# UNKNOWN LOCATION: St-Denis-sur-Mer
# LOCATION: Laniel
# CLOSEST POPULATION CENTRE: Ville-Marie
# LOCATION: Cap-D'Espoir
# CLOSEST POPULATION CENTRE: Grande-Rivière
# LOCATION: St-Medard
# CLOSEST POPULATION CENTRE: Trois-Pistoles
# LOCATION: St-Gabriel-De-Kamouraska
# CLOSEST POPULATION CENTRE: La Pocatière
# LOCATION: Cap-au-Renard
# CLOSEST POPULATION CENTRE: Sainte-Anne-des-Monts
# LOCATION: Roquemaure
# CLOSEST POPULATION CENTRE: La Sarre
# LOCATION: St-Gabriel-Lalemant
# CLOSEST POPULATION CENTRE: La Pocatière
# LOCATION: St-Paul-De-La-Croix
# CLOSEST POPULATION CENTRE: Trois-Pistoles
# LOCATION: Thorne
# CLOSEST POPULATION CENTRE: Shawville
# LOCATION: Nicolet-Sud
# CLOSEST POPULATION CENTRE: Nicolet
# LOCATION: Rapide-Danseur
# CLOSEST POPULATION CENTRE: La Sarre
# LOCATION: St-Gerard-Majella
# CLOSEST POPULATION CENTRE: Pierreville
# LOCATION: Ste-Edwidge
# CLOSEST POPULATION CENTRE: Coaticook
# LOCATION: Ascot
# CLOSEST POPULATION CENTRE: Sherbrooke

# %%
town_dict = {}
town_dict["L'Ile Des Soeurs"] = "Ile des soeurs"
town_dict["St-Joseph-De-Ham-Sud"] = "Ham-Sud"
town_dict["St-Mathieu-De-Laprairie"] = "Saint-Mathieu"
town_dict["St-Denis-sur-Mer"] = "Saint-Denis"
town_dict["St-Isidore-De-Laprairie"] = "Saint-Isodore"
town_dict["St-Stanislas-De-Champlain"] = "Saint-Denis"
town_dict["St-Sebastien-De-Frontenac"] = "Saint-Sebastien"
town_dict["St-Simon-De-Rimouski"] = "Saint-Simon"
town_dict["Ste-Francoise-De-Lotbiniere"] = "Saint-Francoise"
town_dict["St-Guillaume-D'Upton"] = "Saint-Guillaume"
town_dict["St-Adelphe-De-Champlain"] = "Saint-Adelphe"

def fix_unknown(unknown: str):
    if unknown in town_dict.keys():
        return town_dict[unknown]
    elif "ND-" in unknown:
        return unknown.replace("ND-", "Notre-Dame-")
    elif "JC" in unknown:
        return unknown.replace("JC", "Jacques-Cartier")
    elif "St-" in unknown:
        return unknown.replace("St-", "Saint-")
    elif "Ste-" in unknown:
        return unknown.replace("Ste-", "Sainte-")
    elif "Sts-" in unknown:
        return unknown.replace("Sts-", "Saints-")
    else:
        return unknown

# %%
fixed_locations = list(map(fix_unknown, unknown_locations))
unknown_locations_mapper = {fixed_locations[i]: unknown_locations[i] for i in range(len(unknown_locations))}

# %%
location_mapper2, unknown_locations2 = find_closest_population_centre(fixed_locations, population_centres)
# Out:
# LOCATION: Ste-Catherine-de-la-Jacques-Cartier
# CLOSEST POPULATION CENTRE: Sainte-Catherine-de-la-Jacques-Cartier
# LOCATION: Notre-Dame-Des-Prairies
# CLOSEST POPULATION CENTRE: Joliette
# LOCATION: Notre-Dame-De-L'Ile-Perrot
# CLOSEST POPULATION CENTRE: Melocheville
# LOCATION: Notre-Dame-Du-Mont-Carmel
# CLOSEST POPULATION CENTRE: Notre-Dame-du-Mont-Carmel
# LOCATION: Ile des soeurs
# CLOSEST POPULATION CENTRE: Les Cèdres
# LOCATION: Saint-Mathieu
# CLOSEST POPULATION CENTRE: Saint-Michel
# LOCATION: Notre-Dame-Du-Bon-Conseil
# CLOSEST POPULATION CENTRE: Notre-Dame-du-Bon-Conseil
# LOCATION: Notre-Dame-Du-Laus
# CLOSEST POPULATION CENTRE: Maniwaki
# LOCATION: Saint-Isodore
# CLOSEST POPULATION CENTRE: Saint-Roch-de-l'Achigan
# LOCATION: Notre-Dame-De-Lourdes
# CLOSEST POPULATION CENTRE: Joliette
# LOCATION: Saint-Magloire-De-Bellechasse
# CLOSEST POPULATION CENTRE: Sainte-Justine
# LOCATION: Saints-Anges
# CLOSEST POPULATION CENTRE: Vallée-Jonction
# LOCATION: Notre-Dame-De-La-Merci
# CLOSEST POPULATION CENTRE: Saint-Donat-de-Montcalm
# LOCATION: Saint-Donat-De-Rimouski
# CLOSEST POPULATION CENTRE: Luceville
# LOCATION: Notre-Dame-De-La-Salette
# CLOSEST POPULATION CENTRE: Buckingham
# LOCATION: Saint-Denis
# CLOSEST POPULATION CENTRE: Contrecoeur
# LOCATION: Saint-Sebastien
# CLOSEST POPULATION CENTRE: Saint-Alexandre
# LOCATION: Notre-Dame-De-Montauban
# CLOSEST POPULATION CENTRE: Sainte-Thècle
# LOCATION: Saint-Marcel-De-L'Islet
# CLOSEST POPULATION CENTRE: Cap-Saint-Ignace
# LOCATION: Ham-Sud
# CLOSEST POPULATION CENTRE: Disraeli
# LOCATION: Notre-Dame-Des-Sept-Douleurs
# CLOSEST POPULATION CENTRE: Rivière-du-Loup
# LOCATION: Saint-Simon
# CLOSEST POPULATION CENTRE: Saint-Liboire
# LOCATION: Saint-Francoise
# CLOSEST POPULATION CENTRE: Trois-Pistoles
# LOCATION: Notre-Dame-De-Ham
# CLOSEST POPULATION CENTRE: Warwick
# LOCATION: Notre-Dame-de-Lourdes
# CLOSEST POPULATION CENTRE: Joliette
# LOCATION: Notre-Dame-De-La-Paix
# CLOSEST POPULATION CENTRE: Saint-André-Avellin
# LOCATION: Saint-Guillaume
# CLOSEST POPULATION CENTRE: Saint-Germain-de-Grantham
# LOCATION: Saint-Adelphe
# CLOSEST POPULATION CENTRE: Saint-Tite
# LOCATION: Notre-Dame-Des-Neiges-Trois-Pistoles
# CLOSEST POPULATION CENTRE: Trois-Pistoles
# LOCATION: Notre-Dame-De-Stanbridge
# CLOSEST POPULATION CENTRE: Bedford
# LOCATION: Saint-Severin-De-Beauce
# CLOSEST POPULATION CENTRE: Vallée-Jonction
# LOCATION: Saint-François-de-Montmagny
# CLOSEST POPULATION CENTRE: Saint-Raphaël
# LOCATION: Notre-Dame-De-Bonsecours
# CLOSEST POPULATION CENTRE: Saint-André-Avellin
# LOCATION: Saint-Denis
# CLOSEST POPULATION CENTRE: Contrecoeur

# %%
unknown_locations2
# Out:
# []

# %%
location_mapper2 = { unknown_locations_mapper.get(k, k): v for k, v in location_mapper2.items() }

# %%
location_mapper.update(location_mapper2)

# %%
with open('../data/processed/location_mapper.pkl', 'wb') as f:
    pickle.dump(location_mapper, f)
