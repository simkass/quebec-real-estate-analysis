# %% [markdown]
# # Location
# Raw data contains over a thousand different locations, some with very low occurences. This reduces the quality of the model. We must pick a handful of population centres as location data. Population centre for every raw location is chosen based on distance.

# %%
import numpy as np
import pandas as pd
import pickle

from geopy.distance import geodesic
from geopy.geocoders import Nominatim
from geopy.location import Location

# %% [markdown]
# ### Raw Locations

# %%
home_df = pd.read_csv('../data/raw/home_raw_listings.csv')
condo_df = pd.read_csv('../data/raw/condo_raw_listings.csv')
raw_df = pd.concat([home_df, condo_df], axis=0, ignore_index=True)
raw_locations = list(raw_df['location'].value_counts().to_dict().keys())

# %% [markdown]
# ### Population centers

# %%
population_centers = pd.read_csv('../data/wikipedia/cities.csv')
population_centers.head()
# Out:
#         Name
# 0   Montréal
# 1     Québec
# 2      Laval
# 3  Longueuil
# 4   Gatineau

# %% [markdown]
# Dropping Quebec, Montreal & Laval

# %%
population_centers = population_centers[population_centers['Name'] != 'Montréal']
population_centers = population_centers[population_centers['Name'] != 'Québec']
population_centers = population_centers[population_centers['Name'] != 'Laval']

# %% [markdown]
# Fixing town names

# %%
d = {'Ottawa - Gatineau (QC/ON)': 'Gatineau', 'Chicoutimi - Jonquière': 'Chicoutimi', 'Hawkesbury (QC/ON)': 'Grenville',
     'Campbellton (QC/NB)': 'Pointe-à-la-Croix', 'Port-Alfred-Bagotville': 'Bagotville', 'Sainte-Agathe-des-Monts -Val-David': 'Sainte-Agathe-des-Monts', 'Terrasse-des-Pins': 'Prévost', 'Domaine-C.-L.-C.': 'Saint-Lin–Laurentides'}
population_centers['Name'] = population_centers['Name'].replace(d)

# %% [markdown]
# Adding Quebec, Montreal & Laval Boroughs

# %%
mtl = pd.read_csv('../data/wikipedia/mtl-boroughs.csv')
laval = pd.read_csv('../data/wikipedia/laval-boroughs.csv')
quebec = pd.read_csv('../data/wikipedia/qc-boroughs.csv')

# %%
centers = list(population_centers['Name']) + list(mtl['Borough']) + list(laval['name']) + list(quebec['name'])

# %% [markdown]
# Finding geographical position for all population centers

# %%
geolocator = Nominatim(user_agent='housing-qc')

# %% [markdown]
# geolocator = Nominatim(user_agent='housing-qc')geolocator = Nominatim(user_agent='housing-qc')

# %%
center_dicts = []

for center in centers:
    print(center)
    geocode = geolocator.geocode(center + ', QC')
    center_dicts.append({'Name': center, 'Latitude': geocode.latitude, 'Longitude': geocode.longitude})

population_centers = pd.DataFrame(center_dicts)
population_centers.head()

# %%
population_centers.to_csv('../data/processed/population_centers.csv', index=False)

# %%
population_centers = pd.read_csv('../data/processed/population_centers.csv')

# %% [markdown]
# ### Matching Raw Locations with Population Centers

# %%
def find_closest_population_center(geocode: Location, population_centers: pd.DataFrame):
    distances = []

    for _, center in population_centers.iterrows():
        distances.append(geodesic((geocode.latitude, geocode.longitude), (center['Latitude'], center['Longitude'])))
    return population_centers.iloc[np.argmin(distances)]['Name']

# %%
def build_location_mapper(locations: list, population_centers: pd.DataFrame):
    location_mapper = {}
    unknown_locations = []

    for location in locations:
        geocode = geolocator.geocode(str(location) + ', QC', timeout=None)

        if geocode is None:
            unknown_locations.append(location)
            print('UNKNOWN LOCATION: ' + location)
        else:
            closest_center = find_closest_population_center(geocode, population_centers)
            location_mapper[location] = closest_center
            print('LOCATION: ' + location)
            print('CLOSEST POPULATION center: ' + closest_center)

    return location_mapper, unknown_locations

# %%
location_mapper, unknown_locations = build_location_mapper(raw_locations, population_centers)
# Out:
# LOCATION: Gatineau
# CLOSEST POPULATION center: Gatineau
# LOCATION: Trois-Rivières
# CLOSEST POPULATION center: Trois-Rivières
# LOCATION: Beauport
# CLOSEST POPULATION center: Beauport
# LOCATION: Mercier
# CLOSEST POPULATION center: Mercier
# LOCATION: Alma
# CLOSEST POPULATION center: Alma
# LOCATION: Fabreville
# CLOSEST POPULATION center: Fabreville
# LOCATION: Sherbrooke
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: Ste-Marthe-Sur-Le-Lac
# CLOSEST POPULATION center: Sainte-Marthe-sur-le-Lac
# LOCATION: Stoneham
# CLOSEST POPULATION center: La Haute-Saint-Charles
# LOCATION: St-Ferréol-les-Neiges
# CLOSEST POPULATION center: Montmagny
# LOCATION: Longueuil
# CLOSEST POPULATION center: Longueuil
# LOCATION: Deschambault
# CLOSEST POPULATION center: Pont-Rouge
# LOCATION: St-Raymond
# CLOSEST POPULATION center: Saint-Raymond
# LOCATION: Charlesbourg
# CLOSEST POPULATION center: Charlesbourg
# LOCATION: Terrebonne
# CLOSEST POPULATION center: Terrebonne
# LOCATION: Drummondville
# CLOSEST POPULATION center: Drummondville
# LOCATION: Ste-Foy
# CLOSEST POPULATION center: Sainte-Foy-Sillery-Cap-Rouge
# LOCATION: Rosemont
# CLOSEST POPULATION center: Outremont
# LOCATION: St-Jean-sur-Richelieu
# CLOSEST POPULATION center: Saint-Jean-sur-Richelieu
# LOCATION: Repentigny
# CLOSEST POPULATION center: Repentigny
# LOCATION: Brossard
# CLOSEST POPULATION center: Brossard
# LOCATION: Lévis
# CLOSEST POPULATION center: Lévis
# LOCATION: Berthier-Sur-Mer
# CLOSEST POPULATION center: Montmagny
# LOCATION: Boucherville
# CLOSEST POPULATION center: Boucherville
# LOCATION: Le Plateau-Mont-Royal
# CLOSEST POPULATION center: Le Plateau-Mont-Royal
# LOCATION: Chicoutimi
# CLOSEST POPULATION center: Chicoutimi
# LOCATION: St-Jérôme
# CLOSEST POPULATION center: Saint-Jérôme
# LOCATION: Granby
# CLOSEST POPULATION center: Granby
# LOCATION: Chambly
# CLOSEST POPULATION center: Chambly
# LOCATION: Jonquière
# CLOSEST POPULATION center: Jonquière
# LOCATION: Mascouche
# CLOSEST POPULATION center: Mascouche
# LOCATION: St-Nicolas
# CLOSEST POPULATION center: Saint-Augustin-de-Desmaures
# LOCATION: Blainville
# CLOSEST POPULATION center: Blainville
# LOCATION: Lebourgneuf
# CLOSEST POPULATION center: Les Rivières
# LOCATION: Mirabel
# CLOSEST POPULATION center: Mirabel
# LOCATION: Val-Bélair
# CLOSEST POPULATION center: La Haute-Saint-Charles
# LOCATION: Rimouski
# CLOSEST POPULATION center: Rimouski
# LOCATION: Ste-Julie
# CLOSEST POPULATION center: Sainte-Julie
# LOCATION: Neufchatel
# CLOSEST POPULATION center: Les Rivières
# LOCATION: St-Eustache
# CLOSEST POPULATION center: Saint-Eustache
# LOCATION: Magog
# CLOSEST POPULATION center: Magog
# LOCATION: Ville-Marie
# CLOSEST POPULATION center: Ville-Marie
# LOCATION: Ahuntsic
# CLOSEST POPULATION center: Pont-Viau
# LOCATION: Chomedey
# CLOSEST POPULATION center: Chomedey
# LOCATION: Victoriaville
# CLOSEST POPULATION center: Victoriaville
# LOCATION: St-Augustin-De-Desmaures
# CLOSEST POPULATION center: Saint-Augustin-de-Desmaures
# LOCATION: St-Bruno-De-Montarville
# CLOSEST POPULATION center: Saint-Bruno-de-Montarville
# LOCATION: St-Jean-Chrysostome
# CLOSEST POPULATION center: Lévis
# LOCATION: Pointe-Aux-Trembles
# CLOSEST POPULATION center: Rivière-des-Prairies–Pointe-aux-Trembles
# LOCATION: La Prairie
# CLOSEST POPULATION center: La Prairie
# LOCATION: St-Hyacinthe
# CLOSEST POPULATION center: Saint-Hyacinthe
# LOCATION: Varennes
# CLOSEST POPULATION center: Varennes
# LOCATION: Beloeil
# CLOSEST POPULATION center: Beloeil
# LOCATION: Ste-Rose
# CLOSEST POPULATION center: Sainte-Rose
# LOCATION: Villeray
# CLOSEST POPULATION center: Villeray–Saint-Michel–Parc-Extension
# LOCATION: Mont-St-Hilaire
# CLOSEST POPULATION center: Mont-Saint-Hilaire
# LOCATION: St-Émile
# CLOSEST POPULATION center: Les Rivières
# LOCATION: Vaudreuil-Dorion
# CLOSEST POPULATION center: Vaudreuil-Dorion
# LOCATION: Le Sud-Ouest
# CLOSEST POPULATION center: Le Sud-Ouest
# LOCATION: Candiac
# CLOSEST POPULATION center: Candiac
# LOCATION: Bromont
# CLOSEST POPULATION center: Bromont
# LOCATION: Shawinigan
# CLOSEST POPULATION center: Shawinigan
# LOCATION: Montcalm
# CLOSEST POPULATION center: Sainte-Agathe-des-Monts
# LOCATION: Cap-Rouge
# CLOSEST POPULATION center: Sainte-Foy-Sillery-Cap-Rouge
# LOCATION: St-Georges
# CLOSEST POPULATION center: Saint-Georges
# LOCATION: St-Constant
# CLOSEST POPULATION center: Saint-Constant
# LOCATION: St-Basile-Le-Grand
# CLOSEST POPULATION center: Saint-Basile-le-Grand
# LOCATION: St-Romuald
# CLOSEST POPULATION center: Lévis
# LOCATION: L'Assomption
# CLOSEST POPULATION center: L'Assomption
# LOCATION: Saint-Laurent
# CLOSEST POPULATION center: Saint-Laurent
# LOCATION: L'Ancienne-Lorette
# CLOSEST POPULATION center: L'Ancienne-Lorette
# LOCATION: Chateauguay
# CLOSEST POPULATION center: Châteauguay
# LOCATION: Boisbriand
# CLOSEST POPULATION center: Boisbriand
# LOCATION: Lachine
# CLOSEST POPULATION center: Lachine
# LOCATION: St-Étienne-De-Lauzon
# CLOSEST POPULATION center: Sainte-Foy-Sillery-Cap-Rouge
# LOCATION: Verdun
# CLOSEST POPULATION center: Verdun
# LOCATION: St-Lambert
# CLOSEST POPULATION center: Rouyn-Noranda
# LOCATION: Ste-Dorothée
# CLOSEST POPULATION center: Sainte-Dorothée
# LOCATION: Limoilou
# CLOSEST POPULATION center: La Cité-Limoilou
# LOCATION: Sorel-Tracy
# CLOSEST POPULATION center: Sorel-Tracy
# LOCATION: Ste-Therese
# CLOSEST POPULATION center: Sainte-Thérèse
# LOCATION: Ste-Catherine
# CLOSEST POPULATION center: Sainte-Catherine
# LOCATION: Ste-Marie
# CLOSEST POPULATION center: Sainte-Marie
# LOCATION: Duberger
# CLOSEST POPULATION center: Les Rivières
# LOCATION: Auteuil
# CLOSEST POPULATION center: Auteuil
# LOCATION: Côte-des-Neiges
# CLOSEST POPULATION center: Outremont
# LOCATION: Val-Des-Monts
# CLOSEST POPULATION center: Val-des-Monts
# LOCATION: Vimont
# CLOSEST POPULATION center: Vimont
# LOCATION: Bécancour
# CLOSEST POPULATION center: Bécancour
# LOCATION: St-Rédempteur
# CLOSEST POPULATION center: Sainte-Foy-Sillery-Cap-Rouge
# LOCATION: St-Colomban
# CLOSEST POPULATION center: Saint-Colomban
# LOCATION: Pierrefonds
# CLOSEST POPULATION center: Pierrefonds-Roxboro
# LOCATION: Marieville
# CLOSEST POPULATION center: Marieville
# LOCATION: Breakeyville
# CLOSEST POPULATION center: Lévis
# LOCATION: Rivière des Prairies
# CLOSEST POPULATION center: Laval-des-Rapides
# LOCATION: Ste-Adèle
# CLOSEST POPULATION center: Sainte-Adèle
# LOCATION: Deux-Montagnes
# CLOSEST POPULATION center: Deux-Montagnes
# LOCATION: Laval-des-Rapides
# CLOSEST POPULATION center: Laval-des-Rapides
# LOCATION: Orford
# CLOSEST POPULATION center: Magog
# LOCATION: Loretteville
# CLOSEST POPULATION center: Les Rivières
# LOCATION: Charny
# CLOSEST POPULATION center: Sainte-Foy-Sillery-Cap-Rouge
# LOCATION: Duvernay
# CLOSEST POPULATION center: Duvernay
# LOCATION: Pont-Rouge
# CLOSEST POPULATION center: Pont-Rouge
# LOCATION: Carignan
# CLOSEST POPULATION center: Carignan
# UNKNOWN LOCATION: L'Ile Des Soeurs
# LOCATION: Cantley
# CLOSEST POPULATION center: Cantley
# LOCATION: Salaberry-De-Valleyfield
# CLOSEST POPULATION center: Salaberry-de-Valleyfield
# LOCATION: Prévost
# CLOSEST POPULATION center: Prévost
# LOCATION: Anjou
# CLOSEST POPULATION center: Anjou
# LOCATION: Ste-Sophie
# CLOSEST POPULATION center: Sainte-Sophie
# LOCATION: Lac-St-Charles
# CLOSEST POPULATION center: La Haute-Saint-Charles
# UNKNOWN LOCATION: Ste-Catherine-de-la-JC
# LOCATION: St-Sauveur
# CLOSEST POPULATION center: Saint-Sauveur
# LOCATION: Sillery
# CLOSEST POPULATION center: La Cité-Limoilou
# LOCATION: LaSalle
# CLOSEST POPULATION center: LaSalle
# LOCATION: Contrecoeur
# CLOSEST POPULATION center: Lavaltrie
# LOCATION: St-Amable
# CLOSEST POPULATION center: Saint-Amable
# LOCATION: Pintendre
# CLOSEST POPULATION center: Lévis
# LOCATION: Lac-Beauport
# CLOSEST POPULATION center: Charlesbourg
# LOCATION: Rosemère
# CLOSEST POPULATION center: Rosemère
# LOCATION: Joliette
# CLOSEST POPULATION center: Joliette
# LOCATION: La Baie
# CLOSEST POPULATION center: Jonquière
# LOCATION: Otterburn Park
# CLOSEST POPULATION center: Mont-Saint-Hilaire
# LOCATION: Bois-Des-Filion
# CLOSEST POPULATION center: Bois-des-Filion
# LOCATION: St-Lin-Laurentides
# CLOSEST POPULATION center: Saint-Lin - Laurentides
# LOCATION: Shefford
# CLOSEST POPULATION center: Bromont
# LOCATION: St-Hippolyte
# CLOSEST POPULATION center: Saint-Hippolyte
# LOCATION: Donnacona
# CLOSEST POPULATION center: Pont-Rouge
# LOCATION: Saint-Sacrement
# CLOSEST POPULATION center: La Cité-Limoilou
# LOCATION: Boischatel
# CLOSEST POPULATION center: Beauport
# LOCATION: Outremont
# CLOSEST POPULATION center: Outremont
# LOCATION: Montréal-Nord
# CLOSEST POPULATION center: Montréal-Nord
# LOCATION: Lavaltrie
# CLOSEST POPULATION center: Lavaltrie
# LOCATION: Pincourt
# CLOSEST POPULATION center: Pincourt
# LOCATION: Griffintown
# CLOSEST POPULATION center: Le Plateau-Mont-Royal
# LOCATION: Lorraine
# CLOSEST POPULATION center: Bois-des-Filion
# LOCATION: St-Henri-de-Lévis
# CLOSEST POPULATION center: Lévis
# LOCATION: Les Saules
# CLOSEST POPULATION center: L'Ancienne-Lorette
# LOCATION: Rivière-Du-Loup
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: St-Lazare
# CLOSEST POPULATION center: Saint-Lazare
# LOCATION: St-Charles-Borromée
# CLOSEST POPULATION center: Saint-Charles-Borromée
# LOCATION: St-Lambert-De-Lauzon
# CLOSEST POPULATION center: Sainte-Marie
# LOCATION: Cowansville
# CLOSEST POPULATION center: Cowansville
# LOCATION: St-François
# CLOSEST POPULATION center: Saint-François
# LOCATION: Beaupré
# CLOSEST POPULATION center: Beauport
# LOCATION: Rawdon
# CLOSEST POPULATION center: Rawdon
# LOCATION: St-Rémi
# CLOSEST POPULATION center: Mercier
# UNKNOWN LOCATION: ND-Des-Prairies
# LOCATION: Delson
# CLOSEST POPULATION center: Saint-Constant
# LOCATION: L'île-Bizard
# CLOSEST POPULATION center: Pierrefonds-Roxboro
# LOCATION: St-Apollinaire
# CLOSEST POPULATION center: Saint-Augustin-de-Desmaures
# LOCATION: Mont-Tremblant
# CLOSEST POPULATION center: Mont-Tremblant
# LOCATION: Pointe-Claire
# CLOSEST POPULATION center: Pointe-Claire
# LOCATION: Nicolet
# CLOSEST POPULATION center: Trois-Rivières
# LOCATION: Chelsea
# CLOSEST POPULATION center: Cantley
# LOCATION: Ste-Brigitte-De-Laval
# CLOSEST POPULATION center: Beauport
# LOCATION: Ste-Anne-Des-Plaines
# CLOSEST POPULATION center: Sainte-Anne-des-Plaines
# LOCATION: Vanier
# CLOSEST POPULATION center: La Cité-Limoilou
# LOCATION: Laval-Ouest
# CLOSEST POPULATION center: Laval-Ouest
# LOCATION: Dollard-Des-Ormeaux
# CLOSEST POPULATION center: Dollard-Des Ormeaux
# LOCATION: Sutton
# CLOSEST POPULATION center: Cowansville
# LOCATION: Ste-Julienne
# CLOSEST POPULATION center: Sainte-Julienne
# LOCATION: Montchatel
# CLOSEST POPULATION center: La Haute-Saint-Charles
# LOCATION: Ste-Agathe-Des-Monts
# CLOSEST POPULATION center: Sainte-Agathe-des-Monts
# LOCATION: St-Joseph-Du-Lac
# CLOSEST POPULATION center: Sainte-Marthe-sur-le-Lac
# LOCATION: Piedmont
# CLOSEST POPULATION center: Saint-Sauveur
# LOCATION: Neuville
# CLOSEST POPULATION center: Pont-Rouge
# LOCATION: Saint-Roch
# CLOSEST POPULATION center: La Cité-Limoilou
# LOCATION: Roberval
# CLOSEST POPULATION center: Roberval
# LOCATION: Baie-Comeau
# CLOSEST POPULATION center: Matane
# LOCATION: L'Ange-Gardien-Outaouais
# CLOSEST POPULATION center: Gatineau
# LOCATION: St-Félicien
# CLOSEST POPULATION center: Saint-Félicien
# LOCATION: McMasterville
# CLOSEST POPULATION center: Beloeil
# LOCATION: Thetford Mines
# CLOSEST POPULATION center: Thetford Mines
# LOCATION: Montmagny
# CLOSEST POPULATION center: Montmagny
# LOCATION: Val-David
# CLOSEST POPULATION center: Sainte-Agathe-des-Monts
# LOCATION: St-Vincent-de-Paul
# CLOSEST POPULATION center: Montréal-Nord
# LOCATION: La Malbaie
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: St-Honore-De-Chicoutimi
# CLOSEST POPULATION center: Jonquière
# LOCATION: Saint-Sauveur
# CLOSEST POPULATION center: Saint-Sauveur
# LOCATION: St-Paul
# CLOSEST POPULATION center: Joliette
# LOCATION: Beauharnois
# CLOSEST POPULATION center: Beauharnois
# LOCATION: L'Ile-Perrot
# CLOSEST POPULATION center: L'Île-Perrot
# LOCATION: St-Zotique
# CLOSEST POPULATION center: Salaberry-de-Valleyfield
# LOCATION: La Pêche
# CLOSEST POPULATION center: Cantley
# LOCATION: Richelieu
# CLOSEST POPULATION center: Chambly
# LOCATION: Verchères
# CLOSEST POPULATION center: L'Assomption
# LOCATION: St-Philippe
# CLOSEST POPULATION center: Candiac
# LOCATION: Dolbeau-Mistassini
# CLOSEST POPULATION center: Dolbeau-Mistassini
# LOCATION: Shannon
# CLOSEST POPULATION center: La Haute-Saint-Charles
# LOCATION: St-Jean-Baptiste
# CLOSEST POPULATION center: Mont-Saint-Hilaire
# LOCATION: St-Cyrille-De-Wendover
# CLOSEST POPULATION center: Drummondville
# LOCATION: Ile d'Orléans
# CLOSEST POPULATION center: Beauport
# LOCATION: St-Cesaire
# CLOSEST POPULATION center: Marieville
# UNKNOWN LOCATION: ND-De-L'Ile-Perrot
# LOCATION: Farnham
# CLOSEST POPULATION center: Farnham
# LOCATION: St-Adolphe-D'Howard
# CLOSEST POPULATION center: Sainte-Agathe-des-Monts
# LOCATION: St-Anselme
# CLOSEST POPULATION center: Sainte-Marie
# LOCATION: L'Épiphanie
# CLOSEST POPULATION center: L'Assomption
# LOCATION: Pont-Viau
# CLOSEST POPULATION center: Pont-Viau
# LOCATION: Lachute
# CLOSEST POPULATION center: Lachute
# LOCATION: Château-Richer
# CLOSEST POPULATION center: Beauport
# LOCATION: Dorval
# CLOSEST POPULATION center: Dorval
# LOCATION: Matane
# CLOSEST POPULATION center: Matane
# LOCATION: St-Agapit
# CLOSEST POPULATION center: Saint-Augustin-de-Desmaures
# LOCATION: Vieux-Québec
# CLOSEST POPULATION center: La Cité-Limoilou
# LOCATION: St-Faustin-Lac-Carré
# CLOSEST POPULATION center: Mont-Tremblant
# LOCATION: Les Côteaux
# CLOSEST POPULATION center: Salaberry-de-Valleyfield
# LOCATION: Baie-St-Paul
# CLOSEST POPULATION center: Montmagny
# LOCATION: St-Denis-De-Brompton
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: Saint-Léonard
# CLOSEST POPULATION center: Saint-Léonard
# LOCATION: L'Ange-Gardien
# CLOSEST POPULATION center: Beauport
# LOCATION: Eastman
# CLOSEST POPULATION center: Magog
# LOCATION: Charlemagne
# CLOSEST POPULATION center: Repentigny
# LOCATION: St-Mathias-sur-Richelieu
# CLOSEST POPULATION center: Chambly
# UNKNOWN LOCATION: ND-Du-Mont-Carmel
# LOCATION: Pointe-Calumet
# CLOSEST POPULATION center: Sainte-Marthe-sur-le-Lac
# LOCATION: Chertsey
# CLOSEST POPULATION center: Rawdon
# LOCATION: Val-des-Sources
# CLOSEST POPULATION center: Victoriaville
# LOCATION: Lac-Brome
# CLOSEST POPULATION center: Bromont
# LOCATION: Gaspé
# CLOSEST POPULATION center: Gaspé
# LOCATION: Sept-Iles
# CLOSEST POPULATION center: Sept-Îles
# LOCATION: Morin-Heights
# CLOSEST POPULATION center: Saint-Sauveur
# LOCATION: Napierville
# CLOSEST POPULATION center: Saint-Jean-sur-Richelieu
# LOCATION: Les Cèdres
# CLOSEST POPULATION center: Salaberry-de-Valleyfield
# LOCATION: Mont-Laurier
# CLOSEST POPULATION center: Mont-Laurier
# LOCATION: Waterloo
# CLOSEST POPULATION center: Bromont
# LOCATION: Fossambault-Sur-Le-Lac
# CLOSEST POPULATION center: Pont-Rouge
# LOCATION: Duvernay-Est
# CLOSEST POPULATION center: Duvernay
# LOCATION: St-Germain-De-Grantham
# CLOSEST POPULATION center: Drummondville
# LOCATION: St-Côme
# CLOSEST POPULATION center: Rawdon
# LOCATION: Cap-Santé
# CLOSEST POPULATION center: Pont-Rouge
# LOCATION: St-Donat
# CLOSEST POPULATION center: Sainte-Agathe-des-Monts
# LOCATION: Ascot Corner
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: Roxton Pond
# CLOSEST POPULATION center: Granby
# LOCATION: Louiseville
# CLOSEST POPULATION center: Sorel-Tracy
# LOCATION: St-David-de-Falardeau
# CLOSEST POPULATION center: Jonquière
# LOCATION: Beauceville
# CLOSEST POPULATION center: Saint-Georges
# LOCATION: Lac-Mégantic
# CLOSEST POPULATION center: Saint-Martin
# LOCATION: Lac-Etchemin
# CLOSEST POPULATION center: Saint-Georges
# LOCATION: Mont-Joli
# CLOSEST POPULATION center: Rimouski
# LOCATION: Scott
# CLOSEST POPULATION center: Sainte-Marie
# LOCATION: Coteau-Du-Lac
# CLOSEST POPULATION center: Salaberry-de-Valleyfield
# LOCATION: Ste-Martine
# CLOSEST POPULATION center: Mercier
# LOCATION: Mont-Royal
# CLOSEST POPULATION center: Mont-Royal
# LOCATION: Plessisville
# CLOSEST POPULATION center: Victoriaville
# LOCATION: Windsor
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: Rivière-Rouge
# CLOSEST POPULATION center: Mont-Tremblant
# LOCATION: St-Ambroise
# CLOSEST POPULATION center: Jonquière
# LOCATION: St-Charles-De-Bellechasse
# CLOSEST POPULATION center: Lévis
# LOCATION: Portneuf
# CLOSEST POPULATION center: Pont-Rouge
# LOCATION: St-Jean-De-Matha
# CLOSEST POPULATION center: Saint-Charles-Borromée
# LOCATION: St-Sulpice
# CLOSEST POPULATION center: L'Assomption
# LOCATION: Acton Vale
# CLOSEST POPULATION center: Drummondville
# LOCATION: Ste-Anne-Des-Lacs
# CLOSEST POPULATION center: Prévost
# LOCATION: Beaumont
# CLOSEST POPULATION center: Lévis
# LOCATION: St-Boniface
# CLOSEST POPULATION center: Shawinigan
# LOCATION: St-Félix-De-Valois
# CLOSEST POPULATION center: Saint-Charles-Borromée
# LOCATION: St-Bruno
# CLOSEST POPULATION center: Alma
# LOCATION: Kirkland
# CLOSEST POPULATION center: Kirkland
# LOCATION: Ste-Claire
# CLOSEST POPULATION center: Sainte-Marie
# LOCATION: Beaconsfield
# CLOSEST POPULATION center: Beaconsfield
# LOCATION: Val-Morin
# CLOSEST POPULATION center: Sainte-Adèle
# LOCATION: St-Elzéar-de-Beauce
# CLOSEST POPULATION center: Sainte-Marie
# LOCATION: St-Mathieu-De-Beloeil
# CLOSEST POPULATION center: Beloeil
# LOCATION: St-Isidore
# CLOSEST POPULATION center: Sainte-Marie
# LOCATION: Rouyn-Noranda
# CLOSEST POPULATION center: Rouyn-Noranda
# LOCATION: Dunham
# CLOSEST POPULATION center: Cowansville
# LOCATION: Berthierville
# CLOSEST POPULATION center: Sorel-Tracy
# LOCATION: St-Pie
# CLOSEST POPULATION center: Saint-Hyacinthe
# LOCATION: St-Étienne-Des-Gres
# CLOSEST POPULATION center: Shawinigan
# LOCATION: Ste-Catherine-De-Hatley
# CLOSEST POPULATION center: Magog
# LOCATION: Ste-Marguerite-Du-Lac-Masson
# CLOSEST POPULATION center: Sainte-Adèle
# LOCATION: Coaticook
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: Oka
# CLOSEST POPULATION center: Saint-Lazare
# LOCATION: Princeville
# CLOSEST POPULATION center: Victoriaville
# LOCATION: St-Michel
# CLOSEST POPULATION center: Saint-Constant
# LOCATION: Rigaud
# CLOSEST POPULATION center: Saint-Lazare
# LOCATION: St-Gilles
# CLOSEST POPULATION center: Sainte-Marie
# LOCATION: St-Calixte
# CLOSEST POPULATION center: Sainte-Julienne
# LOCATION: St-Maurice
# CLOSEST POPULATION center: Trois-Rivières
# LOCATION: Venise-En-Quebec
# CLOSEST POPULATION center: Saint-Jean-sur-Richelieu
# LOCATION: St-Joseph-De-Beauce
# CLOSEST POPULATION center: Sainte-Marie
# LOCATION: Ste-Croix
# CLOSEST POPULATION center: Pont-Rouge
# LOCATION: Hébertville
# CLOSEST POPULATION center: Alma
# LOCATION: Austin
# CLOSEST POPULATION center: Magog
# LOCATION: Métabetchouan-Lac-à-la-Croix
# CLOSEST POPULATION center: Alma
# LOCATION: Notre-Dame-des-Pins
# CLOSEST POPULATION center: Saint-Georges
# LOCATION: St-Damien
# CLOSEST POPULATION center: Saint-Charles-Borromée
# LOCATION: St-André-Avellin
# CLOSEST POPULATION center: Val-des-Monts
# LOCATION: St-Jacques
# CLOSEST POPULATION center: Sainte-Julienne
# LOCATION: Luskville
# CLOSEST POPULATION center: Cantley
# LOCATION: Champlain
# CLOSEST POPULATION center: Bécancour
# LOCATION: St-Ambroise-De-Kildare
# CLOSEST POPULATION center: Saint-Charles-Borromée
# LOCATION: Ste-Luce
# CLOSEST POPULATION center: Rimouski
# LOCATION: L'Islet
# CLOSEST POPULATION center: Montmagny
# LOCATION: St-Gabriel-De-Brandon
# CLOSEST POPULATION center: Saint-Charles-Borromée
# LOCATION: St-Antoine-De-Tilly
# CLOSEST POPULATION center: Saint-Augustin-de-Desmaures
# LOCATION: Lanoraie
# CLOSEST POPULATION center: Lavaltrie
# LOCATION: St-Anaclet-De-Lessard
# CLOSEST POPULATION center: Rimouski
# LOCATION: St-Basile-De-Portneuf
# CLOSEST POPULATION center: Pont-Rouge
# LOCATION: St-Bernard
# CLOSEST POPULATION center: Sainte-Marie
# LOCATION: East Angus
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: Côte-St-Luc
# CLOSEST POPULATION center: Côte-Saint-Luc
# LOCATION: St-Alphonse-Rodriguez
# CLOSEST POPULATION center: Rawdon
# LOCATION: St-Marc-sur-Richelieu
# CLOSEST POPULATION center: Saint-Amable
# UNKNOWN LOCATION: St-Mathieu-De-Laprairie
# LOCATION: St-Roch-De-Richelieu
# CLOSEST POPULATION center: Lavaltrie
# LOCATION: St-Malachie
# CLOSEST POPULATION center: Sainte-Marie
# LOCATION: Québec
# CLOSEST POPULATION center: La Cité-Limoilou
# LOCATION: Carleton-sur-Mer
# CLOSEST POPULATION center: Gaspé
# LOCATION: St-Roch-De-L'Achigan
# CLOSEST POPULATION center: Mascouche
# UNKNOWN LOCATION: ND-Du-Bon-Conseil
# LOCATION: St-Gabriel-De-Valcartier
# CLOSEST POPULATION center: La Haute-Saint-Charles
# LOCATION: St-Mathieu-Du-Parc
# CLOSEST POPULATION center: Shawinigan
# LOCATION: St-Alexandre-D'Iberville
# CLOSEST POPULATION center: Farnham
# LOCATION: Thurso
# CLOSEST POPULATION center: Val-des-Monts
# LOCATION: St-Jean-Port-Joli
# CLOSEST POPULATION center: Montmagny
# LOCATION: Ste-Thecle
# CLOSEST POPULATION center: Baie-eau
# LOCATION: Brownsburg-Chatham
# CLOSEST POPULATION center: Lachute
# LOCATION: Port-Cartier
# CLOSEST POPULATION center: Sept-Îles
# LOCATION: Valcourt
# CLOSEST POPULATION center: Magog
# LOCATION: Nominingue
# CLOSEST POPULATION center: Mont-Laurier
# LOCATION: Mont-St-Gregoire
# CLOSEST POPULATION center: Saint-Jean-sur-Richelieu
# LOCATION: St-Léonard-D'Aston
# CLOSEST POPULATION center: Bécancour
# LOCATION: St-Prime
# CLOSEST POPULATION center: Saint-Félicien
# LOCATION: Ange-Gardien-de-Rouville
# CLOSEST POPULATION center: Farnham
# LOCATION: St-Alphonse-de-Granby
# CLOSEST POPULATION center: Granby
# LOCATION: Cookshire-Eaton
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: Ste-Madeleine
# CLOSEST POPULATION center: Mont-Saint-Hilaire
# LOCATION: Vieux-Port
# CLOSEST POPULATION center: Le Plateau-Mont-Royal
# LOCATION: St-Tite
# CLOSEST POPULATION center: Shawinigan
# LOCATION: Waterville
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: Ste-Mélanie
# CLOSEST POPULATION center: Saint-Charles-Borromée
# LOCATION: Stoke
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: Dudswell
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: Compton
# CLOSEST POPULATION center: Sherbrooke
# UNKNOWN LOCATION: ND-Du-Laus
# LOCATION: La Pocatiere
# CLOSEST POPULATION center: Montmagny
# LOCATION: St-Alexis-Des-Monts
# CLOSEST POPULATION center: Shawinigan
# LOCATION: Weedon
# CLOSEST POPULATION center: Thetford Mines
# LOCATION: Laurier-Station
# CLOSEST POPULATION center: Pont-Rouge
# LOCATION: L'Anse-St-Jean
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Maniwaki
# CLOSEST POPULATION center: Mont-Laurier
# LOCATION: Chambord
# CLOSEST POPULATION center: Roberval
# LOCATION: St-Liboire
# CLOSEST POPULATION center: Saint-Hyacinthe
# LOCATION: Lac-Superieur
# CLOSEST POPULATION center: Mont-Tremblant
# LOCATION: St-Antoine-sur-Richelieu
# CLOSEST POPULATION center: Lavaltrie
# LOCATION: Amqui
# CLOSEST POPULATION center: Matane
# LOCATION: Tewkesbury
# CLOSEST POPULATION center: La Haute-Saint-Charles
# LOCATION: Saint-Gédéon
# CLOSEST POPULATION center: Alma
# LOCATION: Témiscouata-sur-le-Lac
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Wickham
# CLOSEST POPULATION center: Drummondville
# LOCATION: Mandeville
# CLOSEST POPULATION center: Saint-Charles-Borromée
# LOCATION: Ste-Cécile-De-Milton
# CLOSEST POPULATION center: Granby
# LOCATION: St-Damien-De-Buckland
# CLOSEST POPULATION center: Sainte-Marie
# LOCATION: Yamachiche
# CLOSEST POPULATION center: Trois-Rivières
# LOCATION: Potton
# CLOSEST POPULATION center: Magog
# LOCATION: Danville
# CLOSEST POPULATION center: Victoriaville
# LOCATION: St-Prosper-De-Dorchester
# CLOSEST POPULATION center: Saint-Georges
# LOCATION: Lac-Delage
# CLOSEST POPULATION center: La Haute-Saint-Charles
# LOCATION: Warwick
# CLOSEST POPULATION center: Victoriaville
# LOCATION: Richmond
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: St-Gervais
# CLOSEST POPULATION center: Lévis
# LOCATION: Lacolle
# CLOSEST POPULATION center: Saint-Jean-sur-Richelieu
# LOCATION: St-Christophe-D'Arthabaska
# CLOSEST POPULATION center: Victoriaville
# LOCATION: Degelis
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Ste-Anne-De-Sorel
# CLOSEST POPULATION center: Sorel-Tracy
# UNKNOWN LOCATION: St-Isidore-De-Laprairie
# LOCATION: Brigham
# CLOSEST POPULATION center: Cowansville
# LOCATION: St-François-Xavier-De-Brompton
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: St-Fulgence
# CLOSEST POPULATION center: Jonquière
# LOCATION: St-Pierre-Les-Becquets
# CLOSEST POPULATION center: Baie-eau
# LOCATION: Crabtree
# CLOSEST POPULATION center: Joliette
# LOCATION: Rougemont
# CLOSEST POPULATION center: Marieville
# LOCATION: La Presentation
# CLOSEST POPULATION center: Saint-Hyacinthe
# LOCATION: Stukely-Sud
# CLOSEST POPULATION center: Bromont
# LOCATION: Papineauville
# CLOSEST POPULATION center: Val-des-Monts
# LOCATION: St-Lucien
# CLOSEST POPULATION center: Drummondville
# LOCATION: Ayer's Cliff
# CLOSEST POPULATION center: Magog
# LOCATION: Ste-Beatrix
# CLOSEST POPULATION center: Rawdon
# LOCATION: St-Jacques-Le-Mineur
# CLOSEST POPULATION center: Saint-Vincent-de-Paul
# LOCATION: Stratford
# CLOSEST POPULATION center: Thetford Mines
# LOCATION: St-Michel-de-Bellechasse
# CLOSEST POPULATION center: Lévis
# LOCATION: St-Denis-sur-Richelieu
# CLOSEST POPULATION center: Lavaltrie
# LOCATION: St-Elie-de-Caxton
# CLOSEST POPULATION center: Shawinigan
# LOCATION: Wentworth-Nord
# CLOSEST POPULATION center: Lachute
# LOCATION: St-Anicet
# CLOSEST POPULATION center: Salaberry-de-Valleyfield
# LOCATION: St-Côme-Linière
# CLOSEST POPULATION center: Saint-Georges
# LOCATION: Entrelacs
# CLOSEST POPULATION center: Saint-Hippolyte
# LOCATION: St-Victor
# CLOSEST POPULATION center: Saint-Georges
# LOCATION: Bolton-Est
# CLOSEST POPULATION center: Magog
# LOCATION: St-Paul-De-L'Ile-Aux-Noix
# CLOSEST POPULATION center: Saint-Jean-sur-Richelieu
# LOCATION: Ste-Angèle-De-Monnoir
# CLOSEST POPULATION center: Marieville
# LOCATION: Gore
# CLOSEST POPULATION center: Saint-Colomban
# LOCATION: Trois-Pistoles
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Larouche
# CLOSEST POPULATION center: Alma
# LOCATION: St-Michel-Des-Saints
# CLOSEST POPULATION center: Rawdon
# LOCATION: St-Liguori
# CLOSEST POPULATION center: Saint-Charles-Borromée
# LOCATION: St-Polycarpe
# CLOSEST POPULATION center: Salaberry-de-Valleyfield
# UNKNOWN LOCATION: ND-De-Lourdes
# LOCATION: Cap-St-Ignace
# CLOSEST POPULATION center: Montmagny
# LOCATION: St-Marc-Des-Carrières
# CLOSEST POPULATION center: Baie-eau
# LOCATION: Vallée-Jonction
# CLOSEST POPULATION center: Sainte-Marie
# LOCATION: Disraeli
# CLOSEST POPULATION center: Thetford Mines
# LOCATION: Val-d'Or
# CLOSEST POPULATION center: Val-d'Or
# LOCATION: St-Dominique
# CLOSEST POPULATION center: Saint-Hyacinthe
# LOCATION: Ste-Émélie-De-L'Énergie
# CLOSEST POPULATION center: Rawdon
# LOCATION: St-Antonin
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: St-Charles-sur-Richelieu
# CLOSEST POPULATION center: Saint-Amable
# LOCATION: Rivière-Beaudette
# CLOSEST POPULATION center: Salaberry-de-Valleyfield
# LOCATION: St-André-D'Argenteuil
# CLOSEST POPULATION center: Lachute
# LOCATION: Petite-Rivière-St-François
# CLOSEST POPULATION center: Montmagny
# LOCATION: St-Wenceslas
# CLOSEST POPULATION center: Bécancour
# LOCATION: Ste-Anne-Des-Monts
# CLOSEST POPULATION center: Gaspé
# LOCATION: St-Ours
# CLOSEST POPULATION center: Lavaltrie
# LOCATION: Labelle
# CLOSEST POPULATION center: Mont-Tremblant
# LOCATION: St-Joachim-De-Shefford
# CLOSEST POPULATION center: Granby
# LOCATION: Lac-Sergent
# CLOSEST POPULATION center: Saint-Raymond
# LOCATION: Hudson
# CLOSEST POPULATION center: Saint-Lazare
# LOCATION: Val-Des-Bois
# CLOSEST POPULATION center: Val-des-Monts
# LOCATION: Pontiac
# CLOSEST POPULATION center: Mont-Laurier
# LOCATION: St-Paul-D'Abbotsford
# CLOSEST POPULATION center: Granby
# LOCATION: Lac-Bouchette
# CLOSEST POPULATION center: Roberval
# LOCATION: St-Ferdinand
# CLOSEST POPULATION center: Thetford Mines
# LOCATION: Amherst
# CLOSEST POPULATION center: Mont-Tremblant
# LOCATION: Ste-Marcelline-De-Kildare
# CLOSEST POPULATION center: Rawdon
# LOCATION: Batiscan
# CLOSEST POPULATION center: Baie-eau
# LOCATION: L'Ascension-De-Notre-Seigneur
# CLOSEST POPULATION center: Alma
# LOCATION: St-Ignace-De-Loyola
# CLOSEST POPULATION center: Sorel-Tracy
# LOCATION: Lac-Simon
# CLOSEST POPULATION center: Mont-Tremblant
# LOCATION: Les Éboulements
# CLOSEST POPULATION center: Montmagny
# LOCATION: Ste-Anne-de-Beaupré
# CLOSEST POPULATION center: Beauport
# LOCATION: La Tuque
# CLOSEST POPULATION center: La Tuque
# LOCATION: St-Vallier
# CLOSEST POPULATION center: Montmagny
# LOCATION: St-Ubalde
# CLOSEST POPULATION center: Baie-eau
# LOCATION: Ste-Anne-De-La-Perade
# CLOSEST POPULATION center: Baie-eau
# LOCATION: La Conception
# CLOSEST POPULATION center: Mont-Tremblant
# LOCATION: St-Nérée
# CLOSEST POPULATION center: Sainte-Foy-Sillery-Cap-Rouge
# LOCATION: Kingsey Falls
# CLOSEST POPULATION center: Victoriaville
# LOCATION: Lambton
# CLOSEST POPULATION center: Thetford Mines
# LOCATION: St-Léonard-De-Portneuf
# CLOSEST POPULATION center: Saint-Raymond
# LOCATION: St-Félix-D'Otis
# CLOSEST POPULATION center: Chicoutimi
# LOCATION: Ste-Hénédine
# CLOSEST POPULATION center: Sainte-Marie
# LOCATION: St-Barthelemy
# CLOSEST POPULATION center: Sorel-Tracy
# LOCATION: St-Irenee
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: St-Pascal-De-Kamouraska
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Lery
# CLOSEST POPULATION center: Châteauguay
# LOCATION: Ste-Anne-De-Bellevue
# CLOSEST POPULATION center: L'Île-Perrot
# LOCATION: St-Thomas
# CLOSEST POPULATION center: Joliette
# LOCATION: Lac-Aux-Sables
# CLOSEST POPULATION center: Baie-eau
# LOCATION: St-Joseph-De-Coleraine
# CLOSEST POPULATION center: Thetford Mines
# LOCATION: St-Damase
# CLOSEST POPULATION center: Saint-Hyacinthe
# LOCATION: St-Alexandre-De-Kamouraska
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Roxton Falls
# CLOSEST POPULATION center: Granby
# LOCATION: Percé
# CLOSEST POPULATION center: Gaspé
# LOCATION: Pierreville
# CLOSEST POPULATION center: Sorel-Tracy
# LOCATION: La Durantaye
# CLOSEST POPULATION center: Lévis
# LOCATION: Ripon
# CLOSEST POPULATION center: Val-des-Monts
# LOCATION: Maskinonge
# CLOSEST POPULATION center: Sorel-Tracy
# LOCATION: St-Nazaire
# CLOSEST POPULATION center: Alma
# LOCATION: Bury
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: Val-Joli
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: Ste-Justine
# CLOSEST POPULATION center: Saint-Georges
# LOCATION: Val-Des-Lacs
# CLOSEST POPULATION center: Sainte-Agathe-des-Monts
# LOCATION: St-Alban
# CLOSEST POPULATION center: Baie-eau
# LOCATION: Clermont
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Daveluyville
# CLOSEST POPULATION center: Victoriaville
# LOCATION: Upton
# CLOSEST POPULATION center: Saint-Hyacinthe
# LOCATION: Canton-de-Hatley
# CLOSEST POPULATION center: Magog
# LOCATION: Grenville-sur-la-Rouge
# CLOSEST POPULATION center: Lachute
# LOCATION: Ste-Monique
# CLOSEST POPULATION center: Alma
# LOCATION: St-Henri-De-Taillon
# CLOSEST POPULATION center: Alma
# LOCATION: Ste-Marie-Madeleine
# CLOSEST POPULATION center: Saint-Hyacinthe
# LOCATION: Ste-Lucie-Des-Laurentides
# CLOSEST POPULATION center: Sainte-Agathe-des-Monts
# LOCATION: St-Lazare-De-Bellechasse
# CLOSEST POPULATION center: Sainte-Marie
# LOCATION: Mille-Isles
# CLOSEST POPULATION center: Saint-Sauveur
# LOCATION: Ste-Flavie
# CLOSEST POPULATION center: Rimouski
# LOCATION: La Minerve
# CLOSEST POPULATION center: Mont-Tremblant
# LOCATION: St-Paul-De-Montminy
# CLOSEST POPULATION center: Montmagny
# LOCATION: Armagh
# CLOSEST POPULATION center: Montmagny
# LOCATION: Melbourne
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: Hemmingford
# CLOSEST POPULATION center: Mercier
# LOCATION: Normandin
# CLOSEST POPULATION center: Saint-Félicien
# LOCATION: Westmount
# CLOSEST POPULATION center: Westmount
# LOCATION: Frampton
# CLOSEST POPULATION center: Sainte-Marie
# LOCATION: Canton de Stanstead
# CLOSEST POPULATION center: Magog
# LOCATION: St-Tite-Des-Caps
# CLOSEST POPULATION center: Montmagny
# UNKNOWN LOCATION: St-Magloire-De-Bellechasse
# LOCATION: Beaulac Garthby
# CLOSEST POPULATION center: Thetford Mines
# LOCATION: Maria
# CLOSEST POPULATION center: Gaspé
# LOCATION: Ste-Hélène-De-Bagot
# CLOSEST POPULATION center: Saint-Hyacinthe
# LOCATION: L'Avenir
# CLOSEST POPULATION center: Drummondville
# UNKNOWN LOCATION: Sts-Anges
# LOCATION: Chibougamau
# CLOSEST POPULATION center: Dolbeau-Mistassini
# LOCATION: St-Léon-Le-Grand
# CLOSEST POPULATION center: Shawinigan
# LOCATION: St-Edouard-De-Napierville
# CLOSEST POPULATION center: Saint-Constant
# LOCATION: Lac-Des-Ecorces
# CLOSEST POPULATION center: Mont-Laurier
# LOCATION: St-Chrysostome
# CLOSEST POPULATION center: Mercier
# LOCATION: Pointe-des-Cascades
# CLOSEST POPULATION center: Pincourt
# LOCATION: Ste-Genevieve-De-Batiscan
# CLOSEST POPULATION center: Baie-eau
# LOCATION: Ste-Christine-D'Auvergne
# CLOSEST POPULATION center: Saint-Raymond
# LOCATION: St-Pamphile
# CLOSEST POPULATION center: Montmagny
# LOCATION: Hébertville-Station
# CLOSEST POPULATION center: Alma
# LOCATION: St-Odilon
# CLOSEST POPULATION center: Saint-Georges
# LOCATION: St-Simon-De-Bagot
# CLOSEST POPULATION center: Saint-Hyacinthe
# LOCATION: Chute-St-Philippe
# CLOSEST POPULATION center: Mont-Laurier
# LOCATION: St-Zénon
# CLOSEST POPULATION center: Rawdon
# LOCATION: Sabrevois
# CLOSEST POPULATION center: Saint-Jean-sur-Richelieu
# LOCATION: Cleveland
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: St-Mathieu-De-Rioux
# CLOSEST POPULATION center: Rimouski
# LOCATION: Notre-Dame-de-Pontmain
# CLOSEST POPULATION center: Mont-Laurier
# LOCATION: Lotbinière
# CLOSEST POPULATION center: Pont-Rouge
# LOCATION: St-Roch-Des-Aulnaies
# CLOSEST POPULATION center: Montmagny
# LOCATION: Lac-Ste-Marie
# CLOSEST POPULATION center: Val-des-Monts
# LOCATION: Ste-Clotilde-De-Chateauguay
# CLOSEST POPULATION center: Mercier
# LOCATION: Ste-Brigide-D'Iberville
# CLOSEST POPULATION center: Farnham
# LOCATION: St-Albert
# CLOSEST POPULATION center: Victoriaville
# LOCATION: La Patrie
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: St-Raphael-de-Bellechasse
# CLOSEST POPULATION center: Montmagny
# LOCATION: Tingwick
# CLOSEST POPULATION center: Victoriaville
# UNKNOWN LOCATION: ND-De-La-Merci
# LOCATION: St-Cyrille-De-Lessard
# CLOSEST POPULATION center: Montmagny
# LOCATION: Frontenac
# CLOSEST POPULATION center: Saint-Martin
# LOCATION: Racine
# CLOSEST POPULATION center: Magog
# LOCATION: Pointe-Lebel
# CLOSEST POPULATION center: Matane
# LOCATION: Grondines
# CLOSEST POPULATION center: Baie-eau
# LOCATION: St-Étienne-De-Bolton
# CLOSEST POPULATION center: Magog
# LOCATION: St-Robert
# CLOSEST POPULATION center: Sorel-Tracy
# LOCATION: St-Esprit
# CLOSEST POPULATION center: Sainte-Julienne
# LOCATION: Notre-Dame-Des-Bois
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: St-Casimir
# CLOSEST POPULATION center: Baie-eau
# LOCATION: St-Didace
# CLOSEST POPULATION center: Saint-Charles-Borromée
# LOCATION: St-Pacôme
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: St-Patrice-De-Beaurivage
# CLOSEST POPULATION center: Sainte-Marie
# LOCATION: Buckland
# CLOSEST POPULATION center: Montmagny
# LOCATION: La Macaza
# CLOSEST POPULATION center: Mont-Tremblant
# LOCATION: St-Gabriel-De-Rimouski
# CLOSEST POPULATION center: Rimouski
# LOCATION: ND-Du-Portage
# CLOSEST POPULATION center: Sorel-Tracy
# LOCATION: Cacouna
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Chandler
# CLOSEST POPULATION center: Gaspé
# LOCATION: Messines
# CLOSEST POPULATION center: Mont-Laurier
# LOCATION: St-Flavien
# CLOSEST POPULATION center: Saint-Augustin-de-Desmaures
# LOCATION: St-Aubert
# CLOSEST POPULATION center: Montmagny
# LOCATION: St-François-Du-Lac
# CLOSEST POPULATION center: Sorel-Tracy
# LOCATION: Riviere-Ouelle
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: East Broughton
# CLOSEST POPULATION center: Thetford Mines
# LOCATION: Ste-Victoire-De-Sorel
# CLOSEST POPULATION center: Sorel-Tracy
# LOCATION: Lyster
# CLOSEST POPULATION center: Thetford Mines
# LOCATION: Herouxville
# CLOSEST POPULATION center: Shawinigan
# LOCATION: St-Clet
# CLOSEST POPULATION center: Saint-Lazare
# LOCATION: St-Stanislas-De-Kostka
# CLOSEST POPULATION center: Salaberry-de-Valleyfield
# LOCATION: Vaudreuil-Sur-Le-Lac
# CLOSEST POPULATION center: Vaudreuil-Dorion
# LOCATION: St-Janvier-De-Joly
# CLOSEST POPULATION center: Pont-Rouge
# LOCATION: Huberdeau
# CLOSEST POPULATION center: Mont-Tremblant
# LOCATION: St-Celestin
# CLOSEST POPULATION center: Bécancour
# LOCATION: Cap-Chat
# CLOSEST POPULATION center: Matane
# LOCATION: Grande-Vallee
# CLOSEST POPULATION center: Gaspé
# LOCATION: Bonaventure
# CLOSEST POPULATION center: Gaspé
# LOCATION: Pohénégamook
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: L'Isle-aux-Coudres
# CLOSEST POPULATION center: Montmagny
# LOCATION: St-Ephrem-De-Beauce
# CLOSEST POPULATION center: Saint-Georges
# LOCATION: Ste-Ursule
# CLOSEST POPULATION center: Sorel-Tracy
# LOCATION: Ste-Marguerite-De-Beauce
# CLOSEST POPULATION center: Sainte-Marie
# LOCATION: North-Hatley
# CLOSEST POPULATION center: Magog
# LOCATION: Les Méchins
# CLOSEST POPULATION center: Matane
# LOCATION: Westbury
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: St-Edouard-De-Lotbiniere
# CLOSEST POPULATION center: Pont-Rouge
# LOCATION: St-Ulric
# CLOSEST POPULATION center: Matane
# LOCATION: L'Isle-Verte
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: St-Louis-De-Gonzague
# CLOSEST POPULATION center: Saint-Georges
# LOCATION: St-Blaise-sur-Richelieu
# CLOSEST POPULATION center: Saint-Jean-sur-Richelieu
# LOCATION: St-Fabien
# CLOSEST POPULATION center: Rimouski
# LOCATION: St-Paulin
# CLOSEST POPULATION center: Shawinigan
# LOCATION: St-Jude
# CLOSEST POPULATION center: Saint-Hyacinthe
# LOCATION: St-Jacques-De-Leeds
# CLOSEST POPULATION center: Thetford Mines
# LOCATION: St-Sylvere
# CLOSEST POPULATION center: Bécancour
# LOCATION: St-Narcisse-De-Rimouski
# CLOSEST POPULATION center: Rimouski
# LOCATION: Mayo
# CLOSEST POPULATION center: Val-des-Monts
# LOCATION: St-Majorique-De-Grantham
# CLOSEST POPULATION center: Drummondville
# LOCATION: St-Raphael
# CLOSEST POPULATION center: Montmagny
# LOCATION: St-Bonaventure
# CLOSEST POPULATION center: Drummondville
# LOCATION: Nantes
# CLOSEST POPULATION center: Saint-Martin
# LOCATION: St-Aime-Des-Lacs
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: St-Samuel
# CLOSEST POPULATION center: Victoriaville
# LOCATION: Ste-Clotilde-De-Horton
# CLOSEST POPULATION center: Victoriaville
# LOCATION: St-Placide
# CLOSEST POPULATION center: Mirabel
# LOCATION: Lochaber-Partie-Ouest
# CLOSEST POPULATION center: Gatineau
# LOCATION: Ste-Rose-De-Watford
# CLOSEST POPULATION center: Saint-Georges
# LOCATION: St-Léon-De-Standon
# CLOSEST POPULATION center: Sainte-Marie
# LOCATION: St-Patrice-De-Sherrington
# CLOSEST POPULATION center: Saint-Constant
# LOCATION: St-Narcisse
# CLOSEST POPULATION center: Baie-eau
# LOCATION: Mulgrave-Et-Derry
# CLOSEST POPULATION center: Val-des-Monts
# LOCATION: St-Georges-De-Windsor
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: Ste-Eulalie
# CLOSEST POPULATION center: Victoriaville
# LOCATION: Harrington
# CLOSEST POPULATION center: Mont-Tremblant
# LOCATION: Montebello
# CLOSEST POPULATION center: Lachute
# LOCATION: Montpellier
# CLOSEST POPULATION center: Val-des-Monts
# LOCATION: St-François-De-La-Rivière-Du-Sud
# CLOSEST POPULATION center: Montmagny
# LOCATION: St-Justin
# CLOSEST POPULATION center: Sorel-Tracy
# LOCATION: Val-Brillant
# CLOSEST POPULATION center: Matane
# LOCATION: St-Armand
# CLOSEST POPULATION center: Farnham
# LOCATION: Honfleur
# CLOSEST POPULATION center: Sainte-Marie
# LOCATION: Ulverton
# CLOSEST POPULATION center: Drummondville
# LOCATION: Ste-Cecile-De-Levrard
# CLOSEST POPULATION center: Baie-eau
# LOCATION: Bouchette
# CLOSEST POPULATION center: Mont-Laurier
# LOCATION: St-Edmond-De-Grantham
# CLOSEST POPULATION center: Drummondville
# LOCATION: Wotton
# CLOSEST POPULATION center: Victoriaville
# UNKNOWN LOCATION: St-Donat-De-Rimouski
# LOCATION: St-Charles-De-Bourget
# CLOSEST POPULATION center: Alma
# LOCATION: Adstock
# CLOSEST POPULATION center: Thetford Mines
# LOCATION: St-Guillaume
# CLOSEST POPULATION center: Drummondville
# LOCATION: Chesterville
# CLOSEST POPULATION center: Victoriaville
# LOCATION: Bedford
# CLOSEST POPULATION center: Farnham
# LOCATION: St-Sylvestre
# CLOSEST POPULATION center: Sainte-Marie
# LOCATION: Ste-Euphemie-Sur-Riviere-Du-Sud
# CLOSEST POPULATION center: Montmagny
# LOCATION: Sherrington
# CLOSEST POPULATION center: Saint-Jean-sur-Richelieu
# LOCATION: St-Cyprien-De-Napierville
# CLOSEST POPULATION center: Saint-Jean-sur-Richelieu
# LOCATION: Sawyerville
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: St-Gedeon-De-Beauce
# CLOSEST POPULATION center: Saint-Martin
# LOCATION: Manseau
# CLOSEST POPULATION center: Baie-eau
# LOCATION: St-Alexis
# CLOSEST POPULATION center: Sainte-Julienne
# LOCATION: St-Frédéric
# CLOSEST POPULATION center: Sainte-Marie
# LOCATION: St-Hilarion
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Métis-Sur-Mer
# CLOSEST POPULATION center: Matane
# LOCATION: St-Martin
# CLOSEST POPULATION center: Saint-Martin
# LOCATION: St-Félix-De-Kingsey
# CLOSEST POPULATION center: Drummondville
# LOCATION: St-Luc-De-Vincennes
# CLOSEST POPULATION center: Baie-eau
# LOCATION: Mont-Carmel
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Ste-Aurélie
# CLOSEST POPULATION center: Saint-Georges
# LOCATION: Ste-Sophie-De-Levrard
# CLOSEST POPULATION center: Baie-eau
# LOCATION: Labrecque
# CLOSEST POPULATION center: Alma
# LOCATION: Deschaillons
# CLOSEST POPULATION center: Victoriaville
# LOCATION: La Guadeloupe
# CLOSEST POPULATION center: Saint-Martin
# LOCATION: Stanstead
# CLOSEST POPULATION center: Magog
# LOCATION: Noyan
# CLOSEST POPULATION center: Saint-Jean-sur-Richelieu
# LOCATION: Plaisance
# CLOSEST POPULATION center: Val-des-Monts
# LOCATION: Ste-Geneviève-De-Berthier
# CLOSEST POPULATION center: Sorel-Tracy
# LOCATION: Ste-Praxède
# CLOSEST POPULATION center: Thetford Mines
# LOCATION: Ormstown
# CLOSEST POPULATION center: Salaberry-de-Valleyfield
# LOCATION: Ham-Nord
# CLOSEST POPULATION center: Victoriaville
# LOCATION: Bowman
# CLOSEST POPULATION center: Val-des-Monts
# LOCATION: Dosquet
# CLOSEST POPULATION center: Saint-Augustin-de-Desmaures
# LOCATION: Desbiens
# CLOSEST POPULATION center: Roberval
# LOCATION: Piopolis
# CLOSEST POPULATION center: Saint-Martin
# LOCATION: Bonsecours
# CLOSEST POPULATION center: Magog
# LOCATION: St-Norbert-D'Arthabaska
# CLOSEST POPULATION center: Victoriaville
# LOCATION: La Doré
# CLOSEST POPULATION center: Saint-Félicien
# LOCATION: St-Joachim
# CLOSEST POPULATION center: Montmagny
# LOCATION: Lac-des-Plages
# CLOSEST POPULATION center: Mont-Tremblant
# LOCATION: Laurierville
# CLOSEST POPULATION center: Victoriaville
# LOCATION: Cayamant
# CLOSEST POPULATION center: Val-des-Monts
# LOCATION: St-Benoit-Labre
# CLOSEST POPULATION center: Saint-Georges
# LOCATION: Causapscal
# CLOSEST POPULATION center: Matane
# LOCATION: Ste-Barbe
# CLOSEST POPULATION center: Salaberry-de-Valleyfield
# LOCATION: Iles-de-la-Madeleine
# CLOSEST POPULATION center: Gaspé
# LOCATION: St-Rene
# CLOSEST POPULATION center: Saint-Martin
# LOCATION: Albanel
# CLOSEST POPULATION center: Dolbeau-Mistassini
# LOCATION: Duhamel
# CLOSEST POPULATION center: Mont-Tremblant
# LOCATION: Cloridorme
# CLOSEST POPULATION center: Gaspé
# LOCATION: St-Hugues
# CLOSEST POPULATION center: Saint-Hyacinthe
# LOCATION: Scotstown
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: Ste-Perpétue
# CLOSEST POPULATION center: Montmagny
# LOCATION: Ste-Sabine-De-Bellechasse
# CLOSEST POPULATION center: Saint-Georges
# LOCATION: St-Nazaire-D'Acton
# CLOSEST POPULATION center: Drummondville
# LOCATION: St-Philémon
# CLOSEST POPULATION center: Montmagny
# LOCATION: Lac-Drolet
# CLOSEST POPULATION center: Saint-Martin
# LOCATION: Ferme-Neuve
# CLOSEST POPULATION center: Mont-Laurier
# LOCATION: Hatley
# CLOSEST POPULATION center: Magog
# LOCATION: Yamaska
# CLOSEST POPULATION center: Sorel-Tracy
# UNKNOWN LOCATION: ND-De-La-Salette
# LOCATION: Frelighsburg
# CLOSEST POPULATION center: Cowansville
# UNKNOWN LOCATION: St-Stanislas-De-Champlain
# LOCATION: St-Claude
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: Issoudun
# CLOSEST POPULATION center: Pont-Rouge
# LOCATION: St-Valérien-De-Milton
# CLOSEST POPULATION center: Granby
# LOCATION: Ste-Hedwidge
# CLOSEST POPULATION center: Roberval
# LOCATION: Caplan
# CLOSEST POPULATION center: Gaspé
# LOCATION: Nouvelle
# CLOSEST POPULATION center: Gaspé
# LOCATION: St-Urbain-Premier
# CLOSEST POPULATION center: Mercier
# LOCATION: St-Adrien
# CLOSEST POPULATION center: Victoriaville
# LOCATION: St-Bernard-De-Lacolle
# CLOSEST POPULATION center: Saint-Jean-sur-Richelieu
# LOCATION: Durham-Sud
# CLOSEST POPULATION center: Drummondville
# LOCATION: Ste-Cecile-De-Whitton
# CLOSEST POPULATION center: Saint-Martin
# LOCATION: Lamarche
# CLOSEST POPULATION center: Alma
# LOCATION: Newport
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: Mansfield-Et-Pontefract
# CLOSEST POPULATION center: Cantley
# LOCATION: La Visitation-de-l'Ile-Dupas
# CLOSEST POPULATION center: Sorel-Tracy
# LOCATION: St-Cuthbert
# CLOSEST POPULATION center: Sorel-Tracy
# LOCATION: St-Louis-de-Blandford
# CLOSEST POPULATION center: Victoriaville
# LOCATION: Tadoussac
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: St-Pierre-De-La-Riviere-Du-Sud
# CLOSEST POPULATION center: Montmagny
# LOCATION: Bolton-Ouest
# CLOSEST POPULATION center: Bromont
# LOCATION: St-Zephirin-De-Courval
# CLOSEST POPULATION center: Drummondville
# LOCATION: St-Norbert
# CLOSEST POPULATION center: Saint-Charles-Borromée
# LOCATION: Gracefield
# CLOSEST POPULATION center: Val-des-Monts
# LOCATION: St-Hubert-De-Rivière-Du-Loup
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: St-Fabien-De-Panet
# CLOSEST POPULATION center: Montmagny
# LOCATION: Kiamika
# CLOSEST POPULATION center: Mont-Laurier
# UNKNOWN LOCATION: St-Sebastien-De-Frontenac
# LOCATION: St-Remi-De-Tingwick
# CLOSEST POPULATION center: Victoriaville
# UNKNOWN LOCATION: ND-De-Montauban
# LOCATION: Paspebiac
# CLOSEST POPULATION center: Gaspé
# LOCATION: Lac-Saguay
# CLOSEST POPULATION center: Mont-Laurier
# LOCATION: Déléage
# CLOSEST POPULATION center: Mont-Laurier
# LOCATION: St-Ludger-De-Milot
# CLOSEST POPULATION center: Dolbeau-Mistassini
# LOCATION: St-Narcisse-De-Beaurivage
# CLOSEST POPULATION center: Sainte-Marie
# LOCATION: Audet
# CLOSEST POPULATION center: Saint-Martin
# LOCATION: Chute-aux-Outardes
# CLOSEST POPULATION center: Matane
# LOCATION: Lac-St-Paul
# CLOSEST POPULATION center: Mont-Laurier
# LOCATION: Terrasse-Vaudreuil
# CLOSEST POPULATION center: Pincourt
# LOCATION: Havre-St-Pierre
# CLOSEST POPULATION center: Sept-Îles
# LOCATION: Cabano
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Notre-Dame-Des-Monts
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: St-Louis-Du-Ha-Ha
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Ste-Clotilde-De-Beauce
# CLOSEST POPULATION center: Thetford Mines
# LOCATION: Amos
# CLOSEST POPULATION center: Amos
# LOCATION: Lefebvre
# CLOSEST POPULATION center: Drummondville
# LOCATION: Ste-Anne-De-Sabrevois
# CLOSEST POPULATION center: Saint-Jean-sur-Richelieu
# LOCATION: Ste-Madeleine-De-La-Riviere-Madeleine
# CLOSEST POPULATION center: Gaspé
# LOCATION: St-Rene-De-Matane
# CLOSEST POPULATION center: Matane
# LOCATION: Ste-Anne-De-La-Pocatiere
# CLOSEST POPULATION center: Montmagny
# LOCATION: Ste-Jeanne-D'Arc
# CLOSEST POPULATION center: Rimouski
# LOCATION: St-Marcel-De-Richelieu
# CLOSEST POPULATION center: Sorel-Tracy
# LOCATION: St-Émile-De-Suffolk
# CLOSEST POPULATION center: Mont-Tremblant
# LOCATION: St-André-De-Kamouraska
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Courcelles
# CLOSEST POPULATION center: Saint-Martin
# LOCATION: St-Sixte
# CLOSEST POPULATION center: Val-des-Monts
# LOCATION: St-Valere
# CLOSEST POPULATION center: Victoriaville
# LOCATION: Fort-Coulonge
# CLOSEST POPULATION center: Cantley
# LOCATION: Val-Alain
# CLOSEST POPULATION center: Pont-Rouge
# LOCATION: St-Ludger
# CLOSEST POPULATION center: Saint-Martin
# LOCATION: Lingwick
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: Wentworth
# CLOSEST POPULATION center: Lachute
# LOCATION: Mont-St-Michel
# CLOSEST POPULATION center: Mont-Laurier
# LOCATION: St-Urbain
# CLOSEST POPULATION center: Montmagny
# LOCATION: Chapais
# CLOSEST POPULATION center: Dolbeau-Mistassini
# LOCATION: Ste-Anne-De-La-Rochelle
# CLOSEST POPULATION center: Bromont
# LOCATION: St-Barnabe-Nord
# CLOSEST POPULATION center: Shawinigan
# LOCATION: Gallix
# CLOSEST POPULATION center: Sept-Îles
# LOCATION: St-Sebastien
# CLOSEST POPULATION center: Saint-Jean-sur-Richelieu
# LOCATION: Calixa-Lavallee
# CLOSEST POPULATION center: Saint-Amable
# LOCATION: St-Jean-De-Dieu
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Grand-St-Esprit
# CLOSEST POPULATION center: Bécancour
# LOCATION: Ste-Brigitte-Des-Saults
# CLOSEST POPULATION center: Drummondville
# LOCATION: St-Roch-De-Mekinac
# CLOSEST POPULATION center: Shawinigan
# LOCATION: Pabos
# CLOSEST POPULATION center: Gaspé
# LOCATION: St-Romain
# CLOSEST POPULATION center: Thetford Mines
# LOCATION: St-Siméon
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: St-Siméon-De-Bonaventure
# CLOSEST POPULATION center: Gaspé
# LOCATION: Howick
# CLOSEST POPULATION center: Beauharnois
# LOCATION: New Richmond
# CLOSEST POPULATION center: Gaspé
# LOCATION: Henryville
# CLOSEST POPULATION center: Saint-Jean-sur-Richelieu
# LOCATION: St-Hermenegilde
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: St-Isidore-de-Clifton
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: Lawrenceville
# CLOSEST POPULATION center: Magog
# LOCATION: Ste-Christine
# CLOSEST POPULATION center: Drummondville
# LOCATION: Brébeuf
# CLOSEST POPULATION center: Mont-Tremblant
# LOCATION: Biencourt
# CLOSEST POPULATION center: Rimouski
# LOCATION: Lac-St-Joseph
# CLOSEST POPULATION center: Saint-Raymond
# LOCATION: Black Lake
# ...
# CLOSEST POPULATION center: Baie-eau
# LOCATION: Esterel
# CLOSEST POPULATION center: Saint-Hippolyte
# LOCATION: La Sarre
# CLOSEST POPULATION center: Rouyn-Noranda
# LOCATION: Fassett
# CLOSEST POPULATION center: Lachute
# LOCATION: St-Eloi
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: St-Philibert
# CLOSEST POPULATION center: Saint-Georges
# LOCATION: Rivière-Éternité
# CLOSEST POPULATION center: Chicoutimi
# LOCATION: Ste-Justine-De-Newton
# CLOSEST POPULATION center: Saint-Lazare
# LOCATION: St-Simon-Les-Mines
# CLOSEST POPULATION center: Saint-Georges
# LOCATION: Baie-des-Sables
# CLOSEST POPULATION center: Matane
# LOCATION: St-Mathieu-d'Harricana
# CLOSEST POPULATION center: Amos
# LOCATION: Ste-Agathe-Nord
# CLOSEST POPULATION center: Sainte-Agathe-des-Monts
# LOCATION: St-Nazaire-de-Dorchester
# CLOSEST POPULATION center: Sainte-Marie
# LOCATION: Johnville
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: Ste-Irène
# CLOSEST POPULATION center: Matane
# LOCATION: St-Arsene
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: St-Antoine-Abbe
# CLOSEST POPULATION center: Beauharnois
# LOCATION: Grosses-Roches
# CLOSEST POPULATION center: Matane
# LOCATION: St-André-Du-Lac-St-Jean
# CLOSEST POPULATION center: Roberval
# LOCATION: Egan-Sud
# CLOSEST POPULATION center: Mont-Laurier
# LOCATION: St-Joseph-de-Mékinac
# CLOSEST POPULATION center: Shawinigan
# LOCATION: St-Evariste-De-Forsyth
# CLOSEST POPULATION center: Saint-Martin
# LOCATION: Trois-Lacs
# CLOSEST POPULATION center: Victoriaville
# LOCATION: Ste-Therese-De-Gaspe
# CLOSEST POPULATION center: Gaspé
# LOCATION: St-Onesime
# CLOSEST POPULATION center: Montmagny
# LOCATION: Lacorne
# CLOSEST POPULATION center: Sainte-Sophie
# LOCATION: Montcerf
# CLOSEST POPULATION center: Mont-Laurier
# LOCATION: Esprit-Saint
# CLOSEST POPULATION center: Rimouski
# LOCATION: Ste-Anne-Du-Lac
# CLOSEST POPULATION center: Mont-Laurier
# LOCATION: Villeroy
# CLOSEST POPULATION center: Victoriaville
# LOCATION: Franquelin
# CLOSEST POPULATION center: Matane
# LOCATION: St-Moise
# CLOSEST POPULATION center: Matane
# LOCATION: St-François-De-Sales
# CLOSEST POPULATION center: Roberval
# LOCATION: Franklin
# CLOSEST POPULATION center: Salaberry-de-Valleyfield
# LOCATION: Senneterre
# CLOSEST POPULATION center: Val-d'Or
# LOCATION: Lac-Des-Aigles
# CLOSEST POPULATION center: Rimouski
# LOCATION: Martinville
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: St-Marc-Du-Lac-Long
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Authier
# CLOSEST POPULATION center: Amos
# LOCATION: St-Just-De-Bretenieres
# CLOSEST POPULATION center: Montmagny
# LOCATION: Ste-Paule
# CLOSEST POPULATION center: Matane
# LOCATION: Isle-Aux-Grues
# CLOSEST POPULATION center: Montmagny
# LOCATION: Ste-Sophie-D'Halifax
# CLOSEST POPULATION center: Victoriaville
# LOCATION: Lanoraie-D'Autray
# CLOSEST POPULATION center: Lavaltrie
# LOCATION: Petit-Saguenay
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: St-Fortunat
# CLOSEST POPULATION center: Thetford Mines
# LOCATION: Colombier
# CLOSEST POPULATION center: Rimouski
# LOCATION: St-Michel-Du-Squatec
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Matagami
# CLOSEST POPULATION center: Amos
# LOCATION: Lac-Au-Saumon
# CLOSEST POPULATION center: Matane
# LOCATION: St-Jean-De-Brebeuf
# CLOSEST POPULATION center: Thetford Mines
# LOCATION: St-Pierre-Baptiste
# CLOSEST POPULATION center: Thetford Mines
# LOCATION: Kingsbury
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: Inverness
# CLOSEST POPULATION center: Thetford Mines
# LOCATION: La Trinité-Des-Monts
# CLOSEST POPULATION center: Rimouski
# LOCATION: St-Adrien-D'Irlande
# CLOSEST POPULATION center: Thetford Mines
# LOCATION: Très-St-Sacrement
# CLOSEST POPULATION center: Beauharnois
# LOCATION: Lejeune
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Barkmere
# CLOSEST POPULATION center: Mont-Tremblant
# LOCATION: St-Alphonse-De-Caplan
# CLOSEST POPULATION center: Gaspé
# LOCATION: St-Telesphore
# CLOSEST POPULATION center: Salaberry-de-Valleyfield
# LOCATION: Barraute
# CLOSEST POPULATION center: Amos
# LOCATION: St-Remi-D'Amherst
# CLOSEST POPULATION center: Mont-Tremblant
# LOCATION: St-Maxime-Du-Mont-Louis
# CLOSEST POPULATION center: Gaspé
# LOCATION: St-Severe
# CLOSEST POPULATION center: Shawinigan
# LOCATION: Anse-Pleureuse
# CLOSEST POPULATION center: Gaspé
# LOCATION: St-Thuribe
# CLOSEST POPULATION center: Baie-eau
# LOCATION: St-Octave-De-Metis
# CLOSEST POPULATION center: Rimouski
# LOCATION: St-Albert-De-Warwick
# CLOSEST POPULATION center: Victoriaville
# LOCATION: Pointe-A-La-Croix
# CLOSEST POPULATION center: Gaspé
# LOCATION: Ste-Félicité
# CLOSEST POPULATION center: Matane
# LOCATION: Preissac
# CLOSEST POPULATION center: Amos
# LOCATION: Bryson
# CLOSEST POPULATION center: Cantley
# LOCATION: St-Adelphe
# CLOSEST POPULATION center: Baie-eau
# LOCATION: Pointe-Aux-Outardes
# CLOSEST POPULATION center: Rimouski
# LOCATION: St-Jogues
# CLOSEST POPULATION center: Gaspé
# LOCATION: Eaton
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: Kazabazua
# CLOSEST POPULATION center: Val-des-Monts
# LOCATION: Ste-Seraphine
# CLOSEST POPULATION center: Victoriaville
# LOCATION: Campbells Bay
# CLOSEST POPULATION center: Cantley
# LOCATION: Havelock
# CLOSEST POPULATION center: Mercier
# LOCATION: Abercorn
# CLOSEST POPULATION center: Cowansville
# LOCATION: Vendée
# CLOSEST POPULATION center: Mont-Tremblant
# LOCATION: Poularies
# CLOSEST POPULATION center: Rouyn-Noranda
# LOCATION: St-Aime-Du-Lac-Des-Iles
# CLOSEST POPULATION center: Mont-Laurier
# LOCATION: Ste-Francoise
# CLOSEST POPULATION center: Baie-eau
# LOCATION: Baie-Trinite
# CLOSEST POPULATION center: Matane
# LOCATION: Natashquan
# CLOSEST POPULATION center: Les Îles-de-la-Madeleine
# LOCATION: Godmanchester
# CLOSEST POPULATION center: Salaberry-de-Valleyfield
# LOCATION: Landrienne
# CLOSEST POPULATION center: Amos
# LOCATION: St-Zenon-Du-Lac-Humqui
# CLOSEST POPULATION center: Matane
# UNKNOWN LOCATION: St-Guillaume-D'Upton
# LOCATION: Ste-Helene-de-Chester
# CLOSEST POPULATION center: Victoriaville
# LOCATION: Bergeronnes
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Ste-Elisabeth-de-Proulx
# CLOSEST POPULATION center: Dolbeau-Mistassini
# LOCATION: St-Clement
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Stanbridge Station
# CLOSEST POPULATION center: Farnham
# LOCATION: Rivière-Heva
# CLOSEST POPULATION center: Val-d'Or
# LOCATION: Malartic
# CLOSEST POPULATION center: Val-d'Or
# LOCATION: Ladysmith
# CLOSEST POPULATION center: Cantley
# LOCATION: Lemieux
# CLOSEST POPULATION center: Bécancour
# LOCATION: Port-Au-Persil
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Ivry-Sur-Le-Lac
# CLOSEST POPULATION center: Sainte-Agathe-des-Monts
# LOCATION: St-Camille
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: La Corne
# CLOSEST POPULATION center: Amos
# LOCATION: Moisie
# CLOSEST POPULATION center: Sept-Îles
# UNKNOWN LOCATION: ND-Des-Neiges-Trois-Pistoles
# LOCATION: Rivière-Trois-Pistoles
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: St-Severin
# CLOSEST POPULATION center: Baie-eau
# LOCATION: St-Jean-De-La-Lande
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Mont-St-Pierre
# CLOSEST POPULATION center: Gaspé
# LOCATION: Pike River
# CLOSEST POPULATION center: Farnham
# LOCATION: St-David
# CLOSEST POPULATION center: Sorel-Tracy
# LOCATION: Waltham
# CLOSEST POPULATION center: Cantley
# LOCATION: St-Bruno-De-Kamouraska
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Belleterre
# CLOSEST POPULATION center: Ville-Marie
# LOCATION: l'Ile-du-Grand-Calumet
# CLOSEST POPULATION center: Cantley
# UNKNOWN LOCATION: ND-De-Stanbridge
# LOCATION: Lots-Renversés
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Mashteuiatsh
# CLOSEST POPULATION center: Roberval
# LOCATION: St-Valentin
# CLOSEST POPULATION center: Saint-Jean-sur-Richelieu
# LOCATION: St-Eugène-De-Ladriere
# CLOSEST POPULATION center: Rimouski
# LOCATION: New Carlisle
# CLOSEST POPULATION center: Gaspé
# LOCATION: Gallichan
# CLOSEST POPULATION center: Rouyn-Noranda
# LOCATION: Palmarolle
# CLOSEST POPULATION center: Rouyn-Noranda
# LOCATION: Clarke City
# CLOSEST POPULATION center: Sept-Îles
# LOCATION: Lac-Frontiere
# CLOSEST POPULATION center: Montmagny
# LOCATION: Havre Aubert
# CLOSEST POPULATION center: Les Îles-de-la-Madeleine
# LOCATION: Baie-Ste-Catherine
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: St-Edmond-les-Plaines
# CLOSEST POPULATION center: Dolbeau-Mistassini
# LOCATION: St-Damase-De-L'Islet
# CLOSEST POPULATION center: Montmagny
# LOCATION: St-Pie-De-Guire
# CLOSEST POPULATION center: Drummondville
# LOCATION: Petite-Vallee
# CLOSEST POPULATION center: Gaspé
# LOCATION: St-Guy
# CLOSEST POPULATION center: Rimouski
# LOCATION: St-Jacques-Le-Majeur-De-Wolfestown
# CLOSEST POPULATION center: Thetford Mines
# LOCATION: Ste-Rita
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: St-Denis-De-La-Bouteillerie
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Sayabec
# CLOSEST POPULATION center: Matane
# UNKNOWN LOCATION: St-Adelphe-De-Champlain
# LOCATION: Barnston
# CLOSEST POPULATION center: Magog
# LOCATION: St-Charles-Garnier
# CLOSEST POPULATION center: Rimouski
# LOCATION: Arthabaska
# CLOSEST POPULATION center: Victoriaville
# LOCATION: Labrieville
# CLOSEST POPULATION center: Rimouski
# LOCATION: St-Gabriel-De-Kamouraska
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Chapeau
# CLOSEST POPULATION center: Cantley
# LOCATION: Alleyn-Et-Cawood
# CLOSEST POPULATION center: Val-des-Monts
# LOCATION: Ste-Hélène
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Sacré-Coeur
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Chester-Est
# CLOSEST POPULATION center: Saint-Jean-sur-Richelieu
# LOCATION: Lac-Douaire
# CLOSEST POPULATION center: Mont-Laurier
# LOCATION: Grand-Métis
# CLOSEST POPULATION center: Rimouski
# LOCATION: St-Joseph-De-Kamouraska
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Roquemaure
# CLOSEST POPULATION center: Rouyn-Noranda
# LOCATION: Compton Station
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: St-Jules
# CLOSEST POPULATION center: Saint-Georges
# LOCATION: St-André-De-Restigouche
# CLOSEST POPULATION center: Matane
# LOCATION: St-Blaise
# CLOSEST POPULATION center: Saint-Jean-sur-Richelieu
# LOCATION: Authier-Nord
# CLOSEST POPULATION center: Amos
# LOCATION: Des Ruisseaux
# CLOSEST POPULATION center: Sept-Îles
# LOCATION: St-Edouard
# CLOSEST POPULATION center: Saint-Constant
# LOCATION: Portage-Du-Fort
# CLOSEST POPULATION center: Cantley
# LOCATION: St-Elzéar-De-Temiscouata
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: St-Simon-sur-Mer
# CLOSEST POPULATION center: Rimouski
# LOCATION: Ste-Hélène-de-Mancebourg
# CLOSEST POPULATION center: Rouyn-Noranda
# LOCATION: St-Gabriel
# CLOSEST POPULATION center: Saint-Charles-Borromée
# LOCATION: Grandes-Bergeronnes
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Ascot
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: Grande-Ile
# CLOSEST POPULATION center: Salaberry-de-Valleyfield
# LOCATION: St-Elphege
# CLOSEST POPULATION center: Drummondville
# LOCATION: L'Anse-aux-Griffons
# CLOSEST POPULATION center: Îles Laval
# LOCATION: Ste-Marguerite-De-Lingwick
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: St-Edouard-De-Frampton
# CLOSEST POPULATION center: Sainte-Marie
# LOCATION: Weir
# CLOSEST POPULATION center: Mont-Tremblant
# LOCATION: St-Omer
# CLOSEST POPULATION center: Montmagny
# LOCATION: Port-Menier
# CLOSEST POPULATION center: Sept-Îles
# LOCATION: Ste-Félicité-de-L'Islet
# CLOSEST POPULATION center: Montmagny
# UNKNOWN LOCATION: St-Severin-De-Beauce
# LOCATION: Valcartier
# CLOSEST POPULATION center: La Haute-Saint-Charles
# LOCATION: St-Césaire
# CLOSEST POPULATION center: Marieville
# LOCATION: Hope
# CLOSEST POPULATION center: Gaspé
# LOCATION: Baskatong
# CLOSEST POPULATION center: Mont-Laurier
# LOCATION: Lakefield
# CLOSEST POPULATION center: Saint-Colomban
# LOCATION: Lac-Deschenes
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Villemontel
# CLOSEST POPULATION center: Amos
# LOCATION: Godbout
# CLOSEST POPULATION center: Matane
# LOCATION: Les Buissons
# CLOSEST POPULATION center: Matane
# LOCATION: St-Stanislas
# CLOSEST POPULATION center: Baie-eau
# LOCATION: St-Gabriel-Lalemant
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Hervey-Jonction
# CLOSEST POPULATION center: Baie-eau
# LOCATION: Pointe-Fortune
# CLOSEST POPULATION center: Lachute
# LOCATION: Hope Town
# CLOSEST POPULATION center: Gaspé
# LOCATION: St-Hilaire-De-Dorset
# CLOSEST POPULATION center: Saint-Martin
# LOCATION: Marsoui
# CLOSEST POPULATION center: Gaspé
# LOCATION: St-Omer-L'Islet
# CLOSEST POPULATION center: Montmagny
# LOCATION: Ste-Elisabeth-De-Warwick
# CLOSEST POPULATION center: Victoriaville
# LOCATION: Rapide-Danseur
# CLOSEST POPULATION center: Rouyn-Noranda
# LOCATION: Hampden
# CLOSEST POPULATION center: Sherbrooke
# LOCATION: St-Noel
# CLOSEST POPULATION center: Matane
# LOCATION: Ste-Edwidge
# CLOSEST POPULATION center: Sherbrooke
# UNKNOWN LOCATION: St-Denis-sur-Mer
# LOCATION: Lac Frontière
# CLOSEST POPULATION center: Montmagny
# LOCATION: St-Theophile
# CLOSEST POPULATION center: Saint-Martin
# LOCATION: Ste-Marguerite-Marie
# CLOSEST POPULATION center: Matane
# LOCATION: St-Denis de Kamouraska
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Ste-Lucie-De-Beauregard
# CLOSEST POPULATION center: Montmagny
# LOCATION: Rivière-A-Claude
# CLOSEST POPULATION center: Gaspé
# LOCATION: St-Augustin
# CLOSEST POPULATION center: Les Îles-de-la-Madeleine
# UNKNOWN LOCATION: St-François-de-Montmagny
# LOCATION: St-Cléophas-De-Brandon
# CLOSEST POPULATION center: Saint-Charles-Borromée
# LOCATION: St-Eugène-d'Argentenay
# CLOSEST POPULATION center: Dolbeau-Mistassini
# LOCATION: Longue-Pointe-De-Mingan
# CLOSEST POPULATION center: Sept-Îles
# LOCATION: Thorne
# CLOSEST POPULATION center: Cantley
# LOCATION: Albertville
# CLOSEST POPULATION center: Matane
# LOCATION: Ste-Irene-De-Matapedia
# CLOSEST POPULATION center: Matane
# LOCATION: Laverlochère-Angliers
# CLOSEST POPULATION center: Ville-Marie
# LOCATION: Sheenboro
# CLOSEST POPULATION center: Cantley
# LOCATION: Rivière-Au-Tonnerre
# CLOSEST POPULATION center: Sept-Îles
# LOCATION: St-Joseph-De-Lepage
# CLOSEST POPULATION center: Rimouski
# LOCATION: Les Hauteurs
# CLOSEST POPULATION center: Rimouski
# LOCATION: Macamic
# CLOSEST POPULATION center: Rouyn-Noranda
# LOCATION: Stukely
# CLOSEST POPULATION center: Bromont
# LOCATION: St-Gilbert
# CLOSEST POPULATION center: Saint-Raymond
# LOCATION: Coteau-Station
# CLOSEST POPULATION center: Salaberry-de-Valleyfield
# LOCATION: St-Juste-Du-Lac
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Aguanish
# CLOSEST POPULATION center: Sept-Îles
# LOCATION: St-Paul-De-La-Croix
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: St-Adalbert
# CLOSEST POPULATION center: Montmagny
# LOCATION: Dupuy
# CLOSEST POPULATION center: Rouyn-Noranda
# LOCATION: St-Elzéar-De-Bonaventure
# CLOSEST POPULATION center: Gaspé
# LOCATION: Clarendon
# CLOSEST POPULATION center: Cantley
# LOCATION: Nicolet-Sud
# CLOSEST POPULATION center: Trois-Rivières
# LOCATION: Grand-Lac-St-François
# CLOSEST POPULATION center: Thetford Mines
# LOCATION: Ste-Germaine-Boule
# CLOSEST POPULATION center: Rouyn-Noranda
# LOCATION: L'Ile-Cadieux
# CLOSEST POPULATION center: Vaudreuil-Dorion
# LOCATION: St-Léandre
# CLOSEST POPULATION center: Matane
# LOCATION: Lochaber
# CLOSEST POPULATION center: Val-des-Monts
# LOCATION: La Redemption
# CLOSEST POPULATION center: Rimouski
# LOCATION: Ste-Agnes-De-Dundee
# CLOSEST POPULATION center: Salaberry-de-Valleyfield
# LOCATION: St-Godefroi
# CLOSEST POPULATION center: Gaspé
# LOCATION: L'Anse-À-Valleau
# CLOSEST POPULATION center: Gaspé
# LOCATION: Rivière-Madeleine
# CLOSEST POPULATION center: Gaspé
# LOCATION: St-Gerard-Majella
# CLOSEST POPULATION center: Sorel-Tracy
# LOCATION: Remigny
# CLOSEST POPULATION center: Ville-Marie
# LOCATION: Cascapedia-St-Jules
# CLOSEST POPULATION center: Gaspé
# LOCATION: Ste-Florence
# CLOSEST POPULATION center: Matane
# UNKNOWN LOCATION: ND-De-Bonsecours
# LOCATION: Bristol
# CLOSEST POPULATION center: Cantley
# LOCATION: Laniel
# CLOSEST POPULATION center: Ville-Marie
# LOCATION: Cap-D'Espoir
# CLOSEST POPULATION center: Gaspé
# LOCATION: St-Medard
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Aston Jonction
# CLOSEST POPULATION center: Victoriaville
# LOCATION: St-Antoine-De-L'Isle-Aux-Grues
# CLOSEST POPULATION center: Montmagny
# LOCATION: Cap-au-Renard
# CLOSEST POPULATION center: Gaspé
# LOCATION: Val-Barrette
# CLOSEST POPULATION center: Mont-Laurier
# LOCATION: Parc national du Mont-Tremblant
# CLOSEST POPULATION center: Mont-Tremblant

# %% [markdown]
# Fixing Unknown Locations

# %%
town_dict = {}
town_dict["L'Ile Des Soeurs"] = "Ile des soeurs"
town_dict["St-Joseph-De-Ham-Sud"] = "Ham-Sud"
town_dict["St-Mathieu-De-Laprairie"] = "Saint-Mathieu"
town_dict["St-Denis-sur-Mer"] = "Saint-Denis"
town_dict["St-Isidore-De-Laprairie"] = "Saint-Isodore"
town_dict["St-Stanislas-De-Champlain"] = "Saint-Denis"
town_dict["St-Sebastien-De-Frontenac"] = "Saint-Sebastien"
town_dict["St-Simon-De-Rimouski"] = "Saint-Simon"
town_dict["Ste-Francoise-De-Lotbiniere"] = "Saint-Francoise"
town_dict["St-Guillaume-D'Upton"] = "Saint-Guillaume"
town_dict["St-Adelphe-De-Champlain"] = "Saint-Adelphe"

def fix_unknown_location(unknown_location: str):
    if unknown_location in town_dict.keys():
        return town_dict[unknown_location]
    elif "ND-" in unknown_location:
        return unknown_location.replace("ND-", "Notre-Dame-")
    elif "JC" in unknown_location:
        return unknown_location.replace("JC", "Jacques-Cartier")
    elif "St-" in unknown_location:
        return unknown_location.replace("St-", "Saint-")
    elif "Ste-" in unknown_location:
        return unknown_location.replace("Ste-", "Sainte-")
    elif "Sts-" in unknown_location:
        return unknown_location.replace("Sts-", "Saints-")
    else:
        return unknown_location

# %%
fixed_locations = list(map(fix_unknown_location, unknown_locations))
unknown_locations_mapper = {fixed_locations[i]: unknown_locations[i] for i in range(len(unknown_locations))}

# %%
location_mapper2, unknown_locations2 = build_location_mapper(fixed_locations, population_centers)
# Out:
# LOCATION: Ile des soeurs
# CLOSEST POPULATION center: Salaberry-de-Valleyfield
# LOCATION: Ste-Catherine-de-la-Jacques-Cartier
# CLOSEST POPULATION center: Pont-Rouge
# LOCATION: Notre-Dame-Des-Prairies
# CLOSEST POPULATION center: Joliette
# LOCATION: Notre-Dame-De-L'Ile-Perrot
# CLOSEST POPULATION center: Notre-Dame-de-l'Île-Perrot
# LOCATION: Notre-Dame-Du-Mont-Carmel
# CLOSEST POPULATION center: Shawinigan
# LOCATION: Saint-Mathieu
# CLOSEST POPULATION center: Saint-Constant
# LOCATION: Notre-Dame-Du-Bon-Conseil
# CLOSEST POPULATION center: Drummondville
# LOCATION: Notre-Dame-Du-Laus
# CLOSEST POPULATION center: Val-des-Monts
# LOCATION: Saint-Isodore
# CLOSEST POPULATION center: Mascouche
# LOCATION: Notre-Dame-De-Lourdes
# CLOSEST POPULATION center: Saint-Charles-Borromée
# LOCATION: Saint-Magloire-De-Bellechasse
# CLOSEST POPULATION center: Montmagny
# LOCATION: Saints-Anges
# CLOSEST POPULATION center: Sainte-Marie
# LOCATION: Notre-Dame-De-La-Merci
# CLOSEST POPULATION center: Sainte-Agathe-des-Monts
# LOCATION: Saint-Donat-De-Rimouski
# CLOSEST POPULATION center: Rimouski
# LOCATION: Notre-Dame-De-La-Salette
# CLOSEST POPULATION center: Val-des-Monts
# LOCATION: Saint-Denis
# CLOSEST POPULATION center: Lavaltrie
# LOCATION: Saint-Sebastien
# CLOSEST POPULATION center: Saint-Jean-sur-Richelieu
# LOCATION: Notre-Dame-De-Montauban
# CLOSEST POPULATION center: Baie-eau
# LOCATION: Saint-Marcel-De-L'Islet
# CLOSEST POPULATION center: Montmagny
# LOCATION: Ham-Sud
# CLOSEST POPULATION center: Victoriaville
# LOCATION: Notre-Dame-De-La-Paix
# CLOSEST POPULATION center: Mont-Tremblant
# LOCATION: Notre-Dame-Des-Sept-Douleurs
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Saint-Francoise
# CLOSEST POPULATION center: Rimouski
# LOCATION: Saint-Simon
# CLOSEST POPULATION center: Saint-Hyacinthe
# LOCATION: Notre-Dame-de-Lourdes
# CLOSEST POPULATION center: Saint-Charles-Borromée
# LOCATION: Notre-Dame-De-Ham
# CLOSEST POPULATION center: Victoriaville
# LOCATION: Saint-Guillaume
# CLOSEST POPULATION center: Drummondville
# LOCATION: Notre-Dame-Des-Neiges-Trois-Pistoles
# CLOSEST POPULATION center: Rivière-du-Loup
# LOCATION: Notre-Dame-De-Stanbridge
# CLOSEST POPULATION center: Farnham
# LOCATION: Saint-Adelphe
# CLOSEST POPULATION center: Baie-eau
# LOCATION: Saint-Severin-De-Beauce
# CLOSEST POPULATION center: Sainte-Marie
# LOCATION: Saint-Denis
# CLOSEST POPULATION center: Lavaltrie
# LOCATION: Saint-François-de-Montmagny
# CLOSEST POPULATION center: Montmagny
# LOCATION: Notre-Dame-De-Bonsecours
# CLOSEST POPULATION center: Lachute

# %%
unknown_locations2
# Out:
# []

# %%
location_mapper2 = { unknown_locations_mapper.get(k, k): v for k, v in location_mapper2.items() }
location_mapper.update(location_mapper2)

# %% [markdown]
# ### Saving Final Location Mapper

# %%
with open('../data/processed/population_center_mapper.pkl', 'wb') as f:
    pickle.dump(location_mapper, f)
