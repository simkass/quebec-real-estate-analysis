# %% [markdown]
# ## Visualization Preparation

# %%
import numpy as np
import pandas as pd

from geopy.geocoders import Nominatim

# %% [markdown]
# ### Read Data

# %%
listings_df = pd.read_csv('../data/processed/processed_listings.csv')
listings_df.sample(5)
# Out:
#               Subtype     Style  Living Area  Lot Dimensions  Bedrooms  \
# 13840        2 Storey  Detached         1855            7200         5
# 43920   Semi-detached  2 storey         2400            4471         4
# 102779       Bungalow  Detached         2184           17089         3
# 9241         2 Storey  2 storey         1191            4076         3
# 98732        Bungalow  Detached         1008           12900         4
#
#         Bathrooms  Levels Listing Date  Listing Year  Year of Construction  \
# 13840           2       2   2017-09-01          2017                  2005
# 43920           2       2   2021-12-01          2021                  1989
# 102779          2       1   2012-01-01          2012                  2008
# 9241            1       2   2020-12-01          2020                  2004
# 98732           2       1   2017-03-01          2017                  1973
#
#                      Location                    RCM              Region  \
# 13840   Thérèse-De Blainville  Thérèse-De Blainville         Laurentides
# 43920                Gatineau               Gatineau           Outaouais
# 102779     Les Pays-d'en-Haut     Les Pays-d'en-Haut         Laurentides
# 9241                 Beauport                 Québec  Capitale-Nationale
# 98732       Le Haut-Richelieu      Le Haut-Richelieu          Montérégie
#
#          Price
# 13840   395000
# 43920   360000
# 102779  381000
# 9241    332500
# 98732   224000

# %%
population_centers_df = pd.read_csv('../data/references/handmade/qc-population-centers.csv')
population_centers_df = population_centers_df[["Region", "Bounding Territory", "Display Name", "Bounding Population", "GeoPy Index"]]
population_centers_df = population_centers_df.drop_duplicates().rename(columns={"Display Name": "Location", "Bounding Population": "Population"}).set_index("Location")
population_centers_df.sample(10)
# Out:
#                                                                 Region  \
# Location
# Brome-Missisquoi                                            Montérégie
# Bellechasse                                       Chaudière-Appalaches
# Ville de Mont-Royal                                           Montréal
# L'Île-Bizard-Sainte-Geneviève                                 Montréal
# Saint-Lambert                                               Montérégie
# Saint-Augustin-de-Desmaures                         Capitale-Nationale
# Beauce & Les Etchemins                            Chaudière-Appalaches
# Bécancour & Nicolet                                   Centre-du-Québec
# Pontiac & La Vallée-de-la-Gatineau                           Outaouais
# Duvernay, Saint-Vincent-de-Paul & Saint-François                 Laval
#
#                                                                                  Bounding Territory  \
# Location
# Brome-Missisquoi                                                                   Brome-Missisquoi
# Bellechasse                                                                             Bellechasse
# Ville de Mont-Royal                                                             Ville de Mont-Royal
# L'Île-Bizard-Sainte-Geneviève                                         L'Île-Bizard-Sainte-Geneviève
# Saint-Lambert                                                                         Saint-Lambert
# Saint-Augustin-de-Desmaures                                             Saint-Augustin-de-Desmaures
# Beauce & Les Etchemins                            [La Nouvelle-Beauce,Robert-Cliché,Beauce-Sarti...
# Bécancour & Nicolet                                               [Nicolet-Yamaska,Bécancour (MRC)]
# Pontiac & La Vallée-de-la-Gatineau                               [La Vallée-de-la-Gatineau,Pontiac]
# Duvernay, Saint-Vincent-de-Paul & Saint-François  [Duvernay,Saint-Vincent-de-Paul,Saint-François...
#
#                                                   Population  GeoPy Index
# Location
# Brome-Missisquoi                                       60000            0
# Bellechasse                                            40000            0
# Ville de Mont-Royal                                    20000            0
# L'Île-Bizard-Sainte-Geneviève                          20000            0
# Saint-Lambert                                          20000            0
# Saint-Augustin-de-Desmaures                            20000            0
# Beauce & Les Etchemins                                120000            0
# Bécancour & Nicolet                                    40000            0
# Pontiac & La Vallée-de-la-Gatineau                     35000            0
# Duvernay, Saint-Vincent-de-Paul & Saint-François       65000            0

# %% [markdown]
# ### Location

# %% [markdown]
# Group by Location, calculate Mean

# %%
location_df = listings_df.groupby('Location').mean().astype(int).reset_index()

# %% [markdown]
# Find most common Subtype for each Location

# %%
subtypes = listings_df.groupby('Location')['Subtype'].apply(lambda x: x.mode().iloc[0])
location_df = pd.merge(subtypes, location_df, left_index=True, right_on="Location")

# %% [markdown]
# Number of listings per Location

# %%
location_df.insert(0, 'Nb of listings', '')
location_value_counts = listings_df['Location'].value_counts()
location_df['Nb of listings'] = location_df['Location'].map(location_value_counts).astype(int)

# %% [markdown]
# Price Range for each Location

# %%
conditions = [location_df['Price'] < 210000, 
(location_df['Price'] >= 210000) & (location_df['Price'] < 250000), 
(location_df['Price'] >= 250000) & (location_df['Price'] < 275000), 
(location_df['Price'] >= 275000) & (location_df['Price'] < 300000), 
(location_df['Price'] >= 300000) & (location_df['Price'] < 320000), 
(location_df['Price'] >= 320000) & (location_df['Price'] < 350000), 
(location_df['Price'] >= 350000) & (location_df['Price'] < 400000), 
location_df['Price'] >= 400000]

values = ['0-210k', '210k-250k', '250k-275k', '275k-300k', '300k-320k', '320k-350k', '350k-400k', '>400k']

location_df['Price Range'] = np.select(conditions, values, default=0)

# %% [markdown]
# Merge with Population Centers DataFrame

# %%
location_df = location_df.set_index("Location")
location_df = pd.merge(population_centers_df, location_df, left_index=True, right_index=True)

# %%
location_df.sample(5)
# Out:
#                                      Region     Bounding Territory  \
# Location
# Fabreville                            Laval             Fabreville
# Bellechasse            Chaudière-Appalaches            Bellechasse
# Antoine-Labelle                 Laurentides        Antoine-Labelle
# Bas-Saint-Laurent         Bas-Saint-Laurent      Bas-Saint-Laurent
# Le Plateau-Mont-Royal              Montréal  Le Plateau-Mont-Royal
#
#                        Population  GeoPy Index  Nb of listings      Subtype  \
# Location
# Fabreville                  45000            0            4565     Bungalow
# Bellechasse                 40000            0             709     Bungalow
# Antoine-Labelle             35000            2             162     Bungalow
# Bas-Saint-Laurent          200000            0            1031     Bungalow
# Le Plateau-Mont-Royal      100000            0             884  Condominium
#
#                        Living Area  Lot Dimensions  Bedrooms  Bathrooms  \
# Location
# Fabreville                    1015            6126         3          1
# Bellechasse                   1238           10566         3          1
# Antoine-Labelle               1339           21105         3          1
# Bas-Saint-Laurent             1258           10586         3          1
# Le Plateau-Mont-Royal         1011            6834         2          1
#
#                        Levels  Listing Year  Year of Construction   Price  \
# Location
# Fabreville                  1          2020                  1989  385857
# Bellechasse                 1          2015                  1996  244871
# Antoine-Labelle             1          2016                  1989  230425
# Bas-Saint-Laurent           1          2016                  1985  207676
# Le Plateau-Mont-Royal       1          2014                  1958  389243
#
#                       Price Range
# Location
# Fabreville              350k-400k
# Bellechasse             210k-250k
# Antoine-Labelle         210k-250k
# Bas-Saint-Laurent          0-210k
# Le Plateau-Mont-Royal   350k-400k

# %% [markdown]
# Save Data

# %%
location_df.to_csv('../data/processed/visualization/locations.csv')
