# %% [markdown]
# ## Visualization Preparation

# %%
import numpy as np
import pandas as pd

from geopy.geocoders import Nominatim

# %% [markdown]
# ### Read Data

# %%
listings_df = pd.read_csv('../data/processed/processed_listings.csv')
listings_df.sample(5)
# Out:
#               Subtype                 Style  Living Area  Lot Dimensions  \
# 104131       2 Storey              2 storey         1800            9522
# 17730     Condominium  Divided Co-Ownership         1247            9522
# 36470        Bungalow              Detached          960            6157
# 98652   Semi-detached         Semi-detached          724            1425
# 44997   Semi-detached              2 storey         2400            4471
#
#         Bedrooms  Bathrooms  Levels Listing Date  Listing Year  \
# 104131         3          2       2   2011-03-01          2011
# 17730          2          2       1   2015-02-01          2015
# 36470          3          2       1   2021-11-01          2021
# 98652          3          2       2   2019-04-01          2019
# 44997          4          2       2   2021-12-01          2021
#
#         Year of Construction                 Location                 RCM  \
# 104131                  1990       Les Pays-d'en-Haut  Les Pays-d'en-Haut
# 17730                   1988                 Brossard           Longueuil
# 36470                   1990               Fabreville               Laval
# 98652                   2007  Les Maskoutains & Acton     Les Maskoutains
# 44997                   1989                 Gatineau            Gatineau
#
#              Region   Price
# 104131  Laurentides  200000
# 17730    Montérégie  305000
# 36470         Laval  400000
# 98652    Montérégie  230000
# 44997     Outaouais  360000

# %%
population_centers_df = pd.read_csv('../data/references/handmade/qc-population-centers.csv')
population_centers_df = population_centers_df[["Region", "Bounding Territory", "Display Name", "Bounding Population", "GeoPy Index"]]
population_centers_df = population_centers_df.drop_duplicates().rename(columns={"Display Name": "Location", "Bounding Population": "Population"}).set_index("Location")
population_centers_df.sample(10)
# Out:
#                                                     Region  \
# Location
# L'Assomption                                    Lanaudière
# Marguerite-D'Youville                           Montérégie
# Papineau & Les Collines-de-l'Outaouais           Outaouais
# Beauport                                Capitale-Nationale
# Coaticook                                           Estrie
# Lachine                                           Montréal
# Deux-Montagnes                                 Laurentides
# Nord-du-Québec                              Nord-du-Québec
# Portneuf                                Capitale-Nationale
# Vimont                                               Laval
#
#                                                             Bounding Territory  \
# Location
# L'Assomption                                                L'Assomption (MRC)
# Marguerite-D'Youville                                    Marguerite-D'Youville
# Papineau & Les Collines-de-l'Outaouais  [Les Collines-de-l'Outaouais,Papineau]
# Beauport                                                              Beauport
# Coaticook                                                      Coaticook (MRC)
# Lachine                                              Arrondissement de Lachine
# Deux-Montagnes                                                  Deux-Montagnes
# Nord-du-Québec                                                  Nord-du-Québec
# Portneuf                                                              Portneuf
# Vimont                                                                  Vimont
#
#                                         Population  GeoPy Index
# Location
# L'Assomption                                125000            0
# Marguerite-D'Youville                        80000            0
# Papineau & Les Collines-de-l'Outaouais       60000            0
# Beauport                                     75000            0
# Coaticook                                    20000            0
# Lachine                                      45000            0
# Deux-Montagnes                              100000            1
# Nord-du-Québec                               45000            0
# Portneuf                                     55000            1
# Vimont                                       30000            1

# %% [markdown]
# ### Location

# %% [markdown]
# Group by Location, calculate Mean

# %%
location_df = listings_df.groupby('Location').mean().astype(int).reset_index()

# %% [markdown]
# Find most common Subtype for each Location

# %%
subtypes = listings_df.groupby('Location')['Subtype'].apply(lambda x: x.mode().iloc[0])
location_df = pd.merge(subtypes, location_df, left_index=True, right_on="Location")

# %% [markdown]
# Number of listings per Location

# %%
location_df.insert(0, 'Nb of listings', '')
location_value_counts = listings_df['Location'].value_counts()
location_df['Nb of listings'] = location_df['Location'].map(location_value_counts).astype(int)

# %% [markdown]
# Price Range for each Location

# %%
conditions = [location_df['Price'] < 210000, 
(location_df['Price'] >= 210000) & (location_df['Price'] < 250000), 
(location_df['Price'] >= 250000) & (location_df['Price'] < 275000), 
(location_df['Price'] >= 275000) & (location_df['Price'] < 300000), 
(location_df['Price'] >= 300000) & (location_df['Price'] < 320000), 
(location_df['Price'] >= 320000) & (location_df['Price'] < 350000), 
(location_df['Price'] >= 350000) & (location_df['Price'] < 400000), 
location_df['Price'] >= 400000]

values = ['0-210k', '210k-250k', '250k-275k', '275k-300k', '300k-320k', '320k-350k', '350k-400k', '>400k']

location_df['Price Range'] = np.select(conditions, values, default=0)

# %% [markdown]
# Merge with Population Centers DataFrame

# %%
location_df = location_df.set_index("Location")
location_df = pd.merge(population_centers_df, location_df, left_index=True, right_index=True)

# %%
location_df.sample(5)
# Out:
#                                          Region  \
# Location
# Côte Saint-Luc                         Montréal
# Kirkland                               Montréal
# Côte-Nord                             Côte-Nord
# Thérèse-De Blainville               Laurentides
# Saint-Augustin-de-Desmaures  Capitale-Nationale
#
#                                           Bounding Territory  Population  \
# Location
# Côte Saint-Luc               [Côte Saint-Luc,Montréal-Ouest]       40000
# Kirkland                                            Kirkland       20000
# Côte-Nord                                          Côte-Nord       90000
# Thérèse-De Blainville                  Thérèse-De Blainville      160000
# Saint-Augustin-de-Desmaures      Saint-Augustin-de-Desmaures       20000
#
#                              GeoPy Index  Nb of listings      Subtype  \
# Location
# Côte Saint-Luc                         0              29  Condominium
# Kirkland                               0              37     2 Storey
# Côte-Nord                              0             262     Bungalow
# Thérèse-De Blainville                  0             961     2 Storey
# Saint-Augustin-de-Desmaures            0            1443     2 Storey
#
#                              Living Area  Lot Dimensions  Bedrooms  Bathrooms  \
# Location
# Côte Saint-Luc                      1476            5209         3          1
# Kirkland                            1651            6518         3          1
# Côte-Nord                           1313           12534         3          1
# Thérèse-De Blainville               1402            7593         3          1
# Saint-Augustin-de-Desmaures         1355            9759         3          1
#
#                              Levels  Listing Year  Year of Construction  \
# Location
# Côte Saint-Luc                    1          2015                  1960
# Kirkland                          1          2014                  1986
# Côte-Nord                         1          2016                  1977
# Thérèse-De Blainville             1          2016                  1997
# Saint-Augustin-de-Desmaures       1          2014                  1995
#
#                               Price Price Range
# Location
# Côte Saint-Luc               499482       >400k
# Kirkland                     446991       >400k
# Côte-Nord                    198099      0-210k
# Thérèse-De Blainville        336314   320k-350k
# Saint-Augustin-de-Desmaures  293248   275k-300k

# %% [markdown]
# Save Data

# %%
location_df.to_csv('../data/processed/visualization/locations.csv')
