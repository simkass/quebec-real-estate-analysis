# %% [markdown]
# # Visualization Prep
# Preparing datasets needed for visualization

# %%
import numpy as np
import pandas as pd

from geopy.geocoders import Nominatim

# %%
listings_df = pd.read_csv('../data/processed/processed-listings.csv')
listings_df.sample(5)
# Out:
#            Subtype                 Style  Living Area  Lot Dimensions  \
# 44207     Bungalow      Multi-generation         1100           32880
# 15840    Townhouse  Divided Co-Ownership         2098            2116
# 49415     2 Storey               Unknown          966            4033
# 64318     2 Storey              2 storey         1955            7110
# 84622  Condominium             Mezzanine         1298            1703
#
#        Bedrooms  Bathrooms  Levels Listing Date  Listing Year  \
# 44207         3          2       1   2015-05-01          2015
# 15840         2          1       3   2020-01-01          2020
# 49415         5          2       2   2014-07-01          2014
# 64318         3          1       2   2010-10-01          2010
# 84622         2          1       2   2016-11-01          2016
#
#        Year of Construction  Age                       Location   Price
# 44207                  2004   11                Antoine-Labelle  225000
# 15840                  2016    4                 Deux-Montagnes  374900
# 49415                  1930   84                 Trois-Rivières  126500
# 64318                  1994   16  L'Île-Bizard-Sainte-Geneviève  358000
# 84622                  1999   17                   L'Assomption  224900

# %%
bounding_df = pd.read_csv('../data/references/handmade/bounding-territories.csv')
bounding_df = bounding_df.rename(columns={"Display Name": "Location", "Bounding Population": "Population"}).set_index("Location")
bounding_df.sample(10)
# Out:
#                                                                        Bounding Territory  \
# Location
# D'Autray                                                                         D'Autray
# Papineau & Les Collines-de-l'Outaouais             [Les Collines-de-l'Outaouais,Papineau]
# Laval-des-Rapides                                     [Laval-des-Rapides,Pont-Viau Laval]
# Beauce & Les Etchemins                  [La Nouvelle-Beauce,Robert-Cliché,Beauce-Sarti...
# Memphrémagog                                                                 Memphrémagog
# La Haute-Yamaska                                                         La Haute-Yamaska
# Shawinigan                                                                     Shawinigan
# Sainte-Rose                                                                   Sainte-Rose
# Sainte-Dorothée & Laval-Ouest           [Sainte-Dorothée,Laval-Ouest,Îles Laval,Laval-...
# Hull                                                                                 Hull
#
#                                                              Bounding Type  \
# Location
# D'Autray                                Regional County Municipality (RCM)
# Papineau & Les Collines-de-l'Outaouais  Regional County Municipality (RCM)
# Laval-des-Rapides                                            Laval Borough
# Beauce & Les Etchemins                  Regional County Municipality (RCM)
# Memphrémagog                            Regional County Municipality (RCM)
# La Haute-Yamaska                        Regional County Municipality (RCM)
# Shawinigan                                                    Municipality
# Sainte-Rose                                                  Laval Borough
# Sainte-Dorothée & Laval-Ouest                                Laval Borough
# Hull                                                          Municipality
#
#                                         Population  GeoPy Index
# Location
# D'Autray                                     40000            0
# Papineau & Les Collines-de-l'Outaouais       60000            0
# Laval-des-Rapides                            50000            0
# Beauce & Les Etchemins                      120000            0
# Memphrémagog                                 50000            0
# La Haute-Yamaska                             90000            0
# Shawinigan                                   50000            1
# Sainte-Rose                                  35000            1
# Sainte-Dorothée & Laval-Ouest                45000            0
# Hull                                         70000            0

# %% [markdown]
# Group by Location, calculate Mean

# %%
location_df = listings_df.groupby('Location').mean().astype(int).reset_index()

# %% [markdown]
# Find most common Subtype for each Location

# %%
subtypes = listings_df.groupby('Location')['Subtype'].apply(lambda x: x.mode().iloc[0])
location_df = pd.merge(subtypes, location_df, left_index=True, right_on="Location")

# %% [markdown]
# Number of listings per Location

# %%
location_df.insert(0, 'Nb of listings', '')
location_value_counts = listings_df['Location'].value_counts()
location_df['Nb of listings'] = location_df['Location'].map(location_value_counts).astype(int)

# %% [markdown]
# Price Range for each Location

# %%
conditions = [location_df['Price'] < 210000, 
(location_df['Price'] >= 210000) & (location_df['Price'] < 250000), 
(location_df['Price'] >= 250000) & (location_df['Price'] < 275000), 
(location_df['Price'] >= 275000) & (location_df['Price'] < 300000), 
(location_df['Price'] >= 300000) & (location_df['Price'] < 320000), 
(location_df['Price'] >= 320000) & (location_df['Price'] < 350000), 
(location_df['Price'] >= 350000) & (location_df['Price'] < 400000), 
location_df['Price'] >= 400000]

values = ['0-210k', '210k-250k', '250k-275k', '275k-300k', '300k-320k', '320k-350k', '350k-400k', '>400k']

location_df['Price Range'] = np.select(conditions, values, default=0)

# %% [markdown]
# Merge with Bounding

# %%
location_df = location_df.set_index("Location")
location_df = pd.merge(bounding_df, location_df, left_index=True, right_index=True)

# %%
location_df.sample(5)
# Out:
#                                           Bounding Territory  \
# Location
# Mercier-Hochelaga-Maisonneuve  Mercier-Hochelaga-Maisonneuve
# L'Île-Bizard-Sainte-Geneviève  L'Île-Bizard-Sainte-Geneviève
# Brome-Missisquoi                            Brome-Missisquoi
# Verdun                                                Verdun
# Les Rivières                                    Les Rivières
#
#                                                     Bounding Type  Population  \
# Location
# Mercier-Hochelaga-Maisonneuve                    Montréal Borough      135000
# L'Île-Bizard-Sainte-Geneviève                    Montréal Borough       20000
# Brome-Missisquoi               Regional County Municipality (RCM)       60000
# Verdun                                           Montréal Borough       70000
# Les Rivières                                  Québec City Borough       75000
#
#                                GeoPy Index  Nb of listings      Subtype  \
# Location
# Mercier-Hochelaga-Maisonneuve            0            1451  Condominium
# L'Île-Bizard-Sainte-Geneviève            0             117     2 Storey
# Brome-Missisquoi                         0             923     Bungalow
# Verdun                                   0             516  Condominium
# Les Rivières                             0            1407  Condominium
#
#                                Living Area  Lot Dimensions  Bedrooms  \
# Location
# Mercier-Hochelaga-Maisonneuve         1084            6880         2
# L'Île-Bizard-Sainte-Geneviève         1526            7406         3
# Brome-Missisquoi                      1416           13165         3
# Verdun                                1112            7553         2
# Les Rivières                          1171            6675         2
#
#                                Bathrooms  Levels  Listing Year  \
# Location
# Mercier-Hochelaga-Maisonneuve          1       1          2015
# L'Île-Bizard-Sainte-Geneviève          1       1          2014
# Brome-Missisquoi                       1       1          2016
# Verdun                                 1       1          2014
# Les Rivières                           1       1          2015
#
#                                Year of Construction  Age   Price Price Range
# Location
# Mercier-Hochelaga-Maisonneuve                  1989   25  306592   300k-320k
# L'Île-Bizard-Sainte-Geneviève                  1988   26  376597   350k-400k
# Brome-Missisquoi                               1994   21  300308   300k-320k
# Verdun                                         1985   29  374386   350k-400k
# Les Rivières                                   1996   18  250244   250k-275k

# %%
location_df.to_csv('../data/processed/visualization/locations.csv')
