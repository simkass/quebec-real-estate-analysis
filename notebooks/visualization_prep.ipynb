# %% [markdown]
# ## Visualization Preparation

# %%
import numpy as np
import pandas as pd

from geopy.geocoders import Nominatim

# %% [markdown]
# ### Read Data

# %%
listings_df = pd.read_csv('../data/processed/processed_listings.csv')
listings_df.sample(5)
# Out:
#              Subtype       Style  Living Area  Lot Dimensions  Bedrooms  \
# 38053      Townhouse    2 storey         1220            2575         3
# 89451   1 1/2 Storey  Waterfront         1460            9084         4
# 80351       Bungalow   Open area         1020            9084         2
# 90137       Bungalow    Detached          984            7644         4
# 104354      2 Storey   Townhouse          900            3224         3
#
#         Bathrooms  Levels Listing Date  Listing Year  Year of Construction  \
# 38053           1       2   2018-05-01          2018                  1975
# 89451           1       2   2018-05-01          2018                  1978
# 80351           1       1   2011-05-01          2011                  2001
# 90137           2       1   2013-03-01          2013                  1974
# 104354          1       2   2019-02-01          2019                  2003
#
#                                     Location                 RCM  \
# 38053                               Gatineau            Gatineau
# 89451                      Ville de Saguenay            Saguenay
# 80351                        Antoine-Labelle     Antoine-Labelle
# 90137                      Ville de Saguenay            Saguenay
# 104354  La Côte-de-Beaupré & L'Île-d'Orléans  La Côte-de-Beaupré
#
#                          Region   Price
# 38053                 Outaouais  140000
# 89451   Saguenay-Lac-Saint-Jean  291500
# 80351               Laurentides  277500
# 90137   Saguenay-Lac-Saint-Jean  212000
# 104354       Capitale-Nationale  313000

# %%
population_centers_df = pd.read_csv('../data/references/handmade/qc-population-centers.csv')
population_centers_df = population_centers_df[["Region", "Bounding Territory", "Display Name", "Bounding Population", "GeoPy Index"]]
population_centers_df = population_centers_df.drop_duplicates().rename(columns={"Display Name": "Location", "Bounding Population": "Population"}).set_index("Location")
population_centers_df.sample(10)
# Out:
#                                                                    Region  \
# Location
# Côte-des-Neiges-Notre-Dame-de-Grâce                              Montréal
# Montréal-Nord                                                    Montréal
# Laval-des-Rapides                                                   Laval
# Senneville, Baie-D'Urfé & Saint-Anne-de-Bellevue                 Montréal
# Le Domaine-du-Roy                                 Saguenay-Lac-Saint-Jean
# La Haute-Saint-Charles                                 Capitale-Nationale
# Ville de Saguenay                                 Saguenay-Lac-Saint-Jean
# Trois-Rivières                                                   Mauricie
# Abitibi-Témiscamingue                               Abitibi-Témiscamingue
# D'Autray                                                       Lanaudière
#
#                                                                                 Bounding Territory  \
# Location
# Côte-des-Neiges-Notre-Dame-de-Grâce                [Côte-des-Neiges-Notre-Dame-de-Grâce,Hampstead]
# Montréal-Nord                                                                        Montréal-Nord
# Laval-des-Rapides                                              [Laval-des-Rapides,Pont-Viau Laval]
# Senneville, Baie-D'Urfé & Saint-Anne-de-Bellevue  [Senneville,Baie-D'Urfé,Sainte-Anne-de-Bellevue]
# Le Domaine-du-Roy                                                                Le Domaine-du-Roy
# La Haute-Saint-Charles                                                      La Haute-Saint-Charles
# Ville de Saguenay                                                                         Saguenay
# Trois-Rivières                                                                      Trois-Rivières
# Abitibi-Témiscamingue                                                        Abitibi-Témiscamingue
# D'Autray                                                                                  D'Autray
#
#                                                   Population  GeoPy Index
# Location
# Côte-des-Neiges-Notre-Dame-de-Grâce                   170000            0
# Montréal-Nord                                          85000            0
# Laval-des-Rapides                                      50000            0
# Senneville, Baie-D'Urfé & Saint-Anne-de-Bellevue       10000            0
# Le Domaine-du-Roy                                      30000            0
# La Haute-Saint-Charles                                 85000            0
# Ville de Saguenay                                     150000            1
# Trois-Rivières                                        135000            0
# Abitibi-Témiscamingue                                 150000            0
# D'Autray                                               40000            0

# %% [markdown]
# ### Location

# %% [markdown]
# Group by Location, calculate Mean

# %%
location_df = listings_df.groupby('Location').mean().astype(int).reset_index()

# %% [markdown]
# Find most common Subtype for each Location

# %%
subtypes = listings_df.groupby('Location')['Subtype'].apply(lambda x: x.mode().iloc[0])
location_df = pd.merge(subtypes, location_df, left_index=True, right_on="Location")

# %% [markdown]
# Number of listings per Location

# %%
location_df.insert(0, 'Nb of listings', '')
location_value_counts = listings_df['Location'].value_counts()
location_df['Nb of listings'] = location_df['Location'].map(location_value_counts).astype(int)

# %% [markdown]
# Price Range for each Location

# %%
conditions = [location_df['Price'] < 210000, 
(location_df['Price'] >= 210000) & (location_df['Price'] < 250000), 
(location_df['Price'] >= 250000) & (location_df['Price'] < 275000), 
(location_df['Price'] >= 275000) & (location_df['Price'] < 300000), 
(location_df['Price'] >= 300000) & (location_df['Price'] < 320000), 
(location_df['Price'] >= 320000) & (location_df['Price'] < 350000), 
(location_df['Price'] >= 350000) & (location_df['Price'] < 400000), 
location_df['Price'] >= 400000]

values = ['0-210k', '210k-250k', '250k-275k', '275k-300k', '300k-320k', '320k-350k', '350k-400k', '>400k']

location_df['Price Range'] = np.select(conditions, values, default=0)

# %% [markdown]
# Merge with Population Centers DataFrame

# %%
location_df = location_df.set_index("Location")
location_df = pd.merge(population_centers_df, location_df, left_index=True, right_index=True)

# %%
location_df.sample(5)
# Out:
#                                                             Region  \
# Location
# Ville-Marie                                               Montréal
# Drummond                                          Centre-du-Québec
# Senneville, Baie-D'Urfé & Saint-Anne-de-Bellevue          Montréal
# Laval-des-Rapides                                            Laval
# LaSalle                                                   Montréal
#
#                                                                                 Bounding Territory  \
# Location
# Ville-Marie                                                                            Ville-Marie
# Drummond                                                                                  Drummond
# Senneville, Baie-D'Urfé & Saint-Anne-de-Bellevue  [Senneville,Baie-D'Urfé,Sainte-Anne-de-Bellevue]
# Laval-des-Rapides                                              [Laval-des-Rapides,Pont-Viau Laval]
# LaSalle                                                                                    LaSalle
#
#                                                   Population  GeoPy Index  \
# Location
# Ville-Marie                                            90000            1
# Drummond                                              100000            0
# Senneville, Baie-D'Urfé & Saint-Anne-de-Bellevue       10000            0
# Laval-des-Rapides                                      50000            0
# LaSalle                                                75000            0
#
#                                                   Nb of listings      Subtype  \
# Location
# Ville-Marie                                                  443  Condominium
# Drummond                                                    1733     Bungalow
# Senneville, Baie-D'Urfé & Saint-Anne-de-Bellevue             285     2 Storey
# Laval-des-Rapides                                            295  Condominium
# LaSalle                                                      180  Condominium
#
#                                                   Living Area  Lot Dimensions  \
# Location
# Ville-Marie                                               956            7933
# Drummond                                                 1270            9988
# Senneville, Baie-D'Urfé & Saint-Anne-de-Bellevue         1334            7778
# Laval-des-Rapides                                        1117            6457
# LaSalle                                                  1172            6909
#
#                                                   Bedrooms  Bathrooms  Levels  \
# Location
# Ville-Marie                                              1          1       1
# Drummond                                                 3          1       1
# Senneville, Baie-D'Urfé & Saint-Anne-de-Bellevue         3          1       1
# Laval-des-Rapides                                        2          1       1
# LaSalle                                                  2          1       1
#
#                                                   Listing Year  \
# Location
# Ville-Marie                                               2014
# Drummond                                                  2016
# Senneville, Baie-D'Urfé & Saint-Anne-de-Bellevue          2016
# Laval-des-Rapides                                         2015
# LaSalle                                                   2014
#
#                                                   Year of Construction  \
# Location
# Ville-Marie                                                       1977
# Drummond                                                          1996
# Senneville, Baie-D'Urfé & Saint-Anne-de-Bellevue                  1990
# Laval-des-Rapides                                                 1980
# LaSalle                                                           1990
#
#                                                    Price Price Range
# Location
# Ville-Marie                                       342211   320k-350k
# Drummond                                          232144   210k-250k
# Senneville, Baie-D'Urfé & Saint-Anne-de-Bellevue  303445   300k-320k
# Laval-des-Rapides                                 308004   300k-320k
# LaSalle                                           321952   320k-350k

# %% [markdown]
# Save Data

# %%
location_df.to_csv('../data/processed/visualization/locations.csv')
