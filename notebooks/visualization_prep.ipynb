# %% [markdown]
# # Visualization Prep
# Preparing datasets needed for visualization

# %%
import numpy as np
import pandas as pd

from geopy.geocoders import Nominatim

# %%
listings_df = pd.read_csv('../data/processed/processed_listings.csv')
listings_df.sample(5)
# Out:
#              Subtype                 Style  Living Area  Lot Dimensions  \
# 45809  Semi-detached               Unknown         1255            3270
# 44930  Semi-detached                  Link          968            5589
# 41037       2 Storey               Unknown         1600            5523
# 66911       2 Storey              Detached         1904           31821
# 70177    Condominium  Divided Co-Ownership          592            9283
#
#        Bedrooms  Bathrooms  Levels Listing Date  Listing Year  \
# 45809         4          1       2   2014-09-01          2014
# 44930         4          1       1   2015-03-01          2015
# 41037         4          2       2   2015-12-01          2015
# 66911         3          2       2   2008-05-01          2008
# 70177         1          1       1   2021-04-01          2021
#
#        Year of Construction  Age                Location   Price
# 45809                  1991   23                Gatineau  209000
# 44930                  1998   17          Trois-Rivières  145000
# 41037                  1997   18   Marguerite-D'Youville  385000
# 66911                  2004    4       Le Haut-Richelieu  275000
# 70177                  2013    8  La Haute-Saint-Charles  122000

# %%
bounding_df = pd.read_csv('../data/references/handmade/bounding-territories.csv')
bounding_df = bounding_df.rename(columns={"Display Name": "Location", "Bounding Population": "Population"}).set_index("Location")
bounding_df.sample(10)
# Out:
#                                              Bounding Territory  \
# Location
# Le Haut-Richelieu                             Le Haut-Richelieu
# La Vallée-du-Richelieu                   La Vallée-du-Richelieu
# L'Île-Bizard-Sainte-Geneviève     L'Île-Bizard-Sainte-Geneviève
# La Tuque, Mékinac & Les Chenaux  [La Tuque,Mékinac,Les Chenaux]
# Argenteuil                                           Argenteuil
# Côte-Nord                                             Côte-Nord
# Bas-Saint-Laurent                             Bas-Saint-Laurent
# L'Islet & Montmagny                         [L'Islet,Montmagny]
# Saint-Bruno-de-Montarville           Saint-Bruno-de-Montarville
# Nord-du-Québec                                   Nord-du-Québec
#
#                                                       Bounding Type  \
# Location
# Le Haut-Richelieu                Regional County Municipality (RCM)
# La Vallée-du-Richelieu           Regional County Municipality (RCM)
# L'Île-Bizard-Sainte-Geneviève                      Montréal Borough
# La Tuque, Mékinac & Les Chenaux  Regional County Municipality (RCM)
# Argenteuil                       Regional County Municipality (RCM)
# Côte-Nord                                      Administative Region
# Bas-Saint-Laurent                              Administative Region
# L'Islet & Montmagny              Regional County Municipality (RCM)
# Saint-Bruno-de-Montarville                             Municipality
# Nord-du-Québec                                 Administative Region
#
#                                  Population  GeoPy Index
# Location
# Le Haut-Richelieu                    120000            0
# La Vallée-du-Richelieu               125000            0
# L'Île-Bizard-Sainte-Geneviève         20000            0
# La Tuque, Mékinac & Les Chenaux       40000            0
# Argenteuil                            30000            0
# Côte-Nord                             90000            0
# Bas-Saint-Laurent                    200000            0
# L'Islet & Montmagny                   40000            1
# Saint-Bruno-de-Montarville            25000            0
# Nord-du-Québec                        45000            0

# %% [markdown]
# Group by Location, calculate Mean

# %%
location_df = listings_df.groupby('Location').mean().astype(int).reset_index()

# %% [markdown]
# Find most common Subtype for each Location

# %%
subtypes = listings_df.groupby('Location')['Subtype'].apply(lambda x: x.mode().iloc[0])
location_df = pd.merge(subtypes, location_df, left_index=True, right_on="Location")

# %% [markdown]
# Number of listings per Location

# %%
location_df.insert(0, 'Nb of listings', '')
location_value_counts = listings_df['Location'].value_counts()
location_df['Nb of listings'] = location_df['Location'].map(location_value_counts).astype(int)

# %% [markdown]
# Price Range for each Location

# %%
conditions = [location_df['Price'] < 210000, 
(location_df['Price'] >= 210000) & (location_df['Price'] < 250000), 
(location_df['Price'] >= 250000) & (location_df['Price'] < 275000), 
(location_df['Price'] >= 275000) & (location_df['Price'] < 300000), 
(location_df['Price'] >= 300000) & (location_df['Price'] < 320000), 
(location_df['Price'] >= 320000) & (location_df['Price'] < 350000), 
(location_df['Price'] >= 350000) & (location_df['Price'] < 400000), 
location_df['Price'] >= 400000]

values = ['0-210k', '210k-250k', '250k-275k', '275k-300k', '300k-320k', '320k-350k', '350k-400k', '>400k']

location_df['Price Range'] = np.select(conditions, values, default=0)

# %% [markdown]
# Merge with Bounding

# %%
location_df = location_df.set_index("Location")
location_df = pd.merge(bounding_df, location_df, left_index=True, right_index=True)

# %%
location_df.sample(5)
# Out:
#                           Bounding Territory  \
# Location
# Argenteuil                        Argenteuil
# Westmount                          Westmount
# Le Plateau-Mont-Royal  Le Plateau-Mont-Royal
# Antoine-Labelle              Antoine-Labelle
# Maskinongé                  Maskinongé (MRC)
#
#                                             Bounding Type  Population  \
# Location
# Argenteuil             Regional County Municipality (RCM)       30000
# Westmount                                Montréal Borough       20000
# Le Plateau-Mont-Royal                    Montréal Borough      100000
# Antoine-Labelle        Regional County Municipality (RCM)       35000
# Maskinongé             Regional County Municipality (RCM)       35000
#
#                        GeoPy Index  Nb of listings      Subtype  Living Area  \
# Location
# Argenteuil                       0             184     Bungalow         1409
# Westmount                        0              10  Condominium         1749
# Le Plateau-Mont-Royal            0             868  Condominium         1013
# Antoine-Labelle                  2             243     Bungalow         1325
# Maskinongé                       0             314     Bungalow         1447
#
#                        Lot Dimensions  Bedrooms  Bathrooms  Levels  \
# Location
# Argenteuil                      14824         2          1       1
# Westmount                        4793         3          1       1
# Le Plateau-Mont-Royal            6923         2          1       1
# Antoine-Labelle                 20356         2          1       1
# Maskinongé                      16808         3          1       1
#
#                        Listing Year  Year of Construction  Age   Price  \
# Location
# Argenteuil                     2016                  1990   26  255578
# Westmount                      2011                  1945   65  675950
# Le Plateau-Mont-Royal          2014                  1958   55  391287
# Antoine-Labelle                2016                  1990   26  232753
# Maskinongé                     2016                  1984   32  203863
#
#                       Price Range
# Location
# Argenteuil              250k-275k
# Westmount                   >400k
# Le Plateau-Mont-Royal   350k-400k
# Antoine-Labelle         210k-250k
# Maskinongé                 0-210k

# %%
location_df.to_csv('../data/processed/visualization/locations.csv')
