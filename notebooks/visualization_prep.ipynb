# %% [markdown]
# ## Visualization Preparation

# %%
import numpy as np
import pandas as pd

from geopy.geocoders import Nominatim

# %% [markdown]
# ### Read Data

# %%
listings_df = pd.read_csv('../data/processed/processed_listings.csv')
listings_df.sample(5)
# Out:
#               Subtype             Style  Living Area  Lot Dimensions  \
# 108986       2 Storey       Custom Home         2840            5000
# 102321       Bungalow  New construction         1415            6175
# 107209  Semi-detached          2 storey         1560            3172
# 98481        Bungalow    Cathedral roof         1025            7474
# 40831        Bungalow         Open area         1090            9522
#
#         Bedrooms  Bathrooms  Levels Listing Date  Listing Year  \
# 108986         4          2       2   2016-10-01          2016
# 102321         4          2       1   2018-01-01          2018
# 107209         5          2       2   2021-12-01          2021
# 98481          3          2       1   2018-03-01          2018
# 40831          3          2       1   2011-02-01          2011
#
#         Year of Construction  \
# 108986                  2015
# 102321                  2014
# 107209                  2016
# 98481                   1990
# 40831                   1997
#
#                                                 Location  \
# 108986  Senneville, Baie-D'Urfé & Saint-Anne-de-Bellevue
# 102321                                     Saint-Lambert
# 107209              La Côte-de-Beaupré & L'Île-d'Orléans
# 98481           Le Fjord-du-Saguenay & Maria-Chapdelaine
# 40831                                           Gatineau
#
#                          RCM                   Region   Price
# 108986              Montréal                 Montréal  550000
# 102321             Longueuil               Montérégie  798750
# 107209    La Côte-de-Beaupré       Capitale-Nationale  610000
# 98481   Le Fjord-du-Saguenay  Saguenay-Lac-Saint-Jean  140000
# 40831               Gatineau                Outaouais  222000

# %%
population_centers_df = pd.read_csv('../data/references/handmade/qc-population-centers.csv')
population_centers_df = population_centers_df[["RCM", "Region", "Bounding Territory", "Display Name", "Bounding Population"]]
population_centers_df = population_centers_df.drop_duplicates().rename(columns={"Display Name": "Location", "Bounding Population": "Population"}).set_index("Location")
population_centers_df.sample(10)
# Out:
#                                                                       RCM  \
# Location
# La Haute-Yamaska                                         La Haute-Yamaska
# Bécancour & Nicolet                                             Bécancour
# Beauport                                                           Québec
# Mirabel                                                           Mirabel
# Boucherville                                                    Longueuil
# Les Jardins-de-Napierville & Le Haut-Saint-Laurent  Le Haut-Saint-Laurent
# L'Islet & Montmagny                                               L'Islet
# Montréal-Nord                                                    Montréal
# Ville-Marie                                                      Montréal
# Fabreville                                                          Laval
#
#                                                                   Region  \
# Location
# La Haute-Yamaska                                              Montérégie
# Bécancour & Nicolet                                     Centre-du-Québec
# Beauport                                              Capitale-Nationale
# Mirabel                                                      Laurentides
# Boucherville                                                  Montérégie
# Les Jardins-de-Napierville & Le Haut-Saint-Laurent            Montérégie
# L'Islet & Montmagny                                 Chaudière-Appalaches
# Montréal-Nord                                                   Montréal
# Ville-Marie                                                     Montréal
# Fabreville                                                         Laval
#
#                                                                                    Bounding Territory  \
# Location
# La Haute-Yamaska                                                                     La Haute-Yamaska
# Bécancour & Nicolet                                                 [Nicolet-Yamaska,Bécancour (MRC)]
# Beauport                                                                                     Beauport
# Mirabel                                                                                       Mirabel
# Boucherville                                                                             Boucherville
# Les Jardins-de-Napierville & Le Haut-Saint-Laurent  [Les Jardins-de-Napierville,Le Haut-Saint-Laur...
# L'Islet & Montmagny                                                               [L'Islet,Montmagny]
# Montréal-Nord                                                                           Montréal-Nord
# Ville-Marie                                                                               Ville-Marie
# Fabreville                                                                                 Fabreville
#
#                                                     Population
# Location
# La Haute-Yamaska                                         90000
# Bécancour & Nicolet                                      40000
# Beauport                                                 75000
# Mirabel                                                  60000
# Boucherville                                             40000
# Les Jardins-de-Napierville & Le Haut-Saint-Laurent       50000
# L'Islet & Montmagny                                      40000
# Montréal-Nord                                            85000
# Ville-Marie                                              90000
# Fabreville                                               45000

# %% [markdown]
# ### Location

# %% [markdown]
# Group by Location, calculate Mean

# %%
location_df = listings_df.groupby('Location').mean().astype(int).reset_index()

# %% [markdown]
# Find most common Subtype for each Location

# %%
subtypes = listings_df.groupby('Location')['Subtype'].apply(lambda x: x.mode().iloc[0])
location_df = pd.merge(subtypes, location_df, left_index=True, right_on="Location")

# %% [markdown]
# Number of listings per Location

# %%
location_df.insert(0, 'Nb of listings', '')
location_value_counts = listings_df['Location'].value_counts()
location_df['Nb of listings'] = location_df['Location'].map(location_value_counts).astype(int)

# %% [markdown]
# Price Range for each Location

# %%
conditions = [(location_df['Price'] >= 0) & (location_df['Price'] < 200000), (location_df['Price'] >= 200000) & (
    location_df['Price'] < 300000), (location_df['Price'] >= 300000) & (location_df['Price'] < 400000), location_df['Price'] >= 400000]
values = ['0-200k', '200k-300k', '300k-400k', '>400k']

location_df['Price Range'] = np.select(conditions, values, default=0)

# %% [markdown]
# Merge with Population Centers DataFrame

# %%
location_df = location_df.set_index("Location")
location_df = pd.merge(population_centers_df, location_df, left_index=True, right_index=True)

# %%
location_df.sample(5)
# Out:
#                                                            RCM      Region  \
# Location
# Pontiac & La Vallée-de-la-Gatineau    La Vallée-de-la-Gatineau   Outaouais
# Trois-Rivières                                  Trois-Rivières    Mauricie
# Le Haut-Richelieu                            Le Haut-Richelieu  Montérégie
# Villeray-Saint-Michel-Parc-Extension                  Montréal    Montréal
# LaSalle                                               Montréal    Montréal
#
#                                                         Bounding Territory  \
# Location
# Pontiac & La Vallée-de-la-Gatineau      [La Vallée-de-la-Gatineau,Pontiac]
# Trois-Rivières                                              Trois-Rivières
# Le Haut-Richelieu                                        Le Haut-Richelieu
# Villeray-Saint-Michel-Parc-Extension  Villeray-Saint-Michel-Parc-Extension
# LaSalle                                                            LaSalle
#
#                                       Population  Nb of listings      Subtype  \
# Location
# Pontiac & La Vallée-de-la-Gatineau         35000             182     Bungalow
# Trois-Rivières                            135000            2149     Bungalow
# Le Haut-Richelieu                         120000            1365     Bungalow
# Villeray-Saint-Michel-Parc-Extension      145000             454  Condominium
# LaSalle                                    75000             182  Condominium
#
#                                       Living Area  Lot Dimensions  Bedrooms  \
# Location
# Pontiac & La Vallée-de-la-Gatineau           1432           24328         3
# Trois-Rivières                               1304            8711         3
# Le Haut-Richelieu                            1304            9067         3
# Villeray-Saint-Michel-Parc-Extension          951            6941         2
# LaSalle                                      1174            7092         2
#
#                                       Bathrooms  Levels  Listing Year  \
# Location
# Pontiac & La Vallée-de-la-Gatineau            1       1          2015
# Trois-Rivières                                1       1          2016
# Le Haut-Richelieu                             1       1          2015
# Villeray-Saint-Michel-Parc-Extension          1       1          2015
# LaSalle                                       1       1          2014
#
#                                       Year of Construction   Price Price Range
# Location
# Pontiac & La Vallée-de-la-Gatineau                    1986  238759   200k-300k
# Trois-Rivières                                        1990  203470   200k-300k
# Le Haut-Richelieu                                     1993  281648   200k-300k
# Villeray-Saint-Michel-Parc-Extension                  1984  339271   300k-400k
# LaSalle                                               1990  323040   300k-400k

# %% [markdown]
# Save Data

# %%
location_df.to_csv('../data/processed/visualization/locations.csv')
