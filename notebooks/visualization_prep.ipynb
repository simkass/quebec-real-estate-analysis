# %% [markdown]
# # Visualization Preparation
# To visualize data, we need to prepare some dataframes that hold data such as mean price per location, mean price per listing date, listings per location, etc...

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Read Data

# %%
listings_df = pd.read_csv('../data/processed/processed_listings.csv')
listings_df.head(10)
# Out:
#          subtype      style  living_area  lot_dimensions  bedrooms  bathrooms  \
# 0       2 Storey   2 storey         1191            4076         3          1
# 1       Bungalow  Open area         1261            9500         2          1
# 2      Townhouse    Unknown         1645            1360         3          1
# 3  Bi-generation       Link         2024           17000         4          3
# 4  Semi-detached   2 storey         2400            4471         4          2
# 5       2 Storey    Unknown         1800           16090         5          2
# 6       Bungalow   Detached          960            6157         3          2
# 7  Semi-detached   2 storey         1560            3172         5          2
# 8  Semi-detached   2 storey         1250            6322         4          2
# 9       Bungalow  Open area         1340            5500         4          2
#
#    levels                location  listing_year  age  yard_area listing_date  \
# 0       2                   Lévis          2020   16       2885   2020-12-01
# 1       1                Portneuf          2021   64       8239   2021-12-01
# 2       3                 Mercier          2021   15          0   2021-11-01
# 3       1  Stoneham-et-Tewkesbury          2021    2      14976   2021-12-01
# 4       2                Gatineau          2021   32       2071   2021-12-01
# 5       2                    Alma          2021   31      14290   2021-09-01
# 6       1              Fabreville          2021   31       5197   2021-11-01
# 7       2          Saint-François          2021    5       1612   2021-12-01
# 8       2          Trois-Rivières          2021   16       5072   2021-12-01
# 9       1                   Lévis          2021   34       4160   2021-11-01
#
#    year_of_construction   price
# 0                  2004  332500
# 1                  1957  265000
# 2                  2006  612000
# 3                  2019  526500
# 4                  1989  360000
# 5                  1990  284000
# 6                  1990  400000
# 7                  2016  610000
# 8                  2005  320000
# 9                  1987  350000

# %% [markdown]
# ### Location

# %%
location_df = listings_df.groupby('location').mean().astype(int).reset_index()

# %%
population_centers_coordinates = pd.read_csv('../data/processed/population_centers_coordinates.csv')
lat_dict = pd.Series(population_centers_coordinates.Latitude.values, index=population_centers_coordinates.Name).to_dict()
lon_dict = pd.Series(population_centers_coordinates.Longitude.values, index=population_centers_coordinates.Name).to_dict()

# %%
location_value_counts = listings_df['location'].value_counts()
location_df['nb_of_listings'] = location_df['location'].map(location_value_counts).astype(int)

# %%
location_df['latitude'] = location_df['location'].map(lat_dict)
location_df['longitude'] = location_df['location'].map(lon_dict)

# %%
mtl_island_df = pd.read_csv('../data/references/handmade/mtl-island.csv')
location_df['mtl_island'] = location_df['location'].isin(mtl_island_df['Name'])

# %%
location_df.head(20)
# Out:
#            location  living_area  lot_dimensions  bedrooms  bathrooms  levels  \
# 0        Acton Vale         1399           11261         3          1       1
# 1              Alma         1707           14974         4          1       1
# 2              Amos         1313            8831         3          1       1
# 3             Anjou         1191            5533         2          1       1
# 4           Auteuil         1313            6110         3          1       1
# 5       Baie-Comeau         1208            9024         3          1       1
# 6   Baie-Saint-Paul         1336           10658         3          1       1
# 7      Beaconsfield         1911            9500         3          2       1
# 8       Beauharnois         1241            8210         3          1       1
# 9           Beloeil         1322            6812         3          1       1
# 10       Blainville         1403            7102         3          1       1
# 11  Bois-des-Filion         1317            6851         3          1       1
# 12       Boisbriand         1348            6321         3          1       1
# 13     Boucherville         1394            6498         3          1       1
# 14          Bromont         1408            9302         3          1       1
# 15         Brossard         1224            6294         2          1       1
# 16        Bécancour         1366           10988         3          1       1
# 17          Candiac         1356            6358         3          1       1
# 18          Cantley         1553           10588         3          1       1
# 19         Carignan         1570            9285         3          1       1
#
#     listing_year  age  yard_area  year_of_construction   price  \
# 0           2016   36       9861                  1980  225980
# 1           2020   30      13267                  1989  270800
# 2           2017   34       7517                  1983  210140
# 3           2015   28       4351                  1986  326092
# 4           2015   21       4807                  1993  311234
# 5           2016   39       7822                  1976  176677
# 6           2016   38       9322                  1977  223198
# 7           2013   43       7618                  1970  495167
# 8           2017   29       6969                  1987  263478
# 9           2015   20       5496                  1995  314847
# 10          2016   18       5700                  1997  336493
# 11          2015   19       5541                  1996  303582
# 12          2016   24       4994                  1991  325233
# 13          2015   25       5122                  1989  367056
# 14          2016   13       7907                  2003  348402
# 15          2014   17       5087                  1997  295820
# 16          2016   28       9623                  1987  187504
# 17          2015   16       5011                  1998  335277
# 18          2015   20       9036                  1995  315791
# 19          2016   15       7714                  2001  384817
#
#     nb_of_listings   latitude  longitude  mtl_island
# 0              192  45.648177 -72.564952       False
# 1             4544  48.548887 -71.651459       False
# 2               25  48.571852 -78.116086       False
# 3              175  45.604898 -73.546672        True
# 4              288  45.631013 -73.751998       False
# 5               98  49.211837 -68.180141       False
# 6              146  47.444343 -70.505447       False
# 7               39  45.428977 -73.865439        True
# 8              102  45.313978 -73.875834       False
# 9              554  45.564318 -73.204007       False
# 10             963  45.679320 -73.876190       False
# 11            1858  45.671324 -73.756242       False
# 12             351  45.613035 -73.838683       False
# 13             961  45.605020 -73.452614       False
# 14             406  45.318734 -72.646307       False
# 15            1180  45.455483 -73.467890       False
# 16             468  46.339343 -72.433205       False
# 17             550  45.386795 -73.516382       False
# 18            1092  45.566468 -75.782318       False
# 19             219  45.437955 -73.355490       False

# %%
location_df.to_csv('../data/processed/visualization/locations.csv', index=False)
